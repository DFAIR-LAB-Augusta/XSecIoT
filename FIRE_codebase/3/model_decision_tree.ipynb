# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv')

# %%
data1
# Out:
#                 start_time           end_time_x  total_forward_packets_window  \
# 0      2024-08-13 08:00:00  2024-08-13 08:00:05                           261
# 1      2024-08-13 08:00:56  2024-08-13 08:01:01                            42
# 2      2024-08-13 08:00:57  2024-08-13 08:01:02                            42
# 3      2024-08-13 08:00:58  2024-08-13 08:01:03                            42
# 4      2024-08-13 08:00:59  2024-08-13 08:01:04                            42
# ...                    ...                  ...                           ...
# 23981  2024-08-26 20:15:56  2024-08-26 20:16:01                             1
# 23982  2024-08-26 20:15:57  2024-08-26 20:16:02                             1
# 23983  2024-08-26 20:15:58  2024-08-26 20:16:03                             1
# 23984  2024-08-26 20:15:59  2024-08-26 20:16:04                             1
# 23985  2024-08-26 20:16:00  2024-08-26 20:16:05                             1
#
#        total_backward_packets_window  total_forward_bytes_window  \
# 0                                158                       28218
# 1                                  9                        6232
# 2                                  9                        6232
# 3                                  9                        6232
# 4                                  9                        6232
# ...                              ...                         ...
# 23981                              0                         121
# 23982                              0                         121
# 23983                              0                         121
# 23984                              0                         121
# 23985                              0                         121
#
#        total_backward_bytes_window  average_packet_size_fwd_window  \
# 0                            11769                       64.239935
# 1                              671                      134.525210
# 2                              671                      134.525210
# 3                              671                      134.525210
# 4                              671                      134.525210
# ...                            ...                             ...
# 23981                            0                      121.000000
# 23982                            0                      121.000000
# 23983                            0                      121.000000
# 23984                            0                      121.000000
# 23985                            0                      121.000000
#
#        average_packet_size_bwd_window  flow_duration_window  \
# 0                           56.293254            1370937322
# 1                            8.519608             208424228
# 2                            8.519608             208424228
# 3                            8.519608             208424228
# 4                            8.519608             208424228
# ...                               ...                   ...
# 23981                        0.000000                     0
# 23982                        0.000000                     0
# 23983                        0.000000                     0
# 23984                        0.000000                     0
# 23985                        0.000000                     0
#
#        packet_count_window  ...  bwd_iat_mean  bwd_iat_max  bwd_iat_min  \
# 0                      126  ...           0.0            0            0
# 1                       17  ...           0.0            0            0
# 2                       17  ...           0.0            0            0
# 3                       17  ...           0.0            0            0
# 4                       17  ...           0.0            0            0
# ...                    ...  ...           ...          ...          ...
# 23981                    1  ...           0.0            0            0
# 23982                    1  ...           0.0            0            0
# 23983                    1  ...           0.0            0            0
# 23984                    1  ...           0.0            0            0
# 23985                    1  ...           0.0            0            0
#
#        bwd_iat_tot  bwd_blk_rate_avg           end_time_y  total_packets  \
# 0                0               0.0  2024-08-13 08:00:00              2
# 1                0               0.0  2024-08-13 08:00:00              2
# 2                0               0.0  2024-08-13 08:00:00              2
# 3                0               0.0  2024-08-13 08:00:00              2
# 4                0               0.0  2024-08-13 08:00:00              2
# ...            ...               ...                  ...            ...
# 23981            0               0.0  2024-08-26 20:15:00              1
# 23982            0               0.0  2024-08-26 20:15:00              1
# 23983            0               0.0  2024-08-26 20:15:00              1
# 23984            0               0.0  2024-08-26 20:15:00              1
# 23985            0               0.0  2024-08-26 20:15:00              1
#
#        total_bytes       Label  BinLabel
# 0              114  XMasAttack         1
# 1              114  XMasAttack         1
# 2              114  XMasAttack         1
# 3              114  XMasAttack         1
# 4              114  XMasAttack         1
# ...            ...         ...       ...
# 23981           62      Benign         0
# 23982           62      Benign         0
# 23983           62      Benign         0
# 23984           62      Benign         0
# 23985           62      Benign         0
#
# [23986 rows x 68 columns]

# %%
# Identifying missing values
missing_val = data1.isna().sum()
print(missing_val.loc[missing_val > 0])
# Out:
# Series([], dtype: int64)

# %%
# selecting numeric attributes columns from aggregated_data
num_col = list(data1.select_dtypes(include='number').columns)
print(num_col)
# Out:
# ['total_forward_packets_window', 'total_backward_packets_window', 'total_forward_bytes_window', 'total_backward_bytes_window', 'average_packet_size_fwd_window', 'average_packet_size_bwd_window', 'flow_duration_window', 'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window', 'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window', 'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window', 'flow_rate_packets_window', 'flow_rate_bytes_window', 'flow_direction_ratio_window', 'byte_direction_ratio_window', 'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff_seconds', 'src_port', 'dst_port', 'protocol', 'flow_duration', 'total_forward_packets', 'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward', 'mean_packet_length_forward', 'mean_packet_length_backward', 'packet_size_mean', 'flow_iat_mean', 'down_up_ratio', 'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max', 'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean', 'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg', 'total_packets', 'total_bytes', 'BinLabel']

# %%
# Checking for infinity or NaN values and replacing them with the median value of the column
data1.replace([np.inf, -np.inf], np.nan, inplace=True)
for col in num_col:
    if data1[col].isnull().sum() > 0:
        median_value = data1[col].median()
        data1[col] = data1[col].fillna(median_value)

# %%
# Identifying missing values
missing_val = data1.isna().sum()
print(missing_val.loc[missing_val > 0])
# Out:
# Series([], dtype: int64)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Binary data point detection  - fog simulation

# %%
# Load the scaler and PCA
import joblib
scaler = joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/binary_models/scaler_binary.pkl')
pca = joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/binary_models/pca_binary.pkl')
model=joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/binary_models/dt_model_binary.pkl')

# %% [markdown]
# # Binary

# %% [markdown]
# ## sequential processing of all data points in real time

# %%
# sequential processing of all data points in real time

import time
# Real-time simulation function with latency and overall processing time
def sim_time_based_window(file_path, chunk_size=1000, delay=1):
    latencies = []  # List to store latencies for each chunk
    total_start_time = time.time()  # Start time of the entire process

    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        print("\nProcessing new data chunk...")

        # Start tracking the time for processing this chunk
        start_time_latency = time.time()

        print(chunk.columns)

        # Drop the same non-feature columns from the chunk
        X_chunk = chunk.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
        y_true = chunk['BinLabel']  # Assuming 'BinLabel' is the target variable

        # Check for NaN values and fill with column means if necessary
        if X_chunk.isna().any().any():
            print("Chunk contains NaN values. Filling with column means.")
            X_chunk = X_chunk.fillna(X_chunk.mean())

        # Scale and apply PCA to the new chunk
        X_scaled_chunk = scaler.transform(X_chunk)  # Scale the chunk
        X_pca_chunk = pca.transform(X_scaled_chunk)  # Apply PCA to the scaled chunk

        # Predict using the trained model
        predictions = model.predict(X_pca_chunk)

        # Simulate the results
        for i, pred in enumerate(predictions):
            label = 'Attack' if pred == 1 else 'Benign'
            print(f"Data point {i+1}: {label}")

        # End tracking the time after classification for this chunk
        end_time_latency = time.time()

        # Calculate latency for this chunk
        chunk_latency = end_time_latency - start_time_latency
        latencies.append(chunk_latency)
        print(f"Latency for this chunk: {chunk_latency:.4f} seconds")

        # Simulate delay for real-time processing
        time.sleep(delay)  # You can adjust/remove delay for actual real-time performance

    # Calculate total processing time
    total_end_time = time.time()
    total_processing_time = total_end_time - total_start_time

    # Calculate average latency
    average_latency = sum(latencies) / len(latencies) if latencies else 0

    print(f"\nTotal processing time: {total_processing_time:.4f} seconds")
    print(f"Average latency per chunk: {average_latency:.4f} seconds")

# Run the simulation
sim_time_based_window('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv', chunk_size=1000, delay=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Data point 100: Benign
# Data point 101: Benign
# Data point 102: Benign
# Data point 103: Benign
# Data point 104: Benign
# Data point 105: Benign
# Data point 106: Benign
# Data point 107: Benign
# Data point 108: Benign
# Data point 109: Benign
# Data point 110: Benign
# Data point 111: Benign
# Data point 112: Benign
# Data point 113: Benign
# Data point 114: Benign
# Data point 115: Benign
# Data point 116: Benign
# Data point 117: Benign
# Data point 118: Benign
# Data point 119: Benign
# Data point 120: Benign
# Data point 121: Benign
# Data point 122: Benign
# Data point 123: Benign
# Data point 124: Benign
# Data point 125: Benign
# Data point 126: Benign
# Data point 127: Benign
# Data point 128: Benign
# Data point 129: Benign
# Data point 130: Benign
# Data point 131: Benign
# Data point 132: Benign
# Data point 133: Benign
# Data point 134: Benign
# Data point 135: Benign
# Data point 136: Benign
# Data point 137: Benign
# Data point 138: Benign
# Data point 139: Benign
# Data point 140: Benign
# Data point 141: Benign
# Data point 142: Benign
# Data point 143: Benign
# Data point 144: Benign
# Data point 145: Benign
# Data point 146: Benign
# Data point 147: Benign
# Data point 148: Benign
# Data point 149: Benign
# Data point 150: Benign
# Data point 151: Benign
# Data point 152: Benign
# Data point 153: Benign
# Data point 154: Benign
# Data point 155: Benign
# Data point 156: Benign
# Data point 157: Benign
# Data point 158: Benign
# Data point 159: Benign
# Data point 160: Benign
# Data point 161: Benign
# Data point 162: Benign
# Data point 163: Benign
# Data point 164: Benign
# Data point 165: Benign
# Data point 166: Benign
# Data point 167: Benign
# Data point 168: Benign
# Data point 169: Benign
# Data point 170: Benign
# Data point 171: Benign
# Data point 172: Benign
# Data point 173: Benign
# Data point 174: Benign
# Data point 175: Benign
# Data point 176: Benign
# Data point 177: Benign
# Data point 178: Benign
# Data point 179: Benign
# Data point 180: Benign
# Data point 181: Benign
# Data point 182: Benign
# Data point 183: Benign
# Data point 184: Benign
# Data point 185: Benign
# Data point 186: Benign
# Data point 187: Benign
# Data point 188: Benign
# Data point 189: Benign
# Data point 190: Benign
# Data point 191: Benign
# Data point 192: Benign
# Data point 193: Benign
# Data point 194: Benign
# Data point 195: Benign
# Data point 196: Benign
# Data point 197: Benign
# Data point 198: Benign
# Data point 199: Benign
# Data point 200: Benign
# Data point 201: Benign
# Data point 202: Benign
# Data point 203: Benign
# Data point 204: Benign
# Data point 205: Benign
# Data point 206: Benign
# Data point 207: Benign
# Data point 208: Benign
# Data point 209: Benign
# Data point 210: Benign
# Data point 211: Benign
# Data point 212: Benign
# Data point 213: Benign
# Data point 214: Benign
# Data point 215: Benign
# Data point 216: Benign
# Data point 217: Benign
# Data point 218: Benign
# Data point 219: Benign
# Data point 220: Benign
# Data point 221: Benign
# Data point 222: Benign
# Data point 223: Benign
# Data point 224: Benign
# Data point 225: Benign
# Data point 226: Benign
# Data point 227: Benign
# Data point 228: Benign
# Data point 229: Benign
# Data point 230: Benign
# Data point 231: Benign
# Data point 232: Benign
# Data point 233: Benign
# Data point 234: Benign
# Data point 235: Benign
# Data point 236: Benign
# Data point 237: Benign
# Data point 238: Benign
# Data point 239: Benign
# Data point 240: Benign
# Data point 241: Benign
# Data point 242: Benign
# Data point 243: Benign
# Data point 244: Benign
# Data point 245: Benign
# Data point 246: Benign
# Data point 247: Benign
# Data point 248: Benign
# Data point 249: Benign
# Data point 250: Benign
# Data point 251: Benign
# Data point 252: Benign
# Data point 253: Benign
# Data point 254: Benign
# Data point 255: Benign
# Data point 256: Benign
# Data point 257: Benign
# Data point 258: Benign
# Data point 259: Benign
# Data point 260: Benign
# Data point 261: Benign
# Data point 262: Benign
# Data point 263: Benign
# Data point 264: Benign
# Data point 265: Benign
# Data point 266: Benign
# Data point 267: Benign
# Data point 268: Benign
# Data point 269: Benign
# Data point 270: Benign
# Data point 271: Benign
# Data point 272: Benign
# Data point 273: Benign
# Data point 274: Benign
# Data point 275: Benign
# Data point 276: Benign
# Data point 277: Benign
# Data point 278: Benign
# Data point 279: Benign
# Data point 280: Benign
# Data point 281: Benign
# Data point 282: Benign
# Data point 283: Benign
# Data point 284: Benign
# Data point 285: Benign
# Data point 286: Benign
# Data point 287: Benign
# Data point 288: Benign
# Data point 289: Benign
# Data point 290: Benign
# Data point 291: Benign
# Data point 292: Benign
# Data point 293: Benign
# Data point 294: Benign
# Data point 295: Benign
# Data point 296: Benign
# Data point 297: Benign
# Data point 298: Benign
# Data point 299: Benign
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: Benign
# Data point 372: Benign
# Data point 373: Benign
# Data point 374: Benign
# Data point 375: Benign
# Data point 376: Attack
# Data point 377: Attack
# Data point 378: Attack
# Data point 379: Attack
# Data point 380: Attack
# Data point 381: Benign
# Data point 382: Benign
# Data point 383: Benign
# Data point 384: Benign
# Data point 385: Benign
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: Benign
# Data point 572: Benign
# Data point 573: Benign
# Data point 574: Benign
# Data point 575: Benign
# Data point 576: Benign
# Data point 577: Benign
# Data point 578: Benign
# Data point 579: Benign
# Data point 580: Benign
# Data point 581: Benign
# Data point 582: Benign
# Data point 583: Benign
# Data point 584: Benign
# Data point 585: Benign
# Data point 586: Benign
# Data point 587: Benign
# Data point 588: Benign
# Data point 589: Benign
# Data point 590: Benign
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: Attack
# Data point 762: Attack
# Data point 763: Attack
# Data point 764: Attack
# Data point 765: Attack
# Data point 766: Attack
# Data point 767: Attack
# Data point 768: Attack
# Data point 769: Attack
# Data point 770: Attack
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: Benign
# Data point 777: Benign
# Data point 778: Benign
# Data point 779: Benign
# Data point 780: Benign
# Data point 781: Benign
# Data point 782: Benign
# Data point 783: Benign
# Data point 784: Benign
# Data point 785: Benign
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: Benign
# Data point 977: Benign
# Data point 978: Benign
# Data point 979: Benign
# Data point 980: Benign
# Data point 981: Benign
# Data point 982: Benign
# Data point 983: Benign
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: Benign
# Data point 998: Benign
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 0.1297 seconds
#
# Processing new data chunk...
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 1: Benign
# Data point 2: Benign
# Data point 3: Benign
# Data point 4: Benign
# Data point 5: Benign
# Data point 6: Benign
# Data point 7: Benign
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
# Data point 27: Benign
# Data point 28: Benign
# Data point 29: Benign
# Data point 30: Benign
# Data point 31: Benign
# Data point 32: Benign
# Data point 33: Benign
# Data point 34: Benign
# Data point 35: Benign
# Data point 36: Benign
# Data point 37: Benign
# Data point 38: Benign
# Data point 39: Benign
# Data point 40: Benign
# Data point 41: Benign
# Data point 42: Benign
# Data point 43: Benign
# Data point 44: Benign
# Data point 45: Benign
# Data point 46: Benign
# Data point 47: Benign
# Data point 48: Benign
# Data point 49: Benign
# Data point 50: Benign
# Data point 51: Benign
# Data point 52: Benign
# Data point 53: Benign
# Data point 54: Benign
# Data point 55: Benign
# Data point 56: Benign
# Data point 57: Benign
# Data point 58: Benign
# Data point 59: Benign
# Data point 60: Benign
# Data point 61: Benign
# Data point 62: Benign
# Data point 63: Benign
# Data point 64: Benign
# Data point 65: Benign
# Data point 66: Benign
# Data point 67: Benign
# Data point 68: Benign
# Data point 69: Benign
# Data point 70: Benign
# Data point 71: Benign
# Data point 72: Benign
# Data point 73: Benign
# Data point 74: Benign
# Data point 75: Benign
# Data point 76: Benign
# Data point 77: Benign
# Data point 78: Benign
# Data point 79: Benign
# Data point 80: Benign
# Data point 81: Benign
# Data point 82: Benign
# Data point 83: Benign
# Data point 84: Benign
# Data point 85: Benign
# Data point 86: Benign
# Data point 87: Benign
# Data point 88: Benign
# Data point 89: Benign
# Data point 90: Benign
# Data point 91: Benign
# Data point 92: Benign
# Data point 93: Benign
# Data point 94: Benign
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Data point 100: Benign
# Data point 101: Benign
# Data point 102: Benign
# Data point 103: Benign
# Data point 104: Benign
# Data point 105: Benign
# Data point 106: Benign
# Data point 107: Benign
# Data point 108: Benign
# Data point 109: Benign
# Data point 110: Benign
# Data point 111: Benign
# Data point 112: Benign
# Data point 113: Benign
# Data point 114: Benign
# Data point 115: Benign
# Data point 116: Benign
# Data point 117: Benign
# Data point 118: Benign
# Data point 119: Benign
# Data point 120: Benign
# Data point 121: Benign
# Data point 122: Benign
# Data point 123: Benign
# Data point 124: Benign
# Data point 125: Benign
# Data point 126: Benign
# Data point 127: Benign
# Data point 128: Benign
# Data point 129: Benign
# Data point 130: Benign
# Data point 131: Benign
# Data point 132: Benign
# Data point 133: Benign
# Data point 134: Benign
# Data point 135: Benign
# Data point 136: Benign
# Data point 137: Benign
# Data point 138: Benign
# Data point 139: Benign
# Data point 140: Benign
# Data point 141: Benign
# Data point 142: Benign
# Data point 143: Benign
# Data point 144: Benign
# Data point 145: Benign
# Data point 146: Benign
# Data point 147: Benign
# Data point 148: Benign
# Data point 149: Benign
# Data point 150: Benign
# Data point 151: Benign
# Data point 152: Benign
# Data point 153: Benign
# Data point 154: Benign
# Data point 155: Benign
# Data point 156: Benign
# Data point 157: Benign
# Data point 158: Benign
# Data point 159: Benign
# Data point 160: Benign
# Data point 161: Benign
# Data point 162: Benign
# Data point 163: Benign
# Data point 164: Benign
# Data point 165: Benign
# Data point 166: Benign
# Data point 167: Benign
# Data point 168: Benign
# Data point 169: Benign
# Data point 170: Benign
# Data point 171: Attack
# Data point 172: Attack
# Data point 173: Attack
# Data point 174: Attack
# Data point 175: Attack
# Data point 176: Benign
# Data point 177: Benign
# Data point 178: Benign
# Data point 179: Benign
# Data point 180: Benign
# Data point 181: Benign
# Data point 182: Benign
# Data point 183: Benign
# Data point 184: Benign
# Data point 185: Benign
# Data point 186: Benign
# Data point 187: Benign
# Data point 188: Benign
# Data point 189: Benign
# Data point 190: Benign
# Data point 191: Benign
# Data point 192: Benign
# Data point 193: Benign
# Data point 194: Benign
# Data point 195: Benign
# Data point 196: Benign
# Data point 197: Benign
# Data point 198: Benign
# Data point 199: Benign
# Data point 200: Benign
# Data point 201: Benign
# Data point 202: Benign
# Data point 203: Benign
# Data point 204: Benign
# Data point 205: Benign
# Data point 206: Benign
# Data point 207: Benign
# Data point 208: Benign
# Data point 209: Benign
# Data point 210: Benign
# Data point 211: Benign
# Data point 212: Benign
# Data point 213: Benign
# Data point 214: Benign
# Data point 215: Benign
# Data point 216: Benign
# Data point 217: Benign
# Data point 218: Benign
# Data point 219: Benign
# Data point 220: Benign
# Data point 221: Benign
# Data point 222: Benign
# Data point 223: Benign
# Data point 224: Benign
# Data point 225: Benign
# Data point 226: Benign
# Data point 227: Benign
# Data point 228: Benign
# Data point 229: Benign
# Data point 230: Benign
# Data point 231: Benign
# Data point 232: Benign
# Data point 233: Benign
# Data point 234: Benign
# Data point 235: Benign
# Data point 236: Benign
# Data point 237: Benign
# Data point 238: Benign
# Data point 239: Benign
# Data point 240: Benign
# Data point 241: Benign
# Data point 242: Benign
# Data point 243: Benign
# Data point 244: Benign
# Data point 245: Benign
# Data point 246: Benign
# Data point 247: Benign
# Data point 248: Benign
# Data point 249: Benign
# Data point 250: Benign
# Data point 251: Benign
# Data point 252: Benign
# Data point 253: Benign
# Data point 254: Benign
# Data point 255: Benign
# Data point 256: Benign
# Data point 257: Benign
# Data point 258: Benign
# Data point 259: Benign
# Data point 260: Benign
# Data point 261: Benign
# Data point 262: Benign
# Data point 263: Benign
# Data point 264: Benign
# Data point 265: Benign
# Data point 266: Benign
# Data point 267: Benign
# Data point 268: Benign
# Data point 269: Benign
# Data point 270: Benign
# Data point 271: Benign
# Data point 272: Benign
# Data point 273: Benign
# Data point 274: Benign
# Data point 275: Benign
# Data point 276: Benign
# Data point 277: Benign
# Data point 278: Benign
# Data point 279: Benign
# Data point 280: Benign
# Data point 281: Benign
# Data point 282: Benign
# Data point 283: Benign
# Data point 284: Benign
# Data point 285: Benign
# Data point 286: Benign
# Data point 287: Benign
# Data point 288: Benign
# Data point 289: Benign
# Data point 290: Benign
# Data point 291: Benign
# Data point 292: Benign
# Data point 293: Benign
# Data point 294: Benign
# Data point 295: Benign
# Data point 296: Benign
# Data point 297: Benign
# Data point 298: Benign
# Data point 299: Benign
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: Attack
# Data point 372: Attack
# Data point 373: Attack
# Data point 374: Attack
# Data point 375: Attack
# Data point 376: Attack
# Data point 377: Attack
# Data point 378: Attack
# Data point 379: Attack
# Data point 380: Attack
# Data point 381: Benign
# Data point 382: Benign
# Data point 383: Benign
# Data point 384: Benign
# Data point 385: Benign
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: Attack
# Data point 572: Attack
# Data point 573: Attack
# Data point 574: Attack
# Data point 575: Attack
# Data point 576: Attack
# Data point 577: Attack
# Data point 578: Attack
# Data point 579: Attack
# Data point 580: Attack
# Data point 581: Benign
# Data point 582: Benign
# Data point 583: Benign
# Data point 584: Benign
# Data point 585: Benign
# Data point 586: Benign
# Data point 587: Benign
# Data point 588: Benign
# Data point 589: Benign
# Data point 590: Benign
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: Benign
# Data point 762: Benign
# Data point 763: Benign
# Data point 764: Benign
# Data point 765: Benign
# Data point 766: Benign
# Data point 767: Benign
# Data point 768: Benign
# Data point 769: Benign
# Data point 770: Benign
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: Attack
# Data point 777: Attack
# Data point 778: Attack
# Data point 779: Attack
# Data point 780: Attack
# Data point 781: Attack
# Data point 782: Attack
# Data point 783: Attack
# Data point 784: Attack
# Data point 785: Attack
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: Attack
# Data point 977: Attack
# Data point 978: Attack
# Data point 979: Attack
# Data point 980: Attack
# Data point 981: Attack
# Data point 982: Attack
# Data point 983: Attack
# Data point 984: Attack
# Data point 985: Attack
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: Benign
# Data point 998: Benign
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 0.0628 seconds
#
# Processing new data chunk...
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 1: Benign
# Data point 2: Benign
# Data point 3: Benign
# Data point 4: Benign
# Data point 5: Benign
# Data point 6: Benign
# Data point 7: Benign
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
# Data point 27: Benign
# Data point 28: Benign
# Data point 29: Benign
# Data point 30: Benign
# Data point 31: Benign
# Data point 32: Benign
# Data point 33: Benign
# Data point 34: Benign
# Data point 35: Benign
# Data point 36: Benign
# Data point 37: Benign
# Data point 38: Benign
# Data point 39: Benign
# Data point 40: Benign
# Data point 41: Benign
# Data point 42: Benign
# ...
# Data point 297: Benign
# Data point 298: Benign
# Data point 299: Benign
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: Benign
# Data point 372: Benign
# Data point 373: Benign
# Data point 374: Benign
# Data point 375: Benign
# Data point 376: Benign
# Data point 377: Benign
# Data point 378: Benign
# Data point 379: Benign
# Data point 380: Benign
# Data point 381: Attack
# Data point 382: Attack
# Data point 383: Attack
# Data point 384: Attack
# Data point 385: Attack
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: Benign
# Data point 572: Benign
# Data point 573: Benign
# Data point 574: Benign
# Data point 575: Benign
# Data point 576: Benign
# Data point 577: Benign
# Data point 578: Benign
# Data point 579: Benign
# Data point 580: Benign
# Data point 581: Attack
# Data point 582: Attack
# Data point 583: Attack
# Data point 584: Attack
# Data point 585: Attack
# Data point 586: Attack
# Data point 587: Attack
# Data point 588: Attack
# Data point 589: Attack
# Data point 590: Attack
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: Benign
# Data point 762: Benign
# Data point 763: Benign
# Data point 764: Benign
# Data point 765: Benign
# Data point 766: Benign
# Data point 767: Benign
# Data point 768: Benign
# Data point 769: Benign
# Data point 770: Benign
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: Benign
# Data point 777: Benign
# Data point 778: Benign
# Data point 779: Benign
# Data point 780: Benign
# Data point 781: Benign
# Data point 782: Benign
# Data point 783: Benign
# Data point 784: Benign
# Data point 785: Benign
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: Benign
# Data point 977: Benign
# Data point 978: Benign
# Data point 979: Benign
# Data point 980: Benign
# Data point 981: Benign
# Data point 982: Benign
# Data point 983: Benign
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Latency for this chunk: 0.3880 seconds
#
# Total processing time: 51.7459 seconds
# Average latency per chunk: 0.1369 seconds

# %% [markdown]
# ## Continuos Binary

# %%
# Real-time simulation function with window_duration
def simulate_time_based_window(file_path, chunk_size, window_duration, delay=1):
    sliding_window = pd.DataFrame()
    all_true_labels = []
    all_predictions = []
    latencies = []

    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        print("\nProcessing new data chunk...")

        # Start tracking the time for processing this chunk
        start_time_latency = time.time()

        sliding_window = pd.concat([sliding_window, chunk])
        sliding_window['end_time_x'] = pd.to_datetime(sliding_window['end_time_x'])

        latest_time = sliding_window['end_time_x'].max()
        window_start_time = latest_time - pd.Timedelta(seconds=window_duration)
        sliding_window = sliding_window[sliding_window['end_time_x'] >= window_start_time]

        # print(f"Data within the sliding window:")
        print(sliding_window)

        # Drop the same non-feature columns from the chunk
        X_chunk = sliding_window.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
        y_true = sliding_window['BinLabel']  # Assuming 'BinLabel' is the target variable

        # Check for NaN values and fill with column means if necessary
        if X_chunk.isna().any().any():
            print("Chunk contains NaN values. Filling with column means.")
            X_chunk = X_chunk.fillna(X_chunk.mean())

        # Scale and apply PCA to the new chunk
        X_scaled_chunk = scaler.transform(X_chunk)
        X_pca_chunk = pca.transform(X_scaled_chunk)

        # Predict using the trained model
        predictions = model.predict(X_pca_chunk)

        # End tracking the time after classification
        end_time_latency = time.time()

        # Calculate the processing latency for this chunk
        latency = end_time_latency - start_time_latency
        latencies.append(latency)

        print(f"Processing latency for this chunk: {latency:.4f} seconds")

        # Store predictions and true labels
        all_true_labels.extend(y_true.tolist())
        all_predictions.extend(predictions.tolist())

        # Simulate the results
        for i, pred in enumerate(predictions):
            label = 'Attack' if pred == 1 else 'Benign'
            print(f"Data point {i+1}: {label}")

        time.sleep(delay)  # Simulate delay for real-time processing

    # Calculate average latency
    avg_latency = sum(latencies) / len(latencies)
    print(f"Average processing latency: {avg_latency:.4f} seconds")

    return all_true_labels, all_predictions

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Run the simulation and get predictions and true labels
true_labels, predictions = simulate_time_based_window('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv', chunk_size=1000, window_duration=300, delay=1)

# Ensure that the confusion matrix includes both classes (0 for benign, 1 for attack)
conf_matrix = confusion_matrix(true_labels, predictions, labels=[0, 1])

# Calculate other metrics
accuracy = accuracy_score(true_labels, predictions)
precision = precision_score(true_labels, predictions, labels=[0, 1], zero_division=0)
recall = recall_score(true_labels, predictions, labels=[0, 1], zero_division=0)
f1 = f1_score(true_labels, predictions, labels=[0, 1], zero_division=0)

# Specificity: True Negative Rate = TN / (TN + FP)
tn, fp, fn, tp = conf_matrix.ravel()
specificity = tn / (tn + fp)

# Display results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Specificity: {specificity}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
#
# Processing new data chunk...
#                start_time          end_time_x  total_forward_packets_window  \
# 2974  2024-08-13 17:54:59 2024-08-13 17:55:04                            13
# 2975  2024-08-13 17:55:00 2024-08-13 17:55:05                            13
# 2976  2024-08-13 17:55:56 2024-08-13 17:56:01                            90
# 2977  2024-08-13 17:55:57 2024-08-13 17:56:02                            90
# 2978  2024-08-13 17:55:58 2024-08-13 17:56:03                            90
# 2979  2024-08-13 17:55:59 2024-08-13 17:56:04                            90
# 2980  2024-08-13 17:56:00 2024-08-13 17:56:05                            90
# 2981  2024-08-13 17:56:56 2024-08-13 17:57:01                            78
# 2982  2024-08-13 17:56:57 2024-08-13 17:57:02                            78
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# Function to simulate real-time classification for each chunk
def simulate_real_time_classification(chunk, scaler, pca, model):
    latencies = []
    total_start_time = time.time()
    print(f"Processing chunk in process ID: {os.getpid()}")
    cpu_percent = psutil.cpu_percent(interval=1)
    print(f"CPU Utilization in process {os.getpid()}: {cpu_percent}%")

    cpu_count = psutil.cpu_count()
    print(f"Number of CPUs {os.getpid()}:{cpu_count}")

    memory_info = psutil.virtual_memory()
    print(f"Memory Usage {os.getpid()}:{memory_info.percent}%")

    # Start tracking the time for processing this chunk
    start_time_latency = time.time()
    print(chunk.columns)

    # Perform pre-processing
    chunk = chunk.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
    X_chunk = chunk.fillna(chunk.mean())

    # Scale and apply PCA
    X_scaled_chunk = scaler.transform(X_chunk)
    X_pca_chunk = pca.transform(X_scaled_chunk)

    # Predict
    start_time = time.time()
    predictions = model.predict(X_pca_chunk)
    latency = time.time() - start_time
    print(f"Latency for this chunk: {latency:.4f} seconds")

    # Print predictions for this chunk
    print("Predictions for this chunk:")
    for i, pred in enumerate(predictions):
        label = 'Attack' if pred == 1 else 'Benign'
        print(f"Data point {i+1}: {label}")

    # End tracking the time after classification for this chunk
    end_time_latency = time.time()

    # Calculate latency for this chunk
    chunk_latency = end_time_latency - start_time_latency
    latencies.append(chunk_latency)
    print(f"Latency for this chunk: {chunk_latency:.4f} seconds")

    # Calculate total processing time
    total_end_time = time.time()
    total_processing_time = total_end_time - total_start_time

    # Calculate average latency
    average_latency = sum(latencies) / len(latencies) if latencies else 0

    print(f"\nTotal processing time: {total_processing_time:.4f} seconds")
    print(f"Average latency per chunk: {average_latency:.4f} seconds")

    # Simulate real-time results
    return predictions

# Function to process the dataset in parallel
def parallel_real_time_simulation(dataset, chunk_size, num_processes, scaler, pca, model):
    # Split the data into chunks for parallel processing
    chunks = [dataset[i:i + chunk_size] for i in range(0, len(dataset), chunk_size)]

    # Create a pool of workers and use starmap to pass multiple arguments to the worker function
    with mp.Pool(processes=num_processes) as pool:
        results = pool.starmap(simulate_real_time_classification, [(chunk, scaler, pca, model) for chunk in chunks])

    return results

# Assuming the dataset, scaler, PCA, and trained model are already loaded and defined
aggregated_data = pd.read_csv('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv')

# Fit the scaler and PCA on the entire dataset (without the non-feature columns)
X = aggregated_data.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
scaler = StandardScaler().fit(X)
pca = PCA(n_components=0.95).fit(scaler.transform(X))
y = aggregated_data['BinLabel']  # Assuming 'Label' is the target column
model = DecisionTreeClassifier(max_depth = 54).fit(pca.transform(scaler.transform(X)), y)

# Define chunk size and number of parallel processes
chunk_size = 1000  # Number of data points per chunk
num_processes = 4  # Number of parallel processes

start_time = time.time()

# Run the parallel real-time simulation
parallel_results = parallel_real_time_simulation(aggregated_data, chunk_size, num_processes, scaler, pca, model)

# You can now analyze the parallel_results
end_time = time.time()
print(f"Total processing time with parallelization: {end_time - start_time:.4f} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
# Data point 746: BenignData point 852: Benign
#
# Data point 782: AttackData point 760: Benign
#
# Data point 783: Attack
#
# Data point 784: AttackData point 853: Benign
# Data point 761: Benign
# Data point 747: BenignData point 785: Attack
#
# Data point 762: Benign
# Data point 763: Benign
# Data point 854: BenignData point 786: Benign
#
# Data point 764: BenignData point 787: Benign
# Data point 765: Benign
#
# Data point 748: BenignData point 766: Benign
# Data point 767: BenignData point 855: Benign
# Data point 749: Benign
#
#
# Data point 788: BenignData point 750: Benign
#
# Data point 856: BenignData point 751: BenignData point 768: Benign
#
# Data point 752: BenignData point 857: Benign
#
#
# Data point 753: Benign
#
# Data point 754: Benign
# Data point 858: BenignData point 789: BenignData point 769: BenignData point 755: Benign
#
#
#
# Data point 790: BenignData point 770: BenignData point 859: Benign
#
#
# Data point 756: BenignData point 771: BenignData point 791: BenignData point 860: Benign
#
# Data point 772: Benign
# Data point 861: Benign
#
# Data point 773: BenignData point 792: Benign
#
# Data point 757: BenignData point 862: BenignData point 774: Benign
# Data point 863: Benign
#
#
# Data point 864: Benign
#
# Data point 758: BenignData point 865: BenignData point 793: BenignData point 775: Benign
#
#
# Data point 759: Benign
# Data point 866: Benign
#
# Data point 760: Benign
# Data point 867: BenignData point 761: Benign
# Data point 794: BenignData point 776: BenignData point 868: Benign
#
#
# Data point 795: BenignData point 869: Benign
# Data point 762: Benign
#
# Data point 870: BenignData point 796: Benign
# Data point 777: Benign
# Data point 778: Benign
# Data point 871: Benign
# Data point 763: Benign
# Data point 779: Benign
# Data point 797: Benign
#
# Data point 798: Benign
# Data point 872: Benign
# Data point 799: BenignData point 764: BenignData point 780: Benign
#
# Data point 800: Benign
#
#
# Data point 873: BenignData point 765: BenignData point 801: Benign
# Data point 781: Attack
#
# Data point 874: Benign
# Data point 766: BenignData point 802: Benign
# Data point 782: Attack
#
#
# Data point 875: BenignData point 767: BenignData point 803: BenignData point 783: Attack
#
#
# Data point 876: Benign
# Data point 768: BenignData point 804: Benign
# Data point 805: Benign
# Data point 784: AttackData point 877: Benign
#
#
# Data point 769: BenignData point 785: AttackData point 878: Benign
#
#
#
# Data point 770: BenignData point 806: BenignData point 786: BenignData point 879: Benign
#
#
# Data point 771: Benign
# Data point 807: BenignData point 787: BenignData point 880: Benign
#
#
# Data point 772: BenignData point 808: Benign
#
#
# Data point 881: BenignData point 788: BenignData point 773: Benign
# Data point 809: Benign
#
# Data point 882: Benign
# Data point 789: BenignData point 774: Benign
# Data point 810: Benign
#
# Data point 883: Benign
# Data point 790: BenignData point 775: Benign
# Data point 811: Benign
#
#
# Data point 884: BenignData point 776: AttackData point 791: BenignData point 812: Benign
#
#
#
# Data point 885: BenignData point 792: BenignData point 777: AttackData point 813: Benign
#
#
#
# Data point 886: BenignData point 793: BenignData point 778: AttackData point 814: Benign
#
#
#
# Data point 887: BenignData point 779: AttackData point 815: BenignData point 794: Benign
#
#
# Data point 888: Benign
# Data point 816: BenignData point 780: AttackData point 795: Benign
#
#
#
# Data point 817: BenignData point 889: BenignData point 781: Attack
# Data point 796: Benign
# Data point 818: Benign
#
# Data point 797: Benign
#
# Data point 890: BenignData point 819: BenignData point 798: Benign
#
# Data point 782: AttackData point 799: Benign
#
# Data point 891: Benign
# Data point 820: BenignData point 800: Benign
# Data point 783: AttackData point 892: Benign
#
#
#
# Data point 821: BenignData point 801: BenignData point 784: Attack
# Data point 893: Benign
# Data point 802: Benign
# Data point 785: AttackData point 822: Benign
# Data point 894: Benign
#
#
#
# Data point 895: BenignData point 803: BenignData point 786: BenignData point 823: Benign
#
#
# Data point 824: Benign
# Data point 896: BenignData point 804: BenignData point 787: Benign
#
#
#
# Data point 805: BenignData point 897: Benign
# Data point 825: BenignData point 788: Benign
#
# Data point 789: BenignData point 898: Benign
# Data point 806: Benign
#
# Data point 826: BenignData point 790: Benign
#
# Data point 899: BenignData point 807: Benign
# Data point 791: BenignData point 827: Benign
#
#
#
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: BenignData point 828: BenignData point 808: BenignData point 792: Benign
#
#
# Data point 793: Benign
# Data point 829: Benign
#
# Data point 809: BenignData point 903: BenignData point 794: BenignData point 830: Benign
#
#
#
# Data point 810: BenignData point 904: BenignData point 795: BenignData point 831: Benign
#
#
# Data point 811: Benign
# Data point 796: BenignData point 905: Benign
# Data point 832: Benign
#
# Data point 812: Benign
# Data point 797: BenignData point 906: BenignData point 833: Benign
#
#
#
# Data point 813: BenignData point 907: BenignData point 798: BenignData point 834: Benign
#
#
#
# Data point 814: Benign
# Data point 908: BenignData point 815: BenignData point 799: BenignData point 835: Benign
#
#
#
# Data point 909: BenignData point 816: Benign
# Data point 800: BenignData point 836: BenignData point 910: Benign
# Data point 817: Benign
#
#
# Data point 801: Benign
# Data point 837: Benign
# Data point 818: BenignData point 911: Benign
#
#
# Data point 802: BenignData point 912: Benign
# Data point 819: Benign
#
# Data point 803: BenignData point 838: BenignData point 913: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 839: BenignData point 820: Benign
#
#
# Data point 821: BenignData point 806: Benign
#
# Data point 822: Benign
# Data point 914: BenignData point 840: Benign
#
# Data point 823: Benign
# Data point 841: Benign
# Data point 824: Benign
# Data point 807: BenignData point 915: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 842: Benign
#
# Data point 827: Benign
# Data point 808: Benign
# Data point 916: BenignData point 828: BenignData point 843: Benign
#
#
#
# Data point 917: BenignData point 829: BenignData point 844: BenignData point 809: Benign
#
# Data point 810: Benign
#
#
# Data point 811: Benign
# Data point 918: BenignData point 830: BenignData point 812: BenignData point 845: Benign
#
#
#
# Data point 813: BenignData point 846: BenignData point 831: BenignData point 919: Benign
#
#
# Data point 814: Benign
# Data point 815: Benign
#
# Data point 832: BenignData point 920: BenignData point 816: BenignData point 847: Benign
#
#
#
# Data point 817: BenignData point 833: BenignData point 921: Benign
# Data point 848: BenignData point 818: Benign
#
#
# Data point 834: BenignData point 922: Benign
# Data point 849: Benign
#
# Data point 819: Benign
# Data point 923: BenignData point 835: Benign
# Data point 850: Benign
#
# Data point 820: Benign
# Data point 924: BenignData point 836: Benign
# Data point 851: Benign
#
# Data point 821: Benign
# Data point 837: BenignData point 925: Benign
# Data point 852: Benign
# Data point 822: Benign
#
# Data point 838: BenignData point 926: Benign
# Data point 853: Benign
# Data point 823: Benign
#
# Data point 839: BenignData point 927: Benign
# Data point 854: Benign
# Data point 824: Benign
#
# Data point 840: Benign
# Data point 928: Benign
# Data point 855: BenignData point 825: BenignData point 841: Benign
#
#
# Data point 842: Benign
#
# Data point 843: BenignData point 929: BenignData point 826: BenignData point 856: Benign
#
#
#
# Data point 844: BenignData point 930: BenignData point 827: Benign
# Data point 857: Benign
#
#
# Data point 828: BenignData point 845: BenignData point 931: Benign
# Data point 858: Benign
#
#
# Data point 932: BenignData point 829: BenignData point 846: BenignData point 859: Benign
#
#
#
# Data point 933: BenignData point 830: BenignData point 860: BenignData point 847: Benign
#
#
#
# Data point 934: Benign
# Data point 831: BenignData point 861: BenignData point 935: BenignData point 848: Benign
#
#
#
# Data point 862: BenignData point 936: Benign
# Data point 832: BenignData point 849: Benign
#
#
# Data point 937: BenignData point 833: BenignData point 850: BenignData point 863: Benign
#
# Data point 938: Benign
#
#
# Data point 864: BenignData point 834: BenignData point 851: BenignData point 939: Benign
#
#
#
# Data point 865: BenignData point 835: BenignData point 852: Benign
# Data point 940: Benign
# Data point 866: Benign
# Data point 836: Benign
#
# Data point 853: BenignData point 941: Benign
# Data point 867: Benign
# Data point 837: BenignData point 854: Benign
#
#
#
#
# Data point 855: BenignData point 856: BenignData point 942: BenignData point 868: BenignData point 838: Benign
#
#
# Data point 943: Benign
# Data point 857: Benign
# Data point 869: BenignData point 839: Benign
#
#
# Data point 944: BenignData point 858: BenignData point 840: BenignData point 870: Benign
#
# Data point 871: Benign
# Data point 872: Benign
#
# Data point 945: Benign
# Data point 873: BenignData point 841: BenignData point 859: Benign
#
#
#
# Data point 946: BenignData point 874: BenignData point 860: BenignData point 842: Benign
#
#
#
# Data point 861: BenignData point 947: BenignData point 875: BenignData point 843: Benign
#
#
#
# Data point 948: BenignData point 876: BenignData point 844: BenignData point 862: Benign
#
#
#
# Data point 949: BenignData point 877: BenignData point 863: BenignData point 845: Benign
#
#
#
# Data point 950: BenignData point 878: BenignData point 846: BenignData point 864: Benign
#
#
# Data point 879: Benign
# Data point 847: BenignData point 951: BenignData point 865: Benign
#
#
#
# Data point 952: BenignData point 880: BenignData point 848: BenignData point 866: Benign
#
#
#
# Data point 881: BenignData point 849: BenignData point 953: BenignData point 867: Benign
#
#
#
# Data point 882: BenignData point 850: BenignData point 954: BenignData point 868: Benign
#
#
#
# Data point 883: BenignData point 851: BenignData point 955: BenignData point 869: Benign
#
#
#
# Data point 884: BenignData point 852: BenignData point 956: BenignData point 870: Benign
#
#
#
# Data point 885: BenignData point 853: BenignData point 957: BenignData point 871: Benign
#
#
#
# Data point 886: BenignData point 854: BenignData point 958: BenignData point 872: Benign
#
#
#
# Data point 887: BenignData point 855: BenignData point 959: BenignData point 873: Benign
#
#
#
# Data point 888: BenignData point 856: BenignData point 874: BenignData point 960: Benign
#
#
#
# Data point 889: BenignData point 857: BenignData point 961: BenignData point 875: Benign
#
#
#
# Data point 890: BenignData point 858: BenignData point 876: BenignData point 962: Benign
#
#
#
# Data point 859: BenignData point 891: Benign
# Data point 963: BenignData point 877: Benign
#
#
# Data point 860: BenignData point 892: BenignData point 878: BenignData point 893: BenignData point 965: BenignData point 964: Benign
#
#
# Data point 861: Benign
#
# Data point 879: Benign
# Data point 862: Benign
# Data point 894: Benign
#
#
# Data point 880: BenignData point 863: BenignData point 966: Benign
# Data point 895: Benign
#
#
# Data point 881: BenignData point 864: BenignData point 967: BenignData point 896: Benign
#
#
#
# Data point 882: BenignData point 865: BenignData point 968: BenignData point 897: Benign
#
#
#
# Data point 883: BenignData point 866: BenignData point 969: BenignData point 898: Benign
#
#
#
# Data point 884: BenignData point 867: BenignData point 970: BenignData point 899: Benign
#
#
#
# Data point 885: BenignData point 868: BenignData point 971: BenignData point 900: Benign
#
#
# Data point 869: Benign
# Data point 886: Benign
# Data point 972: Benign
# Data point 901: Benign
# Data point 870: BenignData point 887: Benign
#
# Data point 973: Benign
# Data point 902: BenignData point 871: Benign
#
# Data point 888: Benign
# Data point 974: Benign
# Data point 903: BenignData point 872: Benign
# Data point 889: Benign
#
# Data point 975: Benign
# Data point 904: BenignData point 873: Benign
# Data point 890: Benign
# Data point 976: Attack
#
#
# Data point 905: BenignData point 874: BenignData point 891: Benign
# Data point 977: Attack
#
# Data point 892: Benign
# Data point 906: BenignData point 875: BenignData point 978: Attack
#
#
#
# Data point 876: BenignData point 979: Attack
# Data point 893: BenignData point 907: Benign
#
#
# Data point 877: BenignData point 908: BenignData point 894: BenignData point 980: Attack
#
#
#
# Data point 909: BenignData point 878: BenignData point 981: BenignData point 895: Benign
#
#
#
# Data point 910: BenignData point 879: BenignData point 896: BenignData point 982: Benign
#
#
#
# Data point 911: BenignData point 880: BenignData point 897: BenignData point 983: Benign
#
#
# Data point 898: Benign
# Data point 912: BenignData point 881: BenignData point 984: Benign
#
#
#
# Data point 913: Benign
# Data point 882: BenignData point 899: BenignData point 985: Benign
#
#
# Data point 914: BenignData point 883: BenignData point 900: BenignData point 986: Benign
#
#
#
# Data point 915: BenignData point 884: BenignData point 901: Benign
#
# Data point 987: Benign
# Data point 916: Benign
# Data point 902: BenignData point 885: Benign
#
# Data point 988: Benign
# Data point 917: BenignData point 903: Benign
# Data point 886: Benign
#
# Data point 918: Benign
# Data point 989: BenignData point 887: Benign
#
# Data point 904: BenignData point 919: BenignData point 990: Benign
#
# Data point 888: Benign
#
# Data point 905: Benign
# Data point 920: Benign
# Data point 991: BenignData point 906: Benign
# Data point 889: Benign
#
#
# Data point 921: BenignData point 992: BenignData point 907: Benign
#
# Data point 890: BenignData point 922: BenignData point 993: Benign
#
#
# Data point 908: BenignData point 891: Benign
# Data point 923: Benign
#
# Data point 994: Benign
# Data point 909: Benign
# Data point 892: BenignData point 924: Benign
#
# Data point 995: BenignData point 910: Benign
#
# Data point 893: Benign
# Data point 996: Benign
# Data point 911: BenignData point 925: Benign
# Data point 894: Benign
#
# Data point 926: Benign
# Data point 912: BenignData point 895: BenignData point 997: Benign
#
#
# Data point 896: BenignData point 913: Benign
#
#
# Data point 927: BenignData point 897: BenignData point 998: Benign
#
#
#
# Data point 928: BenignData point 914: Benign
# Data point 999: BenignData point 898: BenignData point 915: BenignData point 929: Benign
#
#
# Data point 1000: BenignData point 899: Benign
# Data point 930: Benign
#
# Latency for this chunk: 22.2678 seconds
# Data point 916: BenignData point 900: BenignData point 931: Benign
#
#
# Total processing time: 23.3458 seconds
#
#
# Data point 932: BenignData point 917: BenignData point 901: Benign
# Average latency per chunk: 22.2678 seconds
#
#
# Data point 933: BenignData point 918: BenignProcessing chunk in process ID: 1636
# Data point 902: Benign
#
# Data point 934: Benign
#
# Data point 935: Benign
# Data point 903: BenignData point 919: Benign
# Data point 936: BenignData point 904: Benign
#
# Data point 920: Benign
# Data point 937: Benign
# Data point 921: Benign
# Data point 905: BenignData point 938: Benign
#
#
# Data point 906: BenignData point 922: BenignData point 939: Benign
#
#
# Data point 907: BenignData point 940: Benign
# Data point 923: Benign
#
# Data point 908: BenignData point 941: Benign
# Data point 924: Benign
#
# Data point 909: BenignData point 925: Benign
# Data point 942: Benign
# Data point 926: Benign
# Data point 910: Benign
# Data point 927: Benign
#
# Data point 943: BenignData point 928: Benign
#
# Data point 944: BenignData point 911: BenignData point 929: Benign
#
# Data point 912: Benign
# Data point 945: Benign
# Data point 913: Benign
# Data point 930: Benign
#
# Data point 946: BenignData point 914: BenignData point 931: Benign
#
#
# Data point 915: BenignData point 947: BenignData point 932: Benign
#
# Data point 948: BenignData point 916: Benign
#
# Data point 933: Benign
#
# Data point 949: BenignData point 917: Benign
# Data point 934: Benign
# Data point 918: Benign
#
# Data point 950: BenignData point 919: Benign
# Data point 935: Benign
# Data point 920: Benign
#
# Data point 951: BenignData point 936: BenignData point 921: Benign
#
#
# Data point 952: BenignData point 922: BenignData point 937: Benign
#
#
# Data point 923: Benign
# Data point 924: BenignData point 953: BenignData point 938: Benign
#
#
# Data point 925: BenignData point 954: BenignData point 939: Benign
#
#
# Data point 955: Benign
# Data point 940: BenignData point 956: Benign
#
# Data point 926: BenignData point 941: Benign
# Data point 957: Benign
#
# Data point 927: BenignData point 942: BenignData point 958: Benign
#
# Data point 928: Benign
# Data point 943: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 929: Benign
# Data point 944: Benign
# Data point 961: Benign
#
# Data point 930: BenignData point 962: BenignData point 945: Benign
# Data point 931: Benign
#
#
#
#
# Data point 932: BenignData point 963: BenignData point 946: BenignData point 933: BenignData point 947: Benign
#
# Data point 948: Benign
#
# Data point 949: BenignData point 964: Benign
#
# Data point 934: BenignData point 950: BenignData point 965: Benign
#
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
#
# Data point 938: Benign
# Data point 951: BenignData point 939: Benign
# Data point 966: Benign
# Data point 940: BenignData point 952: Benign
#
#
# Data point 967: BenignData point 953: Benign
# Data point 941: Benign
#
# Data point 954: Benign
# Data point 968: BenignData point 942: Benign
#
# Data point 955: BenignData point 969: Benign
#
#
# Data point 943: BenignData point 956: BenignData point 944: BenignData point 970: Benign
#
#
# Data point 957: BenignData point 971: BenignData point 945: Benign
#
#
# Data point 946: BenignData point 958: BenignData point 972: Benign
#
#
# Data point 973: BenignData point 959: BenignData point 947: Benign
#
#
# Data point 974: BenignData point 948: BenignData point 960: Benign
#
# Data point 975: Benign
# Data point 949: Benign
# Data point 961: BenignData point 976: Benign
#
# Data point 950: Benign
# Data point 962: Benign
# Data point 977: Benign
# Data point 951: Benign
# Data point 963: Benign
# Data point 978: Benign
# Data point 952: Benign
# Data point 964: Benign
# Data point 979: Benign
# Data point 953: Benign
# Data point 965: BenignCPU Utilization in process 1636: 100.0%
#
# Data point 980: Benign
# Data point 954: Benign
#
# Data point 966: BenignNumber of CPUs 1636:2Data point 981: Benign
# Data point 955: Benign
#
# Data point 967: Benign
# Data point 956: BenignMemory Usage 1636:16.1%Data point 982: Benign
#
#
#
# Data point 968: BenignData point 957: Benign
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 983: BenignData point 969: Benign
#
#
# Data point 958: BenignData point 984: Benign
#
# Data point 970: BenignData point 959: Benign
# Data point 985: Benign
#
# Data point 971: BenignData point 960: BenignData point 986: Benign
# Data point 972: Benign
#
# Data point 961: BenignData point 987: Benign
#
# Data point 973: Benign
# Data point 962: Benign
# Data point 988: Benign
# Data point 974: Benign
# Data point 963: Benign
# Data point 989: BenignData point 975: Benign
#
#
# Data point 964: BenignData point 990: Benign
#
# Data point 976: Benign
# Data point 965: BenignLatency for this chunk: 0.0007 secondsData point 991: Benign
# Data point 977: Benign
# Data point 966: BenignData point 978: Benign
#
# Data point 992: BenignPredictions for this chunk:
#
#
#
# Data point 979: BenignData point 1: Benign
# Data point 993: BenignData point 980: Benign
# Data point 967: Benign
#
# Data point 2: Benign
# Data point 994: BenignData point 981: AttackData point 968: Benign
#
# Data point 3: BenignData point 995: Benign
#
#
# Data point 982: Attack
# Data point 969: Benign
# Data point 4: BenignData point 996: BenignData point 983: Attack
#
#
# Data point 970: Benign
# Data point 5: Benign
# Data point 971: Benign
# Data point 997: Benign
# Data point 972: Benign
# Data point 984: AttackData point 6: BenignData point 998: Benign
#
# Data point 973: Benign
# Data point 985: Attack
#
#
# Data point 999: BenignData point 974: BenignData point 7: Benign
#
# Data point 986: Benign
#
# Data point 975: BenignData point 1000: BenignData point 987: Benign
# Data point 8: Benign
#
# Latency for this chunk: 23.2428 secondsData point 976: Attack
# Data point 988: BenignData point 9: Benign
#
#
#
# Data point 977: AttackData point 989: Benign
# Total processing time: 24.3278 secondsData point 10: Benign
#
#
# Data point 978: Attack
# Average latency per chunk: 23.2428 secondsData point 990: BenignData point 11: Benign
#
# Data point 979: Attack
#
# Data point 991: BenignProcessing chunk in process ID: 1637Data point 12: Benign
#
#
# Data point 992: Benign
# Data point 980: Attack
# Data point 13: Benign
# Data point 981: Attack
#
#
# Data point 14: BenignData point 993: BenignData point 15: BenignData point 982: Attack
# Data point 994: Benign
#
#
# Data point 995: BenignData point 983: AttackData point 16: Benign
#
#
#
# Data point 996: BenignData point 17: BenignData point 997: BenignData point 984: Attack
#
#
# Data point 18: BenignData point 985: AttackData point 998: Benign
#
#
# Data point 19: BenignData point 986: BenignData point 999: Benign
#
#
# Data point 987: BenignData point 20: BenignData point 1000: Benign
#
#
# Data point 988: BenignData point 21: BenignLatency for this chunk: 23.3324 seconds
#
#
# Data point 989: BenignData point 22: Benign
# Total processing time: 24.4114 seconds
#
#
# Average latency per chunk: 23.3324 secondsData point 990: BenignData point 23: Benign
#
#
# Data point 991: BenignProcessing chunk in process ID: 1638Data point 24: Benign
#
#
# Data point 992: BenignData point 25: Benign
#
# Data point 993: Benign
# Data point 26: BenignData point 994: Benign
#
# Data point 995: Benign
# Data point 27: Benign
# Data point 996: Benign
# Data point 28: Benign
# Data point 997: BenignData point 29: Benign
# Data point 998: Benign
#
# Data point 30: BenignData point 999: Benign
#
# Data point 31: BenignData point 1000: Benign
#
# Data point 32: Benign
# Latency for this chunk: 23.6816 secondsData point 33: Benign
#
# Data point 34: Benign
# Data point 35: Benign
# Total processing time: 24.7586 seconds
#
# Data point 36: Benign
# Average latency per chunk: 23.6816 secondsData point 37: Benign
#
# Processing chunk in process ID: 1639
# Data point 38: Benign
# Data point 39: Benign
# Data point 40: Benign
# Data point 41: Benign
# Data point 42: Benign
#
# Data point 43: Benign
# Data point 44: BenignData point 45: Benign
# Data point 46: Benign
# Data point 47: Benign
# Data point 48: Benign
# Data point 49: Benign
# Data point 50: Benign
# Data point 51: Benign
# Data point 52: Benign
# Data point 53: Benign
# Data point 54: Benign
# Data point 55: Benign
# Data point 56: Benign
# Data point 57: Benign
# Data point 58: Benign
# Data point 59: Benign
# Data point 60: Benign
# Data point 61: Benign
# Data point 62: Benign
# Data point 63: Benign
# Data point 64: Benign
# Data point 65: Benign
# Data point 66: Benign
# Data point 67: Benign
# Data point 68: Benign
# Data point 69: Benign
# Data point 70: Benign
# Data point 71: Benign
# Data point 72: Benign
# Data point 73: Benign
# Data point 74: Benign
# Data point 75: Benign
# Data point 76: Benign
# Data point 77: Benign
# Data point 78: Benign
# Data point 79: Benign
# Data point 80: Benign
# Data point 81: Benign
# Data point 82: Benign
# Data point 83: Benign
# Data point 84: Benign
# Data point 85: Benign
# Data point 86: Benign
# Data point 87: Benign
# Data point 88: Benign
# Data point 89: BenignCPU Utilization in process 1637: 100.0%
# Data point 90: Benign
# Number of CPUs 1637:2
#
# Data point 91: BenignMemory Usage 1637:16.1%
# Data point 92: Benign
#
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')Data point 93: Benign
#
# Data point 94: Benign
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Latency for this chunk: 0.0006 secondsData point 100: Benign
#
# Data point 101: Benign
# Data point 102: Benign
# Data point 103: BenignPredictions for this chunk:
# Data point 104: Benign
#
# Data point 105: Benign
# Data point 106: Benign
# Data point 107: Benign
# Data point 108: BenignData point 1: Benign
#
# Data point 109: BenignData point 2: Benign
# CPU Utilization in process 1638: 100.0%
# Number of CPUs 1638:2
#
# Memory Usage 1638:16.1%Data point 110: BenignData point 3: Benign
#
#
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')Data point 4: BenignData point 111: Benign
# Data point 5: Benign
# Data point 6: Benign
#
#
# Data point 7: BenignData point 112: Benign
# Data point 113: Benign
# Data point 114: Benign
# Data point 8: Benign
#
# Data point 9: Benign
# Data point 10: BenignData point 115: Benign
#
# Data point 11: BenignData point 116: Benign
#
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: BenignData point 117: Benign
#
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: BenignData point 118: Benign
#
# Data point 19: BenignCPU Utilization in process 1639: 100.0%Data point 119: Benign
#
# Data point 20: BenignData point 120: Benign
#
# Data point 21: Benign
# Latency for this chunk: 0.0006 secondsData point 22: Benign
# Data point 23: Benign
# Number of CPUs 1639:2Data point 24: Benign
#
# Data point 121: Benign
# Data point 25: Benign
#
#
# Memory Usage 1639:16.1%Predictions for this chunk:
# Data point 122: Benign
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 1: BenignData point 26: Benign
#
#
# Data point 123: BenignData point 2: BenignData point 27: Benign
# Data point 28: Benign
#
# Data point 3: Benign
# Data point 29: BenignData point 124: Benign
#
#
# Data point 125: BenignData point 4: Benign
# Data point 30: BenignData point 5: Benign
#
# Data point 126: BenignData point 31: Benign
#
#
# Data point 6: BenignData point 127: Benign
# Data point 32: Benign
#
# Data point 128: BenignData point 33: Benign
# Data point 129: Benign
# Data point 7: BenignData point 130: Benign
# Data point 131: Benign
# Data point 132: Benign
# Data point 133: Benign
#
# Data point 8: Benign
#
# Data point 34: BenignData point 134: BenignData point 9: Benign
# Latency for this chunk: 0.0006 secondsData point 10: Benign
#
#
#
# Predictions for this chunk:Data point 35: BenignData point 11: Benign
#
# Data point 36: BenignData point 135: Benign
# Data point 1: Benign
#
#
# Data point 12: BenignData point 37: BenignData point 136: BenignData point 2: Benign
#
#
#
# Data point 137: BenignData point 3: BenignData point 13: BenignData point 38: Benign
#
#
#
# Data point 138: BenignData point 14: BenignData point 4: BenignData point 39: Benign
#
#
#
# Data point 5: BenignData point 139: BenignData point 40: Benign
# Data point 15: Benign
#
# Data point 140: BenignData point 41: BenignData point 6: Benign
#
# Data point 42: BenignData point 7: Benign
#
#
#
# Data point 43: BenignData point 8: BenignData point 141: Benign
#
# Data point 16: Benign
# Data point 9: Benign
# Data point 142: BenignData point 17: BenignData point 44: Benign
#
#
# Data point 143: Benign
# Data point 18: Benign
# Data point 144: Benign
# Data point 10: Benign
# Data point 19: BenignData point 45: BenignData point 11: Benign
#
#
# Data point 20: BenignData point 12: Benign
#
# Data point 46: BenignData point 21: Benign
#
#
# Data point 145: BenignData point 13: BenignData point 22: Benign
#
# Data point 47: Benign
#
# Data point 14: BenignData point 23: BenignData point 48: Benign
#
# Data point 15: Benign
# Data point 146: BenignData point 24: Benign
# Data point 49: BenignData point 16: Benign
#
#
# Data point 50: BenignData point 25: BenignData point 17: Benign
#
#
# Data point 26: BenignData point 51: Benign
# Data point 27: Benign
# Data point 147: BenignData point 18: Benign
#
#
# Data point 19: Benign
#
# Data point 20: BenignData point 52: BenignData point 28: BenignData point 148: Benign
# Data point 21: Benign
#
#
# Data point 149: Benign
#
# Data point 53: BenignData point 150: Benign
# Data point 151: BenignData point 29: Benign
# Data point 54: Benign
#
#
# Data point 22: BenignData point 152: BenignData point 30: Benign
# Data point 31: BenignData point 55: Benign
#
#
# Data point 32: BenignData point 56: Benign
#
# Data point 23: Benign
# Data point 153: BenignData point 33: Benign
#
#
# Data point 57: BenignData point 24: Benign
#
# Data point 34: BenignData point 154: Benign
# Data point 58: Benign
# Data point 25: BenignData point 35: Benign
#
# Data point 59: BenignData point 155: Benign
# Data point 26: Benign
# Data point 36: BenignData point 156: Benign
#
#
#
# Data point 60: BenignData point 27: BenignData point 37: BenignData point 157: Benign
#
#
#
# Data point 61: BenignData point 28: BenignData point 38: BenignData point 158: Benign
#
#
#
# Data point 62: BenignData point 39: Benign
# Data point 159: BenignData point 29: Benign
# Data point 63: Benign
#
# Data point 30: BenignData point 160: Benign
# Data point 40: Benign
#
# Data point 161: Benign
# Data point 64: Benign
# Data point 41: BenignData point 31: Benign
# Data point 162: Benign
#
#
# Data point 65: BenignData point 42: Benign
#
# Data point 163: BenignData point 32: BenignData point 66: BenignData point 43: Benign
#
#
#
# Data point 164: BenignData point 67: BenignData point 33: BenignData point 44: Benign
#
# Data point 34: Benign
#
#
# Data point 165: BenignData point 68: BenignData point 45: BenignData point 35: Benign
#
#
#
# Data point 69: BenignData point 166: BenignData point 46: BenignData point 36: Benign
#
#
# Data point 167: BenignData point 47: Benign
# Data point 70: Benign
#
# Data point 37: Benign
# Data point 38: Benign
# Data point 48: BenignData point 168: Benign
#
#
# Data point 71: BenignData point 39: BenignData point 169: Benign
# Data point 49: BenignData point 72: Benign
#
#
# Data point 50: BenignData point 40: BenignData point 170: Benign
# Data point 73: Benign
#
#
#
# Data point 51: BenignData point 171: BenignData point 41: Benign
# Data point 74: Benign
#
# Data point 52: Benign
# Data point 172: BenignData point 42: BenignData point 75: Benign
#
#
# Data point 53: Benign
# Data point 43: BenignData point 173: BenignData point 76: Benign
#
#
# Data point 54: Benign
# Data point 174: BenignData point 44: BenignData point 77: Benign
#
#
# Data point 55: Benign
# Data point 175: BenignData point 45: Benign
# Data point 78: BenignData point 56: Benign
#
#
#
# Data point 57: BenignData point 176: BenignData point 46: BenignData point 79: Benign
#
#
#
# Data point 177: BenignData point 47: BenignData point 58: BenignData point 80: Benign
#
# Data point 59: Benign
#
# Data point 178: Benign
# Data point 48: Benign
# Data point 81: Benign
# Data point 179: BenignData point 60: Benign
# Data point 49: Benign
#
#
# Data point 82: BenignData point 180: BenignData point 61: Benign
# Data point 50: Benign
#
# Data point 62: BenignData point 181: BenignData point 83: Benign
#
#
# Data point 51: BenignData point 182: Benign
# Data point 63: BenignData point 84: Benign
#
#
# Data point 64: BenignData point 183: Benign
#
#
# Data point 85: BenignData point 65: BenignData point 52: BenignData point 184: Benign
#
#
#
# Data point 86: BenignData point 53: BenignData point 66: BenignData point 185: Benign
#
#
#
# Data point 67: BenignData point 186: BenignData point 54: BenignData point 87: Benign
#
#
#
# Data point 68: BenignData point 88: Benign
# Data point 55: BenignData point 187: Benign
# Data point 69: Benign
# Data point 89: Benign
#
# Data point 90: BenignData point 56: Benign
# Data point 188: Benign
#
#
# Data point 91: BenignData point 58: BenignData point 70: BenignData point 57: Benign
# Data point 189: Benign
# Data point 71: Benign
#
#
#
# Data point 190: BenignData point 59: BenignData point 92: BenignData point 72: Benign
#
#
# Data point 191: Benign
# Data point 60: BenignData point 93: Benign
# Data point 73: Benign
#
#
# Data point 192: BenignData point 61: Benign
# Data point 193: BenignData point 94: Benign
# Data point 74: BenignData point 62: Benign
#
# Data point 95: Benign
#
# Data point 63: BenignData point 75: BenignData point 194: Benign
#
# Data point 64: Benign
#
# Data point 76: Benign
# Data point 96: BenignData point 195: BenignData point 65: Benign
#
#
#
# Data point 77: BenignData point 97: BenignData point 196: BenignData point 66: Benign
#
#
#
# Data point 98: BenignData point 197: BenignData point 78: BenignData point 67: Benign
#
#
#
# Data point 99: BenignData point 198: BenignData point 68: BenignData point 79: Benign
#
#
#
# Data point 69: BenignData point 199: BenignData point 100: Benign
# Data point 80: Benign
#
# Data point 101: BenignData point 70: Benign
# Data point 200: Benign
#
# Data point 81: Benign
# Data point 201: BenignData point 71: BenignData point 102: Benign
#
#
# Data point 82: Benign
# Data point 103: BenignData point 72: Benign
# Data point 202: Benign
#
# Data point 83: Benign
#
# Data point 73: BenignData point 104: BenignData point 84: BenignData point 203: Benign
#
#
#
# Data point 74: BenignData point 204: BenignData point 105: BenignData point 85: Benign
#
#
#
# Data point 106: BenignData point 205: BenignData point 75: BenignData point 86: Benign
#
#
# Data point 76: Benign
# Data point 107: Benign
# Data point 206: BenignData point 87: BenignData point 108: Benign
#
#
# Data point 77: BenignData point 109: Benign
#
#
# Data point 207: Benign
# Data point 88: BenignData point 78: BenignData point 110: BenignData point 208: Benign
#
#
#
# Data point 79: BenignData point 209: Benign
# Data point 89: BenignData point 80: BenignData point 111: Benign
#
# Data point 210: BenignData point 90: Benign
#
#
#
# Data point 211: BenignData point 112: BenignData point 81: BenignData point 91: Benign
#
#
#
# Data point 82: BenignData point 212: BenignData point 92: Benign
# Data point 113: BenignData point 93: Benign
#
#
#
# Data point 213: BenignData point 83: BenignData point 114: BenignData point 94: Benign
#
#
#
# Data point 214: BenignData point 95: Benign
# Data point 115: BenignData point 84: Benign
#
# Data point 96: BenignData point 215: Benign
# Data point 85: Benign
#
# Data point 116: Benign
# Data point 216: BenignData point 97: Benign
# Data point 86: Benign
# Data point 117: Benign
#
# Data point 87: Benign
# Data point 98: BenignData point 217: Benign
# Data point 88: Benign
# Data point 89: Benign
#
# Data point 118: BenignData point 99: BenignData point 218: Benign
#
# Data point 90: Benign
#
# Data point 119: Benign
# Data point 100: BenignData point 219: BenignData point 91: Benign
#
#
# Data point 101: BenignData point 120: Benign
# Data point 220: Benign
#
# Data point 121: BenignData point 92: BenignData point 102: Benign
#
# Data point 103: Benign
#
# Data point 221: BenignData point 122: BenignData point 93: Benign
#
# Data point 104: BenignData point 222: Benign
#
#
# Data point 123: Benign
# Data point 94: BenignData point 105: Benign
# Data point 223: Benign
#
# Data point 106: BenignData point 95: BenignData point 124: Benign
#
#
#
# Data point 107: Benign
# Data point 125: BenignData point 224: BenignData point 96: BenignData point 108: Benign
#
#
# Data point 97: BenignData point 126: Benign
#
# Data point 109: Benign
# Data point 225: BenignData point 98: Benign
# Data point 127: Benign
#
#
# Data point 128: BenignData point 110: BenignData point 226: Benign
#
# Data point 99: BenignData point 227: Benign
#
# Data point 111: Benign
# Data point 228: Benign
# Data point 129: BenignData point 100: Benign
#
#
# Data point 229: BenignData point 101: BenignData point 130: Benign
#
# Data point 112: Benign
# Data point 230: BenignData point 131: BenignData point 102: Benign
#
# Data point 231: BenignData point 113: Benign
#
#
# Data point 114: Benign
# Data point 132: BenignData point 103: BenignData point 232: Benign
#
#
#
# Data point 115: BenignData point 133: Benign
# Data point 104: Benign
# Data point 233: Benign
# Data point 134: Benign
# Data point 116: BenignData point 105: Benign
# Data point 234: Benign
# Data point 135: Benign
# Data point 106: Benign
#
#
# Data point 136: BenignData point 117: BenignData point 107: Benign
#
# Data point 235: Benign
#
# Data point 137: BenignData point 118: BenignData point 108: Benign
# Data point 236: Benign
#
# Data point 138: Benign
# Data point 119: BenignData point 109: BenignData point 237: Benign
#
#
#
# Data point 120: Benign
# Data point 121: BenignData point 110: BenignData point 139: Benign
# Data point 238: Benign
# Data point 111: Benign
#
# Data point 122: Benign
# Data point 112: BenignData point 239: Benign
# Data point 140: BenignData point 113: Benign
#
#
# Data point 114: Benign
#
# Data point 115: BenignData point 123: Benign
# Data point 141: BenignData point 240: BenignData point 116: Benign
#
#
#
# Data point 124: BenignData point 142: BenignData point 117: Benign
#
# Data point 241: Benign
#
# Data point 242: BenignData point 125: BenignData point 143: Benign
#
# Data point 243: BenignData point 118: BenignData point 126: Benign
#
#
# Data point 144: Benign
# Data point 244: Benign
# Data point 127: BenignData point 119: BenignData point 145: Benign
#
#
# Data point 128: Benign
# Data point 120: BenignData point 245: BenignData point 146: Benign
#
#
# Data point 121: BenignData point 129: BenignData point 246: Benign
# Data point 147: Benign
#
#
# Data point 122: BenignData point 130: Benign
# Data point 247: Benign
#
# Data point 148: Benign
# Data point 131: BenignData point 123: Benign
# Data point 149: Benign
#
# Data point 150: BenignData point 248: Benign
# Data point 132: Benign
# Data point 124: Benign
#
# Data point 151: Benign
# Data point 249: BenignData point 133: BenignData point 125: Benign
#
#
# Data point 152: Benign
# Data point 134: BenignData point 250: Benign
#
# Data point 126: BenignData point 251: Benign
# Data point 153: Benign
# Data point 252: Benign
# Data point 135: Benign
#
# Data point 253: BenignData point 127: Benign
# Data point 154: Benign
#
# Data point 136: BenignData point 254: Benign
#
# Data point 255: BenignData point 128: Benign
# Data point 155: Benign
#
# Data point 137: BenignData point 256: Benign
# Data point 129: Benign
#
#
# Data point 138: BenignData point 156: BenignData point 130: Benign
# Data point 257: Benign
# Data point 139: Benign
#
# Data point 157: Benign
# Data point 258: Benign
# Data point 131: BenignData point 158: Benign
#
# Data point 140: Benign
#
# Data point 259: BenignData point 141: BenignData point 159: Benign
#
# Data point 132: Benign
# Data point 260: Benign
# Data point 142: BenignData point 160: Benign
#
#
# Data point 133: BenignData point 261: Benign
# Data point 143: BenignData point 161: Benign
#
# Data point 134: Benign
# Data point 262: Benign
#
# Data point 144: BenignData point 162: BenignData point 263: Benign
# Data point 135: Benign
# Data point 145: Benign
# Data point 163: Benign
#
# Data point 264: Benign
# Data point 136: BenignData point 146: Benign
# Data point 164: Benign
#
# Data point 265: Benign
# Data point 137: BenignData point 147: Benign
# Data point 165: Benign
#
# Data point 166: Benign
# Data point 266: Benign
# Data point 138: BenignData point 148: Benign
#
# Data point 267: Benign
# Data point 149: BenignData point 139: Benign
# Data point 167: Benign
#
#
# Data point 150: BenignData point 140: BenignData point 268: Benign
# Data point 168: Benign
# Data point 151: Benign
# Data point 141: Benign
# Data point 269: Benign
#
#
# Data point 169: BenignData point 152: Benign
# Data point 142: BenignData point 270: Benign
#
# Data point 170: Benign
# Data point 153: Benign
# Data point 143: Benign
# Data point 271: Benign
#
# Data point 171: BenignData point 154: BenignData point 144: Benign
# Data point 272: Benign
#
# Data point 172: Benign
# Data point 155: BenignData point 145: Benign
# Data point 273: Benign
# Data point 173: Benign
#
# Data point 156: BenignData point 146: Benign
# Data point 274: Benign
#
# Data point 157: BenignData point 174: Benign
# Data point 275: BenignData point 147: Benign
#
#
# Data point 276: BenignData point 148: Benign
#
# Data point 175: Benign
# Data point 277: BenignData point 158: BenignData point 149: Benign
#
#
# Data point 176: Benign
#
# Data point 159: BenignData point 150: Benign
# Data point 278: Benign
# Data point 160: Benign
# Data point 177: BenignData point 279: Benign
# Data point 151: Benign
#
# Data point 161: Benign
# Data point 152: BenignData point 178: Benign
# Data point 280: Benign
#
# Data point 162: BenignData point 179: Benign
# Data point 153: Benign
#
#
# Data point 163: BenignData point 281: Benign
# Data point 180: BenignData point 154: Benign
# Data point 282: Benign
#
# Data point 164: BenignData point 155: Benign
#
# Data point 181: BenignData point 165: Benign
# Data point 283: Benign
#
# Data point 156: Benign
# Data point 182: BenignData point 166: Benign
# Data point 284: Benign
# Data point 157: Benign
#
# Data point 167: BenignData point 183: Benign
# Data point 285: Benign
# Data point 158: Benign
# Data point 168: Benign
#
# Data point 184: Benign
# Data point 286: Benign
# Data point 159: BenignData point 169: Benign
#
# Data point 185: BenignData point 287: Benign
#
# Data point 170: Benign
# Data point 186: Benign
# Data point 160: Benign
# Data point 288: BenignData point 171: Benign
#
# Data point 187: Benign
# Data point 161: BenignData point 172: Benign
# Data point 289: Benign
# Data point 162: Benign
#
#
# Data point 188: BenignData point 290: BenignData point 173: BenignData point 163: Benign
#
#
# Data point 174: Benign
# Data point 291: BenignData point 189: BenignData point 164: Benign
#
#
# Data point 292: Benign
# Data point 190: BenignData point 175: BenignData point 165: Benign
#
#
# Data point 293: Benign
# Data point 191: Benign
# Data point 176: BenignData point 166: BenignData point 294: Benign
#
#
# Data point 167: BenignData point 177: BenignData point 192: Benign
#
#
#
# Data point 295: Benign
# Data point 168: BenignData point 178: BenignData point 193: Benign
#
# Data point 296: Benign
# Data point 194: BenignData point 169: Benign
# Data point 179: Benign
#
# Data point 297: Benign
# Data point 195: BenignData point 170: Benign
# Data point 180: Benign
# Data point 298: Benign
#
# Data point 196: BenignData point 171: Benign
# Data point 181: Attack
#
#
# Data point 299: Benign
# Data point 197: BenignData point 182: AttackData point 172: Benign
#
# Data point 300: BenignData point 173: Benign
#
# Data point 198: Benign
#
# Data point 301: BenignData point 183: AttackData point 174: Benign
#
#
# Data point 199: Benign
# Data point 302: BenignData point 200: BenignData point 184: AttackData point 175: Benign
#
#
# Data point 185: AttackData point 201: Benign
#
# Data point 303: BenignData point 176: Attack
# Data point 186: Attack
#
# Data point 304: BenignData point 177: Attack
# Data point 202: Benign
#
# Data point 178: Attack
# Data point 305: BenignData point 187: AttackData point 203: Benign
#
#
#
# Data point 204: BenignData point 179: AttackData point 306: BenignData point 188: Attack
# Data point 205: Benign
#
#
#
# Data point 307: BenignData point 189: AttackData point 206: BenignData point 180: Attack
#
#
# Data point 207: Benign
# Data point 181: Attack
# Data point 190: AttackData point 308: Benign
# Data point 191: BenignData point 208: Benign
#
# Data point 182: Attack
#
# Data point 209: BenignData point 192: BenignData point 309: Benign
#
#
#
# Data point 210: BenignData point 193: BenignData point 310: BenignData point 183: Attack
#
#
#
# Data point 211: BenignData point 194: BenignData point 311: Benign
# Data point 184: Attack
#
# Data point 212: BenignData point 312: BenignData point 195: Benign
#
#
#
# Data point 185: AttackData point 196: BenignData point 213: BenignData point 313: Benign
#
#
# Data point 197: BenignData point 314: Benign
#
# Data point 186: Benign
# ...
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 786: Benign
#
# Data point 893: Benign
# Data point 787: Benign
# Data point 833: Benign
# Data point 811: Benign
# Data point 788: BenignData point 894: Benign
# Data point 789: Benign
#
# Data point 834: BenignData point 790: BenignData point 812: Benign
#
# Data point 895: Benign
#
# Data point 813: Benign
# Data point 791: BenignData point 835: BenignData point 814: Benign
# Data point 896: Benign
#
# Data point 815: Benign
#
#
# Data point 792: BenignData point 816: BenignData point 897: BenignData point 836: Benign
#
#
#
# Data point 898: BenignData point 793: BenignData point 817: Benign
# Data point 837: BenignData point 899: Benign
#
#
#
# Data point 900: BenignData point 818: BenignData point 794: BenignData point 838: Benign
#
# Data point 901: Benign
#
#
# Data point 819: BenignData point 795: BenignData point 839: BenignData point 902: Benign
#
#
# Data point 820: Benign
# Data point 903: Benign
# Data point 796: BenignData point 821: BenignData point 840: Benign
#
# Data point 904: Benign
# Data point 822: Benign
# Data point 841: Benign
#
# Data point 797: Benign
# Data point 905: Benign
# Data point 823: Benign
# Data point 798: BenignData point 906: Benign
#
# Data point 842: BenignData point 799: BenignData point 824: Benign
#
#
# Data point 800: BenignData point 825: Benign
#
# Data point 801: Benign
# Data point 802: Benign
# Data point 843: BenignData point 907: Benign
# Data point 826: BenignData point 803: Benign
#
# Data point 827: BenignData point 804: Benign
#
#
#
# Data point 828: Benign
# Data point 829: BenignData point 844: BenignData point 805: BenignData point 908: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
#
#
#
# Data point 809: BenignData point 830: Benign
# Data point 810: Benign
# Data point 811: BenignData point 845: BenignData point 909: Benign
# Data point 812: Benign
#
#
#
# Data point 831: BenignData point 813: Benign
# Data point 814: Benign
# Data point 815: BenignData point 846: BenignData point 910: Benign
#
# Data point 816: Benign
# Data point 847: Benign
#
#
# Data point 911: BenignData point 848: BenignData point 817: BenignData point 832: Benign
# Data point 849: Benign
#
# Data point 833: BenignData point 850: Benign
#
#
# Data point 818: BenignData point 851: Benign
# Data point 912: Benign
# Data point 819: Benign
# Data point 834: Benign
# Data point 913: Benign
#
#
# Data point 914: Benign
# Data point 852: BenignData point 915: Benign
# Data point 820: BenignData point 835: Benign
# Data point 916: Benign
#
# Data point 853: Benign
#
# Data point 836: BenignData point 821: BenignData point 854: BenignData point 917: Benign
#
#
# Data point 855: Benign
# Data point 822: Benign
# Data point 856: BenignData point 837: BenignData point 918: Benign
#
# Data point 857: Benign
# Data point 858: Benign
# Data point 823: Benign
# Data point 838: Benign
#
# Data point 839: Benign
# Data point 840: BenignData point 919: Benign
# Data point 841: BenignData point 824: Benign
# Data point 842: Benign
#
#
#
# Data point 843: BenignData point 825: BenignData point 920: BenignData point 859: Benign
#
#
#
# Data point 844: BenignData point 860: BenignData point 826: Benign
# Data point 845: BenignData point 921: Benign
#
#
# Data point 827: BenignData point 861: Benign
# Data point 846: Benign
#
# Data point 922: Benign
# Data point 828: BenignData point 862: Benign
#
# Data point 847: BenignData point 863: Benign
# Data point 923: Benign
#
# Data point 829: BenignData point 864: Benign
#
# Data point 848: Benign
# Data point 865: BenignData point 924: Benign
#
# Data point 830: Benign
# Data point 849: BenignData point 925: Benign
#
#
# Data point 866: BenignData point 831: BenignData point 926: BenignData point 850: Benign
#
# Data point 832: Benign
#
#
# Data point 833: BenignData point 867: BenignData point 851: BenignData point 927: Benign
#
#
# Data point 868: Benign
# Data point 869: Benign
# Data point 834: Benign
# Data point 852: Benign
#
# Data point 928: BenignData point 853: BenignData point 870: Benign
#
# Data point 871: Benign
# Data point 872: Benign
# Data point 929: Benign
# Data point 835: BenignData point 873: Benign
# Data point 854: Benign
#
# Data point 874: BenignData point 836: Benign
# Data point 930: Benign
#
#
# Data point 875: BenignData point 837: BenignData point 931: BenignData point 855: Benign
#
#
# Data point 876: Benign
# Data point 932: Benign
# Data point 838: BenignData point 877: BenignData point 856: Benign
#
# Data point 878: Benign
#
# Data point 839: Benign
# Data point 879: Benign
# Data point 933: Benign
#
# Data point 857: BenignData point 840: BenignData point 934: Benign
# Data point 880: Benign
#
# Data point 858: Benign
# Data point 841: BenignData point 935: Benign
# Data point 881: Benign
#
# Data point 859: Benign
# Data point 936: BenignData point 842: Benign
# Data point 882: BenignData point 860: Benign
#
#
#
# Data point 937: BenignData point 843: BenignData point 883: BenignData point 861: Benign
#
#
#
# Data point 938: BenignData point 844: BenignData point 884: BenignData point 862: Benign
#
#
#
# Data point 939: BenignData point 885: BenignData point 845: BenignData point 863: Benign
#
#
#
# Data point 940: Benign
# Data point 846: BenignData point 886: BenignData point 864: Benign
#
# Data point 941: Benign
# Data point 847: BenignData point 887: BenignData point 865: Benign
#
#
# Data point 942: Benign
# Data point 848: BenignData point 888: Benign
# Data point 866: Benign
#
# Data point 943: Benign
# Data point 849: BenignData point 867: BenignData point 889: Benign
#
#
# Data point 944: Benign
# Data point 850: BenignData point 890: Benign
#
#
# Data point 868: BenignData point 945: Benign
# Data point 851: BenignData point 891: Benign
#
#
# Data point 946: BenignData point 869: BenignData point 852: BenignData point 892: Benign
#
# Data point 947: Benign
#
# Data point 870: Benign
# Data point 893: BenignData point 853: Benign
#
#
# Data point 948: BenignData point 871: BenignData point 854: BenignData point 894: Benign
#
# Data point 949: Benign
# Data point 950: Benign
#
# Data point 951: Benign
# Data point 872: BenignData point 855: Benign
#
# Data point 895: BenignData point 873: BenignData point 952: Benign
#
#
# Data point 856: Benign
# Data point 896: BenignData point 953: Benign
# Data point 874: Benign
# Data point 857: Benign
# Data point 897: Benign
# Data point 954: Benign
# Data point 955: Benign
#
# Data point 875: BenignData point 898: Benign
#
# Data point 858: Benign
# Data point 956: BenignData point 899: Benign
#
#
# Data point 900: Benign
# Data point 876: BenignData point 859: BenignData point 901: Benign
# Data point 957: Benign
# Data point 877: Benign
# Data point 902: Benign
#
# Data point 878: Benign
# Data point 958: Benign
# Data point 860: BenignData point 903: Benign
# Data point 879: Benign
#
#
# Data point 959: BenignData point 861: BenignData point 904: Benign
#
#
# Data point 905: BenignData point 862: BenignData point 880: Benign
# Data point 960: Benign
# Data point 881: Benign
# Data point 863: Benign
# Data point 961: Benign
#
# Data point 906: BenignData point 882: Benign
#
# Data point 962: Benign
# Data point 864: BenignData point 907: BenignData point 883: Benign
#
# Data point 963: BenignData point 865: Benign
#
#
# Data point 908: BenignData point 884: BenignData point 964: Benign
#
#
# Data point 909: BenignData point 885: BenignData point 866: Benign
#
#
#
# Data point 965: BenignData point 867: Benign
# Data point 886: Benign
# Data point 887: BenignData point 910: Benign
#
#
# Data point 966: BenignData point 888: BenignData point 911: Benign
# Data point 868: Benign
#
# Data point 967: Benign
# Data point 889: BenignData point 912: Benign
#
# Data point 869: BenignData point 890: Benign
# Data point 968: Benign
#
# Data point 913: BenignData point 891: BenignData point 870: Benign
#
#
#
# Data point 969: BenignData point 914: BenignData point 871: BenignData point 892: Benign
#
# Data point 915: Benign
#
# Data point 970: Benign
# Data point 916: Benign
# Data point 872: BenignData point 893: Benign
#
# Data point 971: Benign
# Data point 873: BenignData point 917: Benign
# Data point 894: Benign
#
# Data point 972: Benign
# Data point 918: BenignData point 874: Benign
# Data point 919: Benign
#
#
# Data point 920: BenignData point 895: Benign
# Data point 973: BenignData point 875: Benign
# Data point 896: Benign
#
# Data point 921: Benign
# Data point 974: BenignData point 876: Benign
#
#
# Data point 897: BenignData point 922: BenignData point 975: BenignData point 877: Benign
# Data point 898: Benign
#
#
# Data point 923: Benign
# Data point 924: Benign
# Data point 878: BenignData point 976: Attack
# Data point 899: BenignData point 925: Benign
#
# Data point 926: Benign
# Data point 927: Benign
# Data point 879: Benign
# Data point 977: Attack
# Data point 900: Benign
#
# Data point 928: Benign
# Data point 978: AttackData point 880: Benign
# Data point 901: Benign
#
# Data point 929: Benign
# Data point 881: BenignData point 979: Attack
# Data point 930: BenignData point 902: Benign
#
#
# Data point 980: AttackData point 882: Benign
#
# Data point 903: Benign
# Data point 931: Benign
# Data point 883: BenignData point 981: Benign
# Data point 884: Benign
# Data point 904: Benign
# Data point 982: Benign
#
# Data point 932: BenignData point 885: Benign
# Data point 886: Benign
#
# Data point 887: BenignData point 905: BenignData point 983: Benign
#
#
#
# Data point 933: BenignData point 906: BenignData point 984: BenignData point 888: Benign
#
#
#
# Data point 934: BenignData point 907: BenignData point 985: BenignData point 889: Benign
#
#
#
# Data point 935: BenignData point 986: BenignData point 908: Benign
# Data point 909: Benign
# Data point 890: BenignData point 936: Benign
#
#
#
# Data point 910: BenignData point 891: BenignData point 987: Benign
#
# Data point 911: Benign
#
# Data point 892: BenignData point 937: BenignData point 988: Benign
# Data point 912: Benign
# Data point 893: Benign
# Data point 938: Benign
#
# Data point 989: Benign
#
# Data point 990: BenignData point 913: Benign
#
# Data point 895: Benign
# Data point 894: BenignData point 939: Benign
#
# Data point 896: Benign
# Data point 991: BenignData point 897: BenignData point 940: BenignData point 914: Benign
# Data point 898: Benign
#
# Data point 899: Benign
#
# Data point 992: BenignData point 915: Benign
# Data point 941: Benign
#
# Data point 916: BenignData point 900: Benign
# Data point 942: Benign
#
# Data point 993: BenignData point 901: BenignData point 917: Benign
#
#
# Data point 994: Benign
# Data point 943: Benign
# Data point 918: BenignData point 995: BenignData point 902: Benign
#
#
# Data point 944: Benign
# Data point 919: Benign
# Data point 903: Benign
# Data point 996: Benign
# Data point 945: Benign
# Data point 920: BenignData point 904: Benign
# Data point 997: Benign
#
# Data point 946: Benign
# Data point 905: BenignData point 921: Benign
# Data point 998: Benign
# Data point 906: Benign
#
# Data point 947: Benign
# Data point 999: Benign
# Data point 1000: BenignData point 907: Benign
# Data point 922: Benign
#
# Data point 948: Benign
#
# Latency for this chunk: 23.0435 seconds
#
# Total processing time: 24.1536 seconds
# Data point 908: BenignData point 923: Benign
#
# Data point 909: BenignData point 949: BenignData point 924: Benign
#
# Data point 910: Benign
# Average latency per chunk: 23.0435 secondsData point 925: Benign
# Data point 950: Benign
#
# Data point 911: Benign
# Data point 951: Benign
# Data point 926: Benign
#
# Data point 952: BenignData point 913: Benign
# Data point 953: Benign
# Data point 915: Benign
# Data point 928: BenignData point 954: Benign
#
# Data point 955: Benign
# Data point 956: Benign
#
#
# Data point 957: Benign
#
#
#
# Data point 959: BenignData point 961: BenignData point 930: Benign
#
#
# Data point 918: BenignData point 960: BenignData point 958: BenignData point 931: Benign
#
# Data point 932: BenignData point 963: BenignData point 919: Benign
# Data point 962: BenignData point 917: Benign
# Data point 964: BenignData point 966: BenignData point 967: BenignData point 933: Benign
#
#
# Data point 968: Benign
# Data point 920: Benign
# Data point 921: BenignData point 969: Benign
# Data point 935: Benign
#
#
#
#
# Data point 934: BenignData point 965: BenignData point 936: Benign
#
# Data point 929: BenignData point 922: Benign
# Data point 970: Benign
# Data point 916: Benign
# Data point 914: BenignData point 927: Benign
# Data point 971: Benign
#
# Data point 937: BenignData point 912: Benign
#
# Data point 938: Benign
# Data point 923: BenignData point 972: Benign
#
#
# Data point 939: BenignData point 924: Benign
# Data point 973: Benign
# Data point 940: Benign
# Data point 925: Benign
# Data point 974: Benign
# Data point 941: Benign
# Data point 926: BenignData point 975: Benign
#
# Data point 942: Benign
# Data point 927: BenignData point 976: Benign
#
#
# Data point 943: BenignData point 928: BenignData point 977: Benign
#
#
# Data point 944: BenignData point 929: BenignData point 978: Benign
#
#
# Data point 945: BenignData point 979: BenignData point 930: Benign
#
#
# Data point 946: Benign
# Data point 980: BenignData point 931: Benign
#
# Data point 947: BenignData point 932: BenignData point 981: Benign
#
#
# Data point 933: BenignData point 948: BenignData point 982: Benign
#
#
# Data point 949: BenignData point 983: BenignData point 934: Benign
#
# Data point 984: Benign
#
# Data point 985: Benign
# Data point 986: BenignData point 935: Benign
# Data point 936: Benign
# Data point 987: Benign
# Data point 950: Benign
# Data point 937: Benign
# Data point 951: BenignData point 988: Benign
#
# Data point 952: Benign
# Data point 938: BenignData point 989: Benign
#
#
# Data point 939: BenignData point 953: Benign
# Data point 990: Benign
# Data point 940: Benign
#
# Data point 991: BenignData point 954: Benign
# Data point 992: Benign
# Data point 993: BenignData point 941: Benign
#
#
# Data point 955: BenignData point 942: BenignData point 994: Benign
#
#
# Data point 956: BenignData point 995: Benign
# Data point 943: Benign
# Data point 957: Benign
# Data point 944: Benign
#
# Data point 958: Benign
#
# Data point 996: BenignData point 997: BenignData point 945: BenignData point 959: Benign
#
#
# Data point 946: BenignData point 998: Benign
# Data point 999: Benign
# Data point 960: BenignData point 947: BenignData point 1000: Benign
# Data point 961: Benign
#
# Latency for this chunk: 22.4197 seconds
#
# Data point 949: Benign
#
# Total processing time: 23.5334 secondsData point 950: Benign
#
#
# Data point 948: Benign
# Data point 962: BenignData point 963: Benign
# Average latency per chunk: 22.4197 secondsData point 951: Benign
#
#
# Data point 964: Benign
# Data point 952: Benign
#
# Data point 965: BenignData point 953: BenignData point 966: Benign
#
# Data point 967: BenignData point 954: Benign
#
# Data point 955: BenignData point 968: Benign
# Data point 956: Benign
# Data point 969: Benign
#
# Data point 957: BenignData point 970: Benign
#
# Data point 958: BenignData point 971: Benign
#
# Data point 972: BenignData point 959: Benign
#
# Data point 960: BenignData point 973: Benign
#
# Data point 961: BenignData point 974: Benign
#
# Data point 962: Benign
# Data point 975: Benign
# Data point 976: Benign
# Data point 963: BenignData point 977: Benign
# Data point 964: Benign
# Data point 978: Benign
#
# Data point 979: Benign
# Data point 965: BenignData point 980: Benign
#
# Data point 981: Benign
# Data point 966: BenignData point 982: Benign
#
# Data point 967: BenignData point 983: Benign
# Data point 968: Benign
# Data point 984: Benign
# Data point 969: Benign
#
# Data point 970: BenignData point 985: Benign
#
# Data point 971: Attack
# Data point 986: BenignData point 972: Attack
#
# Latency for this chunk: 22.6212 seconds
# Data point 973: Attack
# Total processing time: 23.7012 seconds
#
# Data point 974: AttackAverage latency per chunk: 22.6212 seconds
#
# Data point 975: Attack
# Data point 976: Benign
# Data point 977: Benign
# Data point 978: BenignData point 979: Benign
#
# Data point 980: Benign
# Data point 981: Benign
# Data point 982: Benign
# Data point 983: Benign
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: BenignData point 998: Benign
#
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 22.7124 seconds
#
# Total processing time: 23.8090 seconds
# Average latency per chunk: 22.7124 seconds
# Total processing time with parallelization: 147.4239 seconds

# %%
# Multi-Classification - Fog simulation

# %%
# Load the scaler and PCA
import joblib
scaler = joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/multi_class_models/scaler_multi.pkl')
pca = joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/multi_class_models/pca_multi.pkl')
model=joblib.load('/content/drive/MyDrive/Labelled_Multiclass_Dataset/multi_class_models/decision_tree_multi.pkl')

# %%
import pickle

# Assuming scaler, pca, and model are already defined objects
try:
    # Test serialization for scaler
    pickle.dumps(scaler)
    print("Scaler object is pickleable.")
except Exception as e:
    print(f"Scaler object is not pickleable: {e}")

try:
    # Test serialization for PCA
    pickle.dumps(pca)
    print("PCA object is pickleable.")
except Exception as e:
    print(f"PCA object is not pickleable: {e}")

try:
    # Test serialization for Decision model
    pickle.dumps(model)
    print("Decision tree model is pickleable.")
except Exception as e:
    print(f"Decision Tree model is not pickleable: {e}")
# Out:
# Scaler object is pickleable.
# PCA object is pickleable.
# RandomForest model is pickleable.

# %% [markdown]
# # MultiClass

# %% [markdown]
# ## sequential processing of all data points in real time for Multi classification

# %%
# sequential processing of all data points in real time for Multi classification

import time
# Real-time simulation function with latency and overall processing time
def sim_time_based_window(file_path, chunk_size=1000, delay=1):
    latencies = []  # List to store latencies for each chunk
    total_start_time = time.time()  # Start time of the entire process

    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        print("\nProcessing new data chunk...")

        # Start tracking the time for processing this chunk
        start_time_latency = time.time()

        print(chunk.columns)

        # Drop the same non-feature columns from the chunk
        X_chunk = chunk.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
        y_true = chunk['Label']  # Assuming 'Label' is the target variable


        # Check for NaN values and fill with column means if necessary
        if X_chunk.isna().any().any():
            print("Chunk contains NaN values. Filling with column means.")
            X_chunk = X_chunk.fillna(X_chunk.mean())

        # Scale and apply PCA to the new chunk
        X_scaled_chunk = scaler.transform(X_chunk)  # Scale the chunk
        X_pca_chunk = pca.transform(X_scaled_chunk)  # Apply PCA to the scaled chunk

        # Predict using the trained model
        predictions = model.predict(X_pca_chunk)

        # Simulate the results with multi-class labels
        for i, pred in enumerate(predictions):
            print(f"Data point {i+1}: {pred}")

        # End tracking the time after classification for this chunk
        end_time_latency = time.time()

        # Calculate latency for this chunk
        chunk_latency = end_time_latency - start_time_latency
        latencies.append(chunk_latency)
        print(f"Latency for this chunk: {chunk_latency:.4f} seconds")

        # Simulate delay for real-time processing
        time.sleep(delay)  # You can adjust/remove delay for actual real-time performance

    # Calculate total processing time
    total_end_time = time.time()
    total_processing_time = total_end_time - total_start_time

    # Calculate average latency
    average_latency = sum(latencies) / len(latencies) if latencies else 0

    print(f"\nTotal processing time: {total_processing_time:.4f} seconds")
    print(f"Average latency per chunk: {average_latency:.4f} seconds")

# Run the simulation
sim_time_based_window('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv', chunk_size=1000, delay=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Data point 100: Benign
# Data point 101: Benign
# Data point 102: Benign
# Data point 103: Benign
# Data point 104: Benign
# Data point 105: Benign
# Data point 106: Benign
# Data point 107: Benign
# Data point 108: Benign
# Data point 109: Benign
# Data point 110: Benign
# Data point 111: Benign
# Data point 112: Benign
# Data point 113: Benign
# Data point 114: Benign
# Data point 115: Benign
# Data point 116: Benign
# Data point 117: Benign
# Data point 118: Benign
# Data point 119: Benign
# Data point 120: Benign
# Data point 121: Benign
# Data point 122: Benign
# Data point 123: Benign
# Data point 124: Benign
# Data point 125: Benign
# Data point 126: Benign
# Data point 127: Benign
# Data point 128: Benign
# Data point 129: Benign
# Data point 130: Benign
# Data point 131: Benign
# Data point 132: Benign
# Data point 133: Benign
# Data point 134: Benign
# Data point 135: Benign
# Data point 136: Benign
# Data point 137: Benign
# Data point 138: Benign
# Data point 139: Benign
# Data point 140: Benign
# Data point 141: Benign
# Data point 142: Benign
# Data point 143: Benign
# Data point 144: Benign
# Data point 145: Benign
# Data point 146: Benign
# Data point 147: Benign
# Data point 148: Benign
# Data point 149: Benign
# Data point 150: Benign
# Data point 151: Benign
# Data point 152: Benign
# Data point 153: Benign
# Data point 154: Benign
# Data point 155: Benign
# Data point 156: Benign
# Data point 157: Benign
# Data point 158: Benign
# Data point 159: Benign
# Data point 160: Benign
# Data point 161: Benign
# Data point 162: Benign
# Data point 163: Benign
# Data point 164: Benign
# Data point 165: Benign
# Data point 166: Benign
# Data point 167: Benign
# Data point 168: Benign
# Data point 169: Benign
# Data point 170: Benign
# Data point 171: Benign
# Data point 172: Benign
# Data point 173: Benign
# Data point 174: Benign
# Data point 175: Benign
# Data point 176: Benign
# Data point 177: Benign
# Data point 178: Benign
# Data point 179: Benign
# Data point 180: Benign
# Data point 181: Benign
# Data point 182: Benign
# Data point 183: Benign
# Data point 184: Benign
# Data point 185: Benign
# Data point 186: Benign
# Data point 187: Benign
# Data point 188: Benign
# Data point 189: Benign
# Data point 190: Benign
# Data point 191: Benign
# Data point 192: Benign
# Data point 193: Benign
# Data point 194: Benign
# Data point 195: Benign
# Data point 196: Benign
# Data point 197: Benign
# Data point 198: Benign
# Data point 199: Benign
# Data point 200: Benign
# Data point 201: Benign
# Data point 202: Benign
# Data point 203: Benign
# Data point 204: Benign
# Data point 205: Benign
# Data point 206: Benign
# Data point 207: Benign
# Data point 208: Benign
# Data point 209: Benign
# Data point 210: Benign
# Data point 211: Benign
# Data point 212: Benign
# Data point 213: Benign
# Data point 214: Benign
# Data point 215: Benign
# Data point 216: Benign
# Data point 217: Benign
# Data point 218: Benign
# Data point 219: Benign
# Data point 220: Benign
# Data point 221: Benign
# Data point 222: Benign
# Data point 223: Benign
# Data point 224: Benign
# Data point 225: Benign
# Data point 226: Benign
# Data point 227: Benign
# Data point 228: Benign
# Data point 229: Benign
# Data point 230: Benign
# Data point 231: Benign
# Data point 232: Benign
# Data point 233: Benign
# Data point 234: Benign
# Data point 235: Benign
# Data point 236: Benign
# Data point 237: Benign
# Data point 238: Benign
# Data point 239: Benign
# Data point 240: Benign
# Data point 241: Benign
# Data point 242: Benign
# Data point 243: Benign
# Data point 244: Benign
# Data point 245: Benign
# Data point 246: Benign
# Data point 247: Benign
# Data point 248: Benign
# Data point 249: Benign
# Data point 250: Benign
# Data point 251: Benign
# Data point 252: Benign
# Data point 253: Benign
# Data point 254: Benign
# Data point 255: Benign
# Data point 256: Benign
# Data point 257: Benign
# Data point 258: Benign
# Data point 259: Benign
# Data point 260: Benign
# Data point 261: Benign
# Data point 262: Benign
# Data point 263: Benign
# Data point 264: Benign
# Data point 265: Benign
# Data point 266: Benign
# Data point 267: Benign
# Data point 268: Benign
# Data point 269: Benign
# Data point 270: Benign
# Data point 271: Benign
# Data point 272: Benign
# Data point 273: Benign
# Data point 274: Benign
# Data point 275: Benign
# Data point 276: Benign
# Data point 277: Benign
# Data point 278: Benign
# Data point 279: Benign
# Data point 280: Benign
# Data point 281: Benign
# Data point 282: Benign
# Data point 283: Benign
# Data point 284: Benign
# Data point 285: Benign
# Data point 286: Benign
# Data point 287: Benign
# Data point 288: Benign
# Data point 289: Benign
# Data point 290: Benign
# Data point 291: Benign
# Data point 292: Benign
# Data point 293: Benign
# Data point 294: Benign
# Data point 295: Benign
# Data point 296: Benign
# Data point 297: Benign
# Data point 298: Benign
# Data point 299: Benign
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: Benign
# Data point 372: Benign
# Data point 373: Benign
# Data point 374: Benign
# Data point 375: Benign
# Data point 376: XMasAttack
# Data point 377: XMasAttack
# Data point 378: XMasAttack
# Data point 379: XMasAttack
# Data point 380: XMasAttack
# Data point 381: Benign
# Data point 382: Benign
# Data point 383: Benign
# Data point 384: Benign
# Data point 385: Benign
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: Benign
# Data point 572: Benign
# Data point 573: Benign
# Data point 574: Benign
# Data point 575: Benign
# Data point 576: Benign
# Data point 577: Benign
# Data point 578: Benign
# Data point 579: Benign
# Data point 580: Benign
# Data point 581: Benign
# Data point 582: Benign
# Data point 583: Benign
# Data point 584: Benign
# Data point 585: Benign
# Data point 586: Benign
# Data point 587: Benign
# Data point 588: Benign
# Data point 589: Benign
# Data point 590: Benign
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: TCPAttack
# Data point 762: TCPAttack
# Data point 763: TCPAttack
# Data point 764: TCPAttack
# Data point 765: TCPAttack
# Data point 766: TCPAttack
# Data point 767: TCPAttack
# Data point 768: TCPAttack
# Data point 769: TCPAttack
# Data point 770: TCPAttack
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: Benign
# Data point 777: Benign
# Data point 778: Benign
# Data point 779: Benign
# Data point 780: Benign
# Data point 781: Benign
# Data point 782: Benign
# Data point 783: Benign
# Data point 784: Benign
# Data point 785: Benign
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: Benign
# Data point 977: Benign
# Data point 978: Benign
# Data point 979: Benign
# Data point 980: Benign
# Data point 981: Benign
# Data point 982: Benign
# Data point 983: Benign
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: Benign
# Data point 998: Benign
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 0.0658 seconds
#
# Processing new data chunk...
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 1: Benign
# Data point 2: Benign
# Data point 3: Benign
# Data point 4: Benign
# Data point 5: Benign
# Data point 6: Benign
# Data point 7: Benign
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
# Data point 27: Benign
# Data point 28: Benign
# Data point 29: Benign
# Data point 30: Benign
# Data point 31: Benign
# Data point 32: Benign
# Data point 33: Benign
# Data point 34: Benign
# Data point 35: Benign
# Data point 36: Benign
# Data point 37: Benign
# Data point 38: Benign
# Data point 39: Benign
# Data point 40: Benign
# Data point 41: Benign
# Data point 42: Benign
# Data point 43: Benign
# Data point 44: Benign
# Data point 45: Benign
# Data point 46: Benign
# Data point 47: Benign
# Data point 48: Benign
# Data point 49: Benign
# Data point 50: Benign
# Data point 51: Benign
# Data point 52: Benign
# Data point 53: Benign
# Data point 54: Benign
# Data point 55: Benign
# Data point 56: Benign
# Data point 57: Benign
# Data point 58: Benign
# Data point 59: Benign
# Data point 60: Benign
# Data point 61: Benign
# Data point 62: Benign
# Data point 63: Benign
# Data point 64: Benign
# Data point 65: Benign
# Data point 66: Benign
# Data point 67: Benign
# Data point 68: Benign
# Data point 69: Benign
# Data point 70: Benign
# Data point 71: Benign
# Data point 72: Benign
# Data point 73: Benign
# Data point 74: Benign
# Data point 75: Benign
# Data point 76: Benign
# Data point 77: Benign
# Data point 78: Benign
# Data point 79: Benign
# Data point 80: Benign
# Data point 81: Benign
# Data point 82: Benign
# Data point 83: Benign
# Data point 84: Benign
# Data point 85: Benign
# Data point 86: Benign
# Data point 87: Benign
# Data point 88: Benign
# Data point 89: Benign
# Data point 90: Benign
# Data point 91: Benign
# Data point 92: Benign
# Data point 93: Benign
# Data point 94: Benign
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Data point 100: Benign
# Data point 101: Benign
# Data point 102: Benign
# Data point 103: Benign
# Data point 104: Benign
# Data point 105: Benign
# Data point 106: Benign
# Data point 107: Benign
# Data point 108: Benign
# Data point 109: Benign
# Data point 110: Benign
# Data point 111: Benign
# Data point 112: Benign
# Data point 113: Benign
# Data point 114: Benign
# Data point 115: Benign
# Data point 116: Benign
# Data point 117: Benign
# Data point 118: Benign
# Data point 119: Benign
# Data point 120: Benign
# Data point 121: Benign
# Data point 122: Benign
# Data point 123: Benign
# Data point 124: Benign
# Data point 125: Benign
# Data point 126: Benign
# Data point 127: Benign
# Data point 128: Benign
# Data point 129: Benign
# Data point 130: Benign
# Data point 131: Benign
# Data point 132: Benign
# Data point 133: Benign
# Data point 134: Benign
# Data point 135: Benign
# Data point 136: Benign
# Data point 137: Benign
# Data point 138: Benign
# Data point 139: Benign
# Data point 140: Benign
# Data point 141: Benign
# Data point 142: Benign
# Data point 143: Benign
# Data point 144: Benign
# Data point 145: Benign
# Data point 146: Benign
# Data point 147: Benign
# Data point 148: Benign
# Data point 149: Benign
# Data point 150: Benign
# Data point 151: Benign
# Data point 152: Benign
# Data point 153: Benign
# Data point 154: Benign
# Data point 155: Benign
# Data point 156: Benign
# Data point 157: Benign
# Data point 158: Benign
# Data point 159: Benign
# Data point 160: Benign
# Data point 161: Benign
# Data point 162: Benign
# Data point 163: Benign
# Data point 164: Benign
# Data point 165: Benign
# Data point 166: Benign
# Data point 167: Benign
# Data point 168: Benign
# Data point 169: Benign
# Data point 170: Benign
# Data point 171: TCPAttack
# Data point 172: TCPAttack
# Data point 173: TCPAttack
# Data point 174: TCPAttack
# Data point 175: TCPAttack
# Data point 176: Benign
# Data point 177: Benign
# Data point 178: Benign
# Data point 179: Benign
# Data point 180: Benign
# Data point 181: Benign
# Data point 182: Benign
# Data point 183: Benign
# Data point 184: Benign
# Data point 185: Benign
# Data point 186: Benign
# Data point 187: Benign
# Data point 188: Benign
# Data point 189: Benign
# Data point 190: Benign
# Data point 191: Benign
# Data point 192: Benign
# Data point 193: Benign
# Data point 194: Benign
# Data point 195: Benign
# Data point 196: Benign
# Data point 197: Benign
# Data point 198: Benign
# Data point 199: Benign
# Data point 200: Benign
# Data point 201: Benign
# Data point 202: Benign
# Data point 203: Benign
# Data point 204: Benign
# Data point 205: Benign
# Data point 206: Benign
# Data point 207: Benign
# Data point 208: Benign
# Data point 209: Benign
# Data point 210: Benign
# Data point 211: Benign
# Data point 212: Benign
# Data point 213: Benign
# Data point 214: Benign
# Data point 215: Benign
# Data point 216: Benign
# Data point 217: Benign
# Data point 218: Benign
# Data point 219: Benign
# Data point 220: Benign
# Data point 221: Benign
# Data point 222: Benign
# Data point 223: Benign
# Data point 224: Benign
# Data point 225: Benign
# Data point 226: Benign
# Data point 227: Benign
# Data point 228: Benign
# Data point 229: Benign
# Data point 230: Benign
# Data point 231: Benign
# Data point 232: Benign
# Data point 233: Benign
# Data point 234: Benign
# Data point 235: Benign
# Data point 236: Benign
# Data point 237: Benign
# Data point 238: Benign
# Data point 239: Benign
# Data point 240: Benign
# Data point 241: Benign
# Data point 242: Benign
# Data point 243: Benign
# Data point 244: Benign
# Data point 245: Benign
# Data point 246: Benign
# Data point 247: Benign
# Data point 248: Benign
# Data point 249: Benign
# Data point 250: Benign
# Data point 251: Benign
# Data point 252: Benign
# Data point 253: Benign
# Data point 254: Benign
# Data point 255: Benign
# Data point 256: Benign
# Data point 257: Benign
# Data point 258: Benign
# Data point 259: Benign
# Data point 260: Benign
# Data point 261: Benign
# Data point 262: Benign
# Data point 263: Benign
# Data point 264: Benign
# Data point 265: Benign
# Data point 266: Benign
# Data point 267: Benign
# Data point 268: Benign
# Data point 269: Benign
# Data point 270: Benign
# Data point 271: Benign
# Data point 272: Benign
# Data point 273: Benign
# Data point 274: Benign
# Data point 275: Benign
# Data point 276: Benign
# Data point 277: Benign
# Data point 278: Benign
# Data point 279: Benign
# Data point 280: Benign
# Data point 281: Benign
# Data point 282: Benign
# Data point 283: Benign
# Data point 284: Benign
# Data point 285: Benign
# Data point 286: Benign
# Data point 287: Benign
# Data point 288: Benign
# Data point 289: Benign
# Data point 290: Benign
# Data point 291: Benign
# Data point 292: Benign
# Data point 293: Benign
# Data point 294: Benign
# Data point 295: Benign
# Data point 296: Benign
# Data point 297: Benign
# Data point 298: Benign
# Data point 299: Benign
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: UDPAttack
# Data point 372: UDPAttack
# Data point 373: UDPAttack
# Data point 374: UDPAttack
# Data point 375: UDPAttack
# Data point 376: UDPAttack
# Data point 377: UDPAttack
# Data point 378: UDPAttack
# Data point 379: UDPAttack
# Data point 380: UDPAttack
# Data point 381: Benign
# Data point 382: Benign
# Data point 383: Benign
# Data point 384: Benign
# Data point 385: Benign
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: UDPAttack
# Data point 572: UDPAttack
# Data point 573: UDPAttack
# Data point 574: UDPAttack
# Data point 575: UDPAttack
# Data point 576: UDPAttack
# Data point 577: UDPAttack
# Data point 578: UDPAttack
# Data point 579: UDPAttack
# Data point 580: UDPAttack
# Data point 581: Benign
# Data point 582: Benign
# Data point 583: Benign
# Data point 584: Benign
# Data point 585: Benign
# Data point 586: Benign
# Data point 587: Benign
# Data point 588: Benign
# Data point 589: Benign
# Data point 590: Benign
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: Benign
# Data point 762: Benign
# Data point 763: Benign
# Data point 764: Benign
# Data point 765: Benign
# Data point 766: Benign
# Data point 767: Benign
# Data point 768: Benign
# Data point 769: Benign
# Data point 770: Benign
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: UDPAttack
# Data point 777: UDPAttack
# Data point 778: UDPAttack
# Data point 779: UDPAttack
# Data point 780: UDPAttack
# Data point 781: UDPAttack
# Data point 782: UDPAttack
# Data point 783: UDPAttack
# Data point 784: UDPAttack
# Data point 785: UDPAttack
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: HTTPAttack
# Data point 977: HTTPAttack
# Data point 978: HTTPAttack
# Data point 979: HTTPAttack
# Data point 980: HTTPAttack
# Data point 981: HTTPAttack
# Data point 982: HTTPAttack
# Data point 983: HTTPAttack
# Data point 984: HTTPAttack
# Data point 985: HTTPAttack
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: Benign
# Data point 998: Benign
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 0.0786 seconds
#
# Processing new data chunk...
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 1: Benign
# Data point 2: Benign
# Data point 3: Benign
# Data point 4: Benign
# Data point 5: Benign
# Data point 6: Benign
# Data point 7: Benign
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
# Data point 27: Benign
# Data point 28: Benign
# Data point 29: Benign
# Data point 30: Benign
# Data point 31: Benign
# Data point 32: Benign
# Data point 33: Benign
# ...
# Data point 300: Benign
# Data point 301: Benign
# Data point 302: Benign
# Data point 303: Benign
# Data point 304: Benign
# Data point 305: Benign
# Data point 306: Benign
# Data point 307: Benign
# Data point 308: Benign
# Data point 309: Benign
# Data point 310: Benign
# Data point 311: Benign
# Data point 312: Benign
# Data point 313: Benign
# Data point 314: Benign
# Data point 315: Benign
# Data point 316: Benign
# Data point 317: Benign
# Data point 318: Benign
# Data point 319: Benign
# Data point 320: Benign
# Data point 321: Benign
# Data point 322: Benign
# Data point 323: Benign
# Data point 324: Benign
# Data point 325: Benign
# Data point 326: Benign
# Data point 327: Benign
# Data point 328: Benign
# Data point 329: Benign
# Data point 330: Benign
# Data point 331: Benign
# Data point 332: Benign
# Data point 333: Benign
# Data point 334: Benign
# Data point 335: Benign
# Data point 336: Benign
# Data point 337: Benign
# Data point 338: Benign
# Data point 339: Benign
# Data point 340: Benign
# Data point 341: Benign
# Data point 342: Benign
# Data point 343: Benign
# Data point 344: Benign
# Data point 345: Benign
# Data point 346: Benign
# Data point 347: Benign
# Data point 348: Benign
# Data point 349: Benign
# Data point 350: Benign
# Data point 351: Benign
# Data point 352: Benign
# Data point 353: Benign
# Data point 354: Benign
# Data point 355: Benign
# Data point 356: Benign
# Data point 357: Benign
# Data point 358: Benign
# Data point 359: Benign
# Data point 360: Benign
# Data point 361: Benign
# Data point 362: Benign
# Data point 363: Benign
# Data point 364: Benign
# Data point 365: Benign
# Data point 366: Benign
# Data point 367: Benign
# Data point 368: Benign
# Data point 369: Benign
# Data point 370: Benign
# Data point 371: Benign
# Data point 372: Benign
# Data point 373: Benign
# Data point 374: Benign
# Data point 375: Benign
# Data point 376: Benign
# Data point 377: Benign
# Data point 378: Benign
# Data point 379: Benign
# Data point 380: Benign
# Data point 381: HTTPAttack
# Data point 382: HTTPAttack
# Data point 383: HTTPAttack
# Data point 384: HTTPAttack
# Data point 385: HTTPAttack
# Data point 386: Benign
# Data point 387: Benign
# Data point 388: Benign
# Data point 389: Benign
# Data point 390: Benign
# Data point 391: Benign
# Data point 392: Benign
# Data point 393: Benign
# Data point 394: Benign
# Data point 395: Benign
# Data point 396: Benign
# Data point 397: Benign
# Data point 398: Benign
# Data point 399: Benign
# Data point 400: Benign
# Data point 401: Benign
# Data point 402: Benign
# Data point 403: Benign
# Data point 404: Benign
# Data point 405: Benign
# Data point 406: Benign
# Data point 407: Benign
# Data point 408: Benign
# Data point 409: Benign
# Data point 410: Benign
# Data point 411: Benign
# Data point 412: Benign
# Data point 413: Benign
# Data point 414: Benign
# Data point 415: Benign
# Data point 416: Benign
# Data point 417: Benign
# Data point 418: Benign
# Data point 419: Benign
# Data point 420: Benign
# Data point 421: Benign
# Data point 422: Benign
# Data point 423: Benign
# Data point 424: Benign
# Data point 425: Benign
# Data point 426: Benign
# Data point 427: Benign
# Data point 428: Benign
# Data point 429: Benign
# Data point 430: Benign
# Data point 431: Benign
# Data point 432: Benign
# Data point 433: Benign
# Data point 434: Benign
# Data point 435: Benign
# Data point 436: Benign
# Data point 437: Benign
# Data point 438: Benign
# Data point 439: Benign
# Data point 440: Benign
# Data point 441: Benign
# Data point 442: Benign
# Data point 443: Benign
# Data point 444: Benign
# Data point 445: Benign
# Data point 446: Benign
# Data point 447: Benign
# Data point 448: Benign
# Data point 449: Benign
# Data point 450: Benign
# Data point 451: Benign
# Data point 452: Benign
# Data point 453: Benign
# Data point 454: Benign
# Data point 455: Benign
# Data point 456: Benign
# Data point 457: Benign
# Data point 458: Benign
# Data point 459: Benign
# Data point 460: Benign
# Data point 461: Benign
# Data point 462: Benign
# Data point 463: Benign
# Data point 464: Benign
# Data point 465: Benign
# Data point 466: Benign
# Data point 467: Benign
# Data point 468: Benign
# Data point 469: Benign
# Data point 470: Benign
# Data point 471: Benign
# Data point 472: Benign
# Data point 473: Benign
# Data point 474: Benign
# Data point 475: Benign
# Data point 476: Benign
# Data point 477: Benign
# Data point 478: Benign
# Data point 479: Benign
# Data point 480: Benign
# Data point 481: Benign
# Data point 482: Benign
# Data point 483: Benign
# Data point 484: Benign
# Data point 485: Benign
# Data point 486: Benign
# Data point 487: Benign
# Data point 488: Benign
# Data point 489: Benign
# Data point 490: Benign
# Data point 491: Benign
# Data point 492: Benign
# Data point 493: Benign
# Data point 494: Benign
# Data point 495: Benign
# Data point 496: Benign
# Data point 497: Benign
# Data point 498: Benign
# Data point 499: Benign
# Data point 500: Benign
# Data point 501: Benign
# Data point 502: Benign
# Data point 503: Benign
# Data point 504: Benign
# Data point 505: Benign
# Data point 506: Benign
# Data point 507: Benign
# Data point 508: Benign
# Data point 509: Benign
# Data point 510: Benign
# Data point 511: Benign
# Data point 512: Benign
# Data point 513: Benign
# Data point 514: Benign
# Data point 515: Benign
# Data point 516: Benign
# Data point 517: Benign
# Data point 518: Benign
# Data point 519: Benign
# Data point 520: Benign
# Data point 521: Benign
# Data point 522: Benign
# Data point 523: Benign
# Data point 524: Benign
# Data point 525: Benign
# Data point 526: Benign
# Data point 527: Benign
# Data point 528: Benign
# Data point 529: Benign
# Data point 530: Benign
# Data point 531: Benign
# Data point 532: Benign
# Data point 533: Benign
# Data point 534: Benign
# Data point 535: Benign
# Data point 536: Benign
# Data point 537: Benign
# Data point 538: Benign
# Data point 539: Benign
# Data point 540: Benign
# Data point 541: Benign
# Data point 542: Benign
# Data point 543: Benign
# Data point 544: Benign
# Data point 545: Benign
# Data point 546: Benign
# Data point 547: Benign
# Data point 548: Benign
# Data point 549: Benign
# Data point 550: Benign
# Data point 551: Benign
# Data point 552: Benign
# Data point 553: Benign
# Data point 554: Benign
# Data point 555: Benign
# Data point 556: Benign
# Data point 557: Benign
# Data point 558: Benign
# Data point 559: Benign
# Data point 560: Benign
# Data point 561: Benign
# Data point 562: Benign
# Data point 563: Benign
# Data point 564: Benign
# Data point 565: Benign
# Data point 566: Benign
# Data point 567: Benign
# Data point 568: Benign
# Data point 569: Benign
# Data point 570: Benign
# Data point 571: Benign
# Data point 572: Benign
# Data point 573: Benign
# Data point 574: Benign
# Data point 575: Benign
# Data point 576: Benign
# Data point 577: Benign
# Data point 578: Benign
# Data point 579: Benign
# Data point 580: Benign
# Data point 581: TCPAttack
# Data point 582: HTTPAttack
# Data point 583: HTTPAttack
# Data point 584: HTTPAttack
# Data point 585: HTTPAttack
# Data point 586: HTTPAttack
# Data point 587: HTTPAttack
# Data point 588: HTTPAttack
# Data point 589: HTTPAttack
# Data point 590: HTTPAttack
# Data point 591: Benign
# Data point 592: Benign
# Data point 593: Benign
# Data point 594: Benign
# Data point 595: Benign
# Data point 596: Benign
# Data point 597: Benign
# Data point 598: Benign
# Data point 599: Benign
# Data point 600: Benign
# Data point 601: Benign
# Data point 602: Benign
# Data point 603: Benign
# Data point 604: Benign
# Data point 605: Benign
# Data point 606: Benign
# Data point 607: Benign
# Data point 608: Benign
# Data point 609: Benign
# Data point 610: Benign
# Data point 611: Benign
# Data point 612: Benign
# Data point 613: Benign
# Data point 614: Benign
# Data point 615: Benign
# Data point 616: Benign
# Data point 617: Benign
# Data point 618: Benign
# Data point 619: Benign
# Data point 620: Benign
# Data point 621: Benign
# Data point 622: Benign
# Data point 623: Benign
# Data point 624: Benign
# Data point 625: Benign
# Data point 626: Benign
# Data point 627: Benign
# Data point 628: Benign
# Data point 629: Benign
# Data point 630: Benign
# Data point 631: Benign
# Data point 632: Benign
# Data point 633: Benign
# Data point 634: Benign
# Data point 635: Benign
# Data point 636: Benign
# Data point 637: Benign
# Data point 638: Benign
# Data point 639: Benign
# Data point 640: Benign
# Data point 641: Benign
# Data point 642: Benign
# Data point 643: Benign
# Data point 644: Benign
# Data point 645: Benign
# Data point 646: Benign
# Data point 647: Benign
# Data point 648: Benign
# Data point 649: Benign
# Data point 650: Benign
# Data point 651: Benign
# Data point 652: Benign
# Data point 653: Benign
# Data point 654: Benign
# Data point 655: Benign
# Data point 656: Benign
# Data point 657: Benign
# Data point 658: Benign
# Data point 659: Benign
# Data point 660: Benign
# Data point 661: Benign
# Data point 662: Benign
# Data point 663: Benign
# Data point 664: Benign
# Data point 665: Benign
# Data point 666: Benign
# Data point 667: Benign
# Data point 668: Benign
# Data point 669: Benign
# Data point 670: Benign
# Data point 671: Benign
# Data point 672: Benign
# Data point 673: Benign
# Data point 674: Benign
# Data point 675: Benign
# Data point 676: Benign
# Data point 677: Benign
# Data point 678: Benign
# Data point 679: Benign
# Data point 680: Benign
# Data point 681: Benign
# Data point 682: Benign
# Data point 683: Benign
# Data point 684: Benign
# Data point 685: Benign
# Data point 686: Benign
# Data point 687: Benign
# Data point 688: Benign
# Data point 689: Benign
# Data point 690: Benign
# Data point 691: Benign
# Data point 692: Benign
# Data point 693: Benign
# Data point 694: Benign
# Data point 695: Benign
# Data point 696: Benign
# Data point 697: Benign
# Data point 698: Benign
# Data point 699: Benign
# Data point 700: Benign
# Data point 701: Benign
# Data point 702: Benign
# Data point 703: Benign
# Data point 704: Benign
# Data point 705: Benign
# Data point 706: Benign
# Data point 707: Benign
# Data point 708: Benign
# Data point 709: Benign
# Data point 710: Benign
# Data point 711: Benign
# Data point 712: Benign
# Data point 713: Benign
# Data point 714: Benign
# Data point 715: Benign
# Data point 716: Benign
# Data point 717: Benign
# Data point 718: Benign
# Data point 719: Benign
# Data point 720: Benign
# Data point 721: Benign
# Data point 722: Benign
# Data point 723: Benign
# Data point 724: Benign
# Data point 725: Benign
# Data point 726: Benign
# Data point 727: Benign
# Data point 728: Benign
# Data point 729: Benign
# Data point 730: Benign
# Data point 731: Benign
# Data point 732: Benign
# Data point 733: Benign
# Data point 734: Benign
# Data point 735: Benign
# Data point 736: Benign
# Data point 737: Benign
# Data point 738: Benign
# Data point 739: Benign
# Data point 740: Benign
# Data point 741: Benign
# Data point 742: Benign
# Data point 743: Benign
# Data point 744: Benign
# Data point 745: Benign
# Data point 746: Benign
# Data point 747: Benign
# Data point 748: Benign
# Data point 749: Benign
# Data point 750: Benign
# Data point 751: Benign
# Data point 752: Benign
# Data point 753: Benign
# Data point 754: Benign
# Data point 755: Benign
# Data point 756: Benign
# Data point 757: Benign
# Data point 758: Benign
# Data point 759: Benign
# Data point 760: Benign
# Data point 761: Benign
# Data point 762: Benign
# Data point 763: Benign
# Data point 764: Benign
# Data point 765: Benign
# Data point 766: Benign
# Data point 767: Benign
# Data point 768: Benign
# Data point 769: Benign
# Data point 770: Benign
# Data point 771: Benign
# Data point 772: Benign
# Data point 773: Benign
# Data point 774: Benign
# Data point 775: Benign
# Data point 776: Benign
# Data point 777: Benign
# Data point 778: Benign
# Data point 779: Benign
# Data point 780: Benign
# Data point 781: Benign
# Data point 782: Benign
# Data point 783: Benign
# Data point 784: Benign
# Data point 785: Benign
# Data point 786: Benign
# Data point 787: Benign
# Data point 788: Benign
# Data point 789: Benign
# Data point 790: Benign
# Data point 791: Benign
# Data point 792: Benign
# Data point 793: Benign
# Data point 794: Benign
# Data point 795: Benign
# Data point 796: Benign
# Data point 797: Benign
# Data point 798: Benign
# Data point 799: Benign
# Data point 800: Benign
# Data point 801: Benign
# Data point 802: Benign
# Data point 803: Benign
# Data point 804: Benign
# Data point 805: Benign
# Data point 806: Benign
# Data point 807: Benign
# Data point 808: Benign
# Data point 809: Benign
# Data point 810: Benign
# Data point 811: Benign
# Data point 812: Benign
# Data point 813: Benign
# Data point 814: Benign
# Data point 815: Benign
# Data point 816: Benign
# Data point 817: Benign
# Data point 818: Benign
# Data point 819: Benign
# Data point 820: Benign
# Data point 821: Benign
# Data point 822: Benign
# Data point 823: Benign
# Data point 824: Benign
# Data point 825: Benign
# Data point 826: Benign
# Data point 827: Benign
# Data point 828: Benign
# Data point 829: Benign
# Data point 830: Benign
# Data point 831: Benign
# Data point 832: Benign
# Data point 833: Benign
# Data point 834: Benign
# Data point 835: Benign
# Data point 836: Benign
# Data point 837: Benign
# Data point 838: Benign
# Data point 839: Benign
# Data point 840: Benign
# Data point 841: Benign
# Data point 842: Benign
# Data point 843: Benign
# Data point 844: Benign
# Data point 845: Benign
# Data point 846: Benign
# Data point 847: Benign
# Data point 848: Benign
# Data point 849: Benign
# Data point 850: Benign
# Data point 851: Benign
# Data point 852: Benign
# Data point 853: Benign
# Data point 854: Benign
# Data point 855: Benign
# Data point 856: Benign
# Data point 857: Benign
# Data point 858: Benign
# Data point 859: Benign
# Data point 860: Benign
# Data point 861: Benign
# Data point 862: Benign
# Data point 863: Benign
# Data point 864: Benign
# Data point 865: Benign
# Data point 866: Benign
# Data point 867: Benign
# Data point 868: Benign
# Data point 869: Benign
# Data point 870: Benign
# Data point 871: Benign
# Data point 872: Benign
# Data point 873: Benign
# Data point 874: Benign
# Data point 875: Benign
# Data point 876: Benign
# Data point 877: Benign
# Data point 878: Benign
# Data point 879: Benign
# Data point 880: Benign
# Data point 881: Benign
# Data point 882: Benign
# Data point 883: Benign
# Data point 884: Benign
# Data point 885: Benign
# Data point 886: Benign
# Data point 887: Benign
# Data point 888: Benign
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: Benign
# Data point 893: Benign
# Data point 894: Benign
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: Benign
# Data point 898: Benign
# Data point 899: Benign
# Data point 900: Benign
# Data point 901: Benign
# Data point 902: Benign
# Data point 903: Benign
# Data point 904: Benign
# Data point 905: Benign
# Data point 906: Benign
# Data point 907: Benign
# Data point 908: Benign
# Data point 909: Benign
# Data point 910: Benign
# Data point 911: Benign
# Data point 912: Benign
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
# Data point 917: Benign
# Data point 918: Benign
# Data point 919: Benign
# Data point 920: Benign
# Data point 921: Benign
# Data point 922: Benign
# Data point 923: Benign
# Data point 924: Benign
# Data point 925: Benign
# Data point 926: Benign
# Data point 927: Benign
# Data point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
# Data point 931: Benign
# Data point 932: Benign
# Data point 933: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 936: Benign
# Data point 937: Benign
# Data point 938: Benign
# Data point 939: Benign
# Data point 940: Benign
# Data point 941: Benign
# Data point 942: Benign
# Data point 943: Benign
# Data point 944: Benign
# Data point 945: Benign
# Data point 946: Benign
# Data point 947: Benign
# Data point 948: Benign
# Data point 949: Benign
# Data point 950: Benign
# Data point 951: Benign
# Data point 952: Benign
# Data point 953: Benign
# Data point 954: Benign
# Data point 955: Benign
# Data point 956: Benign
# Data point 957: Benign
# Data point 958: Benign
# Data point 959: Benign
# Data point 960: Benign
# Data point 961: Benign
# Data point 962: Benign
# Data point 963: Benign
# Data point 964: Benign
# Data point 965: Benign
# Data point 966: Benign
# Data point 967: Benign
# Data point 968: Benign
# Data point 969: Benign
# Data point 970: Benign
# Data point 971: Benign
# Data point 972: Benign
# Data point 973: Benign
# Data point 974: Benign
# Data point 975: Benign
# Data point 976: Benign
# Data point 977: Benign
# Data point 978: Benign
# Data point 979: Benign
# Data point 980: Benign
# Data point 981: Benign
# Data point 982: Benign
# Data point 983: Benign
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Latency for this chunk: 0.0834 seconds
#
# Total processing time: 51.4260 seconds
# Average latency per chunk: 0.1108 seconds

# %%
print("Unique prediction values:", set(predictions))
# Out:
# Unique prediction values: {0, 1}

# %% [markdown]
# ## Continuous Multiclass

# %%
# Real-time simulation function
def simulate_time_based_window(file_path, chunk_size, window_duration, delay=1):
    sliding_window = pd.DataFrame()
    all_true_labels = []
    all_predictions = []
    latencies = []

    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        print("\nProcessing new data chunk...")

        # Start tracking the time for processing this chunk
        start_time_latency = time.time()

        sliding_window = pd.concat([sliding_window, chunk])
        sliding_window['end_time_x'] = pd.to_datetime(sliding_window['end_time_x'])

        latest_time = sliding_window['end_time_x'].max()
        window_start_time = latest_time - pd.Timedelta(seconds=window_duration)
        sliding_window = sliding_window[sliding_window['end_time_x'] >= window_start_time]

        # print(f"Data within the sliding window:")
        print(sliding_window)

        # Drop the same non-feature columns from the chunk
        X_chunk = sliding_window.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
        y_true = sliding_window['Label']  # Assuming 'BinLabel' is the target variable

        # Check for NaN values and fill with column means if necessary
        if X_chunk.isna().any().any():
            print("Chunk contains NaN values. Filling with column means.")
            X_chunk = X_chunk.fillna(X_chunk.mean())

        # Scale and apply PCA to the new chunk
        X_scaled_chunk = scaler.transform(X_chunk)  # Scale the chunk
        X_pca_chunk = pca.transform(X_scaled_chunk)  # Apply PCA to the scaled chunk

        # Predict using the trained model
        predictions = model.predict(X_pca_chunk)

        # End tracking the time after classification
        end_time_latency = time.time()

        # Calculate the processing latency for this chunk
        latency = end_time_latency - start_time_latency
        latencies.append(latency)

        print(f"Processing latency for this chunk: {latency:.4f} seconds")

        # Store predictions and true labels
        all_true_labels.extend(y_true.tolist())
        all_predictions.extend(predictions.tolist())

        # Simulate the results
        for i, pred in enumerate(predictions):
            print(f"Data point {i+1}: {pred}")

        time.sleep(delay)  # Simulate delay for real-time processing

    # Calculate average latency
    avg_latency = sum(latencies) / len(latencies)
    print(f"Average processing latency: {avg_latency:.4f} seconds")

    return all_true_labels, all_predictions

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Run the simulation and get predictions and true labels
true_labels, predictions = simulate_time_based_window('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.cs
# 23971            0               0.0  2024-08-26 20:13:00              1
# 23972            0               0.0  2024-08-26 20:13:00              1
# 23973            0               0.0  2024-08-26 20:13:00              1
# 23974            0               0.0  2024-08-26 20:13:00              1
# 23975            0               0.0  2024-08-26 20:14:00              1
# 23976            0               0.0  2024-08-26 20:14:00              1
# 23977            0               0.0  2024-08-26 20:14:00              1
# 23978            0               0.0  2024-08-26 20:14:00              1
# 23979            0               0.0  2024-08-26 20:14:00              1
# 23980            0               0.0  2024-08-26 20:15:00              1
# 23981            0               0.0  2024-08-26 20:15:00              1
# 23982            0               0.0  2024-08-26 20:15:00              1
# 23983            0               0.0  2024-08-26 20:15:00              1
# 23984            0               0.0  2024-08-26 20:15:00              1
# 23985            0               0.0  2024-08-26 20:15:00              1
#
#        total_bytes   Label  BinLabel
# 23960           62  Benign         0
# 23961           62  Benign         0
# 23962           62  Benign         0
# 23963           62  Benign         0
# 23964           62  Benign         0
# 23965           62  Benign         0
# 23966           62  Benign         0
# 23967           62  Benign         0
# 23968           62  Benign         0
# 23969           62  Benign         0
# 23970           62  Benign         0
# 23971           62  Benign         0
# 23972           62  Benign         0
# 23973           62  Benign         0
# 23974           62  Benign         0
# 23975           62  Benign         0
# 23976           62  Benign         0
# 23977           62  Benign         0
# 23978           62  Benign         0
# 23979           62  Benign         0
# 23980           62  Benign         0
# 23981           62  Benign         0
# 23982           62  Benign         0
# 23983           62  Benign         0
# 23984           62  Benign         0
# 23985           62  Benign         0
#
# [26 rows x 68 columns]
# Processing latency for this chunk: 0.0510 seconds
# Data point 1: Benign
# Data point 2: Benign
# Data point 3: Benign
# Data point 4: Benign
# Data point 5: Benign
# Data point 6: Benign
# Data point 7: Benign
# Data point 8: Benign
# Data point 9: Benign
# Data point 10: Benign
# Data point 11: Benign
# Data point 12: Benign
# Data point 13: Benign
# Data point 14: Benign
# Data point 15: Benign
# Data point 16: Benign
# Data point 17: Benign
# Data point 18: Benign
# Data point 19: Benign
# Data point 20: Benign
# Data point 21: Benign
# Data point 22: Benign
# Data point 23: Benign
# Data point 24: Benign
# Data point 25: Benign
# Data point 26: Benign
# Average processing latency: 0.0574 seconds
# Unique classes in true_labels and predictions: ['Benign', 'HTTPAttack', 'TCPAttack', 'UDPAttack', 'XMasAttack']
# Accuracy: 1.0
# Confusion Matrix:
# [[501   0   0   0   0]
#  [  0  21   0   0   0]
#  [  0   0  45   0   0]
#  [  0   0   0  41   0]
#  [  0   0   0   0  16]]
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
print("Unique classes in true_labels:", set(true_labels))
# Out:
# Unique classes in true_labels: {'UDPAttack', 'HTTPAttack', 'XMasAttack', 'Benign', 'TCPAttack'}

# %%
# Check unique labels in the true labels and predictions
unique_labels = sorted(set(true_labels) | set(predictions))
print("Unique classes in true_labels and predictions:", unique_labels)
# Out:
# Unique classes in true_labels and predictions: ['Benign', 'HTTPAttack', 'TCPAttack', 'UDPAttack', 'XMasAttack']

# %% [markdown]
# ## Parrellel MultiClass

# %%
import os
import psutil
import multiprocessing as mp
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# Function to simulate real-time classification for each chunk
def simulate_real_time_classification(chunk, scaler, pca, model):
    latencies = []  # List to store latencies for each chunk
    total_start_time = time.time()  # Start time of the entire process
    print(f"Processing chunk in process ID: {os.getpid()}")
    cpu_percent = psutil.cpu_percent(interval=1)  # Check CPU utilization
    print(f"CPU Utilization in process {os.getpid()}: {cpu_percent}%")

    cpu_count = psutil.cpu_count()
    print(f"Number of CPUs {os.getpid()}:{cpu_count}")

    memory_info = psutil.virtual_memory()
    print(f"Memory Usage {os.getpid()}:{memory_info.percent}%")

    # Start tracking the time for processing this chunk
    start_time_latency = time.time()
    print(chunk.columns)

    # Perform pre-processing
    chunk = chunk.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
    X_chunk = chunk.fillna(chunk.mean())

    # Scale and apply PCA
    X_scaled_chunk = scaler.transform(X_chunk)
    X_pca_chunk = pca.transform(X_scaled_chunk)

    # Predict
    start_time = time.time()
    predictions = model.predict(X_pca_chunk)
    latency = time.time() - start_time
    print(f"Latency for this chunk: {latency:.4f} seconds")

    # Print predictions for this chunk
    print("Predictions for this chunk:")
    for i, pred in enumerate(predictions):
        print(f"Data point {i+1}: {pred}")

    # End tracking the time after classification for this chunk
    end_time_latency = time.time()

    # Calculate latency for this chunk
    chunk_latency = end_time_latency - start_time_latency
    latencies.append(chunk_latency)
    print(f"Latency for this chunk: {chunk_latency:.4f} seconds")

    # Calculate total processing time
    total_end_time = time.time()
    total_processing_time = total_end_time - total_start_time

    # Calculate average latency
    average_latency = sum(latencies) / len(latencies) if latencies else 0

    print(f"\nTotal processing time: {total_processing_time:.4f} seconds")
    print(f"Average latency per chunk: {average_latency:.4f} seconds")

    # Simulate real-time results
    return predictions

# Function to process the dataset in parallel
def parallel_real_time_simulation(dataset, chunk_size, num_processes, scaler, pca, model):
    # Split the data into chunks for parallel processing
    chunks = [dataset[i:i + chunk_size] for i in range(0, len(dataset), chunk_size)]

    # Create a pool of workers and use starmap to pass multiple arguments to the worker function
    with mp.Pool(processes=num_processes) as pool:
        results = pool.starmap(simulate_real_time_classification, [(chunk, scaler, pca, model) for chunk in chunks])

    return results

# Assuming the dataset, scaler, PCA, and trained model are already loaded and defined
aggregated_data = pd.read_csv('/content/drive/MyDrive/Labelled_Multiclass_Dataset/aggregated_data.csv')

# Fit the scaler and PCA on the entire dataset (without the non-feature columns)
X = aggregated_data.drop(columns=['Label', 'BinLabel', 'src_ip', 'dst_ip', 'start_time', 'end_time_x', 'end_time_y', 'time_diff', 'time_diff_seconds'])
scaler = StandardScaler().fit(X)
pca = PCA(n_components=0.95).fit(scaler.transform(X))
y = aggregated_data['Label']  # Assuming 'Label' is the target column
model = DecisionTreeClassifier(max_depth = 54).fit(pca.transform(scaler.transform(X)), y)

# Define chunk size and number of parallel processes
chunk_size = 1000  # Number of data points per chunk
num_processes = 4  # Number of parallel processes

start_time = time.time()

# Run the parallel real-time simulation
parallel_results = parallel_real_time_simulation(aggregated_data, chunk_size, num_processes, scaler, pca, model)

# You can now analyze the parallel_results
end_time = time.time()
print(f"Total processing time with parallelization: {end_time - start_time:.4f} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Data point 882: Benign
#
# Data point 741: BenignData point 747: BenignData point 883: Benign
#
# Data point 771: Benign
#
# Data point 742: BenignData point 773: BenignData point 748: BenignData point 772: BenignData point 884: Benign
#
#
#
# Data point 749: Benign
# Data point 743: BenignData point 774: Benign
#
#
# Data point 885: BenignData point 750: Benign
# Data point 744: BenignData point 775: Benign
# Data point 776: HTTPAttack
# Data point 751: Benign
#
# Data point 745: Benign
# Data point 886: BenignData point 752: Benign
# Data point 777: HTTPAttack
#
#
# Data point 778: HTTPAttackData point 746: Benign
# Data point 779: HTTPAttackData point 887: Benign
#
# Data point 753: Benign
# Data point 754: BenignData point 747: Benign
# Data point 780: HTTPAttack
# Data point 888: Benign
#
# Data point 748: BenignData point 781: HTTPAttack
#
#
# Data point 782: HTTPAttackData point 755: BenignData point 889: BenignData point 749: Benign
#
#
# Data point 890: Benign
# Data point 756: BenignData point 750: Benign
# Data point 783: HTTPAttackData point 891: Benign
#
#
# Data point 757: BenignData point 784: HTTPAttack
# Data point 751: BenignData point 892: Benign
#
#
#
# Data point 785: HTTPAttackData point 893: BenignData point 758: Benign
#
# Data point 894: Benign
#
# Data point 752: BenignData point 786: BenignData point 759: BenignData point 895: Benign
#
# Data point 753: Benign
# Data point 896: Benign
#
# Data point 897: Benign
# Data point 760: BenignData point 787: Benign
#
# Data point 761: Benign
#
# Data point 754: BenignData point 898: BenignData point 762: Benign
#
# Data point 788: BenignData point 763: Benign
# Data point 899: Benign
#
# Data point 755: BenignData point 900: Benign
#
# Data point 901: Benign
#
# Data point 789: BenignData point 764: BenignData point 902: BenignData point 756: Benign
#
#
# Data point 903: BenignData point 790: Benign
#
# Data point 765: Benign
# Data point 904: BenignData point 757: Benign
# Data point 791: Benign
#
# Data point 905: Benign
# Data point 766: BenignData point 758: Benign
#
# Data point 792: Benign
# Data point 759: BenignData point 767: Benign
# Data point 768: BenignData point 906: Benign
#
#
# Data point 793: BenignData point 769: BenignData point 760: Benign
# Data point 770: Benign
#
#
# Data point 761: Benign
#
# Data point 907: BenignData point 762: BenignData point 771: Benign
# Data point 794: Benign
#
# Data point 908: BenignData point 763: BenignData point 772: Benign
#
#
#
# Data point 795: BenignData point 764: BenignData point 909: BenignData point 773: Benign
#
#
# Data point 796: Benign
# Data point 765: BenignData point 910: Benign
# Data point 774: Benign
#
# Data point 775: Benign
#
# Data point 797: BenignData point 776: BenignData point 766: Benign
# Data point 777: BenignData point 911: Benign
#
#
# Data point 767: Benign
# Data point 798: BenignData point 778: BenignData point 912: Benign
#
#
#
# Data point 799: BenignData point 768: BenignData point 779: BenignData point 913: Benign
#
#
#
# Data point 800: BenignData point 780: BenignData point 769: BenignData point 914: Benign
#
#
#
# Data point 801: BenignData point 781: UDPAttackData point 770: BenignData point 915: Benign
#
#
#
# Data point 802: BenignData point 771: BenignData point 782: UDPAttackData point 916: Benign
#
#
#
# Data point 772: BenignData point 783: UDPAttackData point 803: BenignData point 917: Benign
#
#
#
# Data point 804: BenignData point 773: BenignData point 784: UDPAttackData point 918: Benign
#
#
#
# Data point 805: BenignData point 785: UDPAttackData point 774: Benign
#
# Data point 919: Benign
# Data point 786: Benign
# Data point 806: BenignData point 775: Benign
#
# Data point 920: Benign
# Data point 787: BenignData point 807: Benign
# Data point 921: Benign
# Data point 776: UDPAttack
#
# Data point 788: Benign
# Data point 808: Benign
#
# Data point 922: BenignData point 777: UDPAttackData point 809: BenignData point 789: Benign
#
#
# Data point 923: Benign
# Data point 778: UDPAttackData point 810: Benign
# Data point 790: Benign
#
#
# Data point 924: BenignData point 779: UDPAttackData point 811: BenignData point 791: Benign
#
#
#
# Data point 812: BenignData point 925: BenignData point 780: UDPAttackData point 792: Benign
#
#
#
# Data point 926: BenignData point 781: UDPAttackData point 813: BenignData point 793: Benign
#
#
#
# Data point 927: BenignData point 782: UDPAttackData point 814: BenignData point 794: Benign
#
#
#
# Data point 928: BenignData point 783: UDPAttackData point 815: Benign
# Data point 795: Benign
#
# Data point 929: Benign
# Data point 784: UDPAttackData point 816: Benign
# Data point 796: Benign
#
# Data point 930: Benign
# Data point 817: BenignData point 785: UDPAttackData point 797: Benign
#
#
#
# Data point 931: BenignData point 818: BenignData point 786: BenignData point 798: Benign
#
#
#
# Data point 932: BenignData point 819: BenignData point 787: BenignData point 799: Benign
#
#
#
# Data point 820: BenignData point 933: BenignData point 788: BenignData point 800: Benign
#
#
# Data point 934: Benign
# Data point 821: BenignData point 801: BenignData point 789: Benign
# Data point 935: Benign
#
#
#
# Data point 802: BenignData point 822: BenignData point 790: Benign
# Data point 791: Benign
#
# Data point 936: Benign
# Data point 792: BenignData point 803: Benign
# Data point 823: Benign
# Data point 937: Benign
#
# Data point 804: BenignData point 793: Benign
# Data point 824: Benign
#
# Data point 938: Benign
# Data point 825: Benign
# Data point 794: BenignData point 805: Benign
# Data point 939: Benign
#
# Data point 795: BenignData point 826: Benign
# Data point 806: BenignData point 940: Benign
#
#
# Data point 796: Benign
# Data point 827: Benign
# Data point 807: BenignData point 941: Benign
#
# Data point 797: Benign
# Data point 828: BenignData point 808: Benign
# Data point 942: Benign
#
# Data point 798: Benign
#
# Data point 829: BenignData point 799: BenignData point 809: Benign
# Data point 800: Benign
# Data point 943: BenignData point 830: Benign
#
# Data point 801: BenignData point 831: Benign
#
#
#
# Data point 802: BenignData point 832: Benign
# Data point 810: Benign
# Data point 803: BenignData point 944: Benign
#
#
# Data point 833: BenignData point 804: Benign
#
# Data point 834: Benign
# Data point 945: BenignData point 805: BenignData point 835: Benign
#
# Data point 806: BenignData point 836: BenignData point 811: Benign
#
#
# Data point 807: BenignData point 837: BenignData point 946: Benign
#
#
# Data point 808: BenignData point 812: Benign
#
# Data point 947: Benign
# Data point 838: Benign
# Data point 813: BenignData point 809: Benign
# Data point 948: BenignData point 814: Benign
#
#
#
# Data point 949: BenignData point 810: BenignData point 815: Benign
# Data point 839: Benign
#
# Data point 950: Benign
# Data point 811: Benign
# Data point 840: Benign
# Data point 951: BenignData point 816: Benign
# Data point 812: Benign
# Data point 841: Benign
#
# Data point 952: BenignData point 813: Benign
#
# Data point 842: Benign
#
# Data point 953: Benign
# Data point 843: BenignData point 954: Benign
# Data point 817: BenignData point 814: Benign
# Data point 844: Benign
#
# Data point 845: Benign
# Data point 955: Benign
#
# Data point 818: BenignData point 956: BenignData point 846: BenignData point 815: Benign
#
#
# Data point 957: Benign
# Data point 847: BenignData point 819: Benign
# Data point 816: BenignData point 848: Benign
#
#
#
# Data point 820: BenignData point 849: BenignData point 958: Benign
#
# Data point 817: Benign
# Data point 821: BenignData point 850: BenignData point 959: Benign
#
#
#
# Data point 822: BenignData point 851: BenignData point 960: Benign
#
#
# Data point 823: BenignData point 818: BenignData point 852: BenignData point 961: Benign
#
#
# Data point 824: Benign
#
# Data point 819: BenignData point 962: BenignData point 825: BenignData point 853: Benign
#
#
#
# Data point 820: BenignData point 826: BenignData point 854: Benign
# Data point 855: Benign
#
#
# Data point 963: BenignData point 821: BenignData point 856: BenignData point 827: Benign
#
#
# Data point 964: Benign
# Data point 822: BenignData point 857: BenignData point 828: Benign
#
# Data point 823: Benign
#
#
# Data point 824: BenignData point 965: BenignData point 858: BenignData point 829: Benign
# Data point 825: Benign
#
#
#
# Data point 830: BenignData point 859: BenignData point 966: BenignData point 826: Benign
#
#
# Data point 967: Benign
# Data point 831: BenignData point 860: Benign
#
# Data point 861: BenignData point 827: Benign
#
# Data point 832: BenignData point 968: BenignData point 862: Benign
#
# Data point 833: Benign
# Data point 828: Benign
#
# Data point 863: Benign
# Data point 834: Benign
#
# Data point 864: BenignData point 969: BenignData point 835: BenignData point 829: Benign
#
#
# Data point 970: Benign
# Data point 865: Benign
# Data point 830: Benign
# Data point 971: BenignData point 866: BenignData point 836: Benign
#
#
# Data point 831: BenignData point 972: Benign
# Data point 837: Benign
#
# Data point 973: Benign
#
# Data point 832: BenignData point 974: BenignData point 867: BenignData point 838: Benign
#
#
# Data point 833: BenignData point 975: Benign
#
# Data point 839: Benign
# Data point 868: Benign
# Data point 976: XMasAttackData point 834: BenignData point 840: Benign
#
#
#
# Data point 869: BenignData point 835: BenignData point 841: Benign
#
# Data point 836: Benign
# Data point 870: BenignData point 842: BenignData point 977: XMasAttack
#
#
# Data point 871: Benign
#
# Data point 872: Benign
# Data point 978: XMasAttackData point 843: BenignData point 837: Benign
# Data point 873: Benign
#
#
# Data point 838: BenignData point 844: Benign
# Data point 979: XMasAttackData point 874: BenignData point 845: Benign
#
#
# Data point 846: Benign
# Data point 847: BenignData point 839: BenignData point 980: XMasAttack
#
#
# Data point 840: Benign
# Data point 875: Benign
#
# Data point 841: BenignData point 981: BenignData point 848: Benign
# Data point 876: Benign
#
# Data point 849: Benign
# Data point 982: BenignData point 842: BenignData point 877: Benign
#
#
# Data point 850: Benign
# Data point 983: BenignData point 878: Benign
# Data point 843: Benign
#
# Data point 851: BenignData point 984: Benign
#
# Data point 844: BenignData point 879: Benign
#
# Data point 985: Benign
#
# Data point 852: BenignData point 880: Benign
# Data point 845: BenignData point 986: BenignData point 853: Benign
#
# Data point 846: Benign
# Data point 881: Benign
#
#
# Data point 987: BenignData point 854: BenignData point 847: BenignData point 882: Benign
#
#
# Data point 988: Benign
# Data point 855: BenignData point 848: BenignData point 883: Benign
#
#
# Data point 989: BenignData point 849: BenignData point 856: Benign
#
# Data point 884: Benign
#
#
# Data point 885: BenignData point 857: BenignData point 990: Benign
# Data point 850: Benign
# Data point 851: Benign
#
#
# Data point 886: BenignData point 852: BenignData point 991: BenignData point 858: Benign
#
# Data point 992: BenignData point 859: Benign
#
#
# Data point 993: Benign
# Data point 887: BenignData point 994: BenignData point 853: Benign
#
#
# Data point 995: BenignData point 860: BenignData point 888: Benign
#
# Data point 854: BenignData point 996: Benign
#
#
# Data point 861: Benign
#
# Data point 997: BenignData point 889: BenignData point 862: BenignData point 855: Benign
#
# Data point 863: Benign
# Data point 864: Benign
# Data point 998: Benign
#
# Data point 890: BenignData point 999: Benign
#
# Data point 1000: BenignData point 856: Benign
#
# Latency for this chunk: 22.3608 secondsData point 865: Benign
#
# Total processing time: 23.4699 seconds
#
# Data point 891: BenignAverage latency per chunk: 22.3608 seconds
# Data point 857: Benign
# Data point 866: Benign
#
# Data point 892: BenignData point 858: Benign
#
# Processing chunk in process ID: 202666
# Data point 893: Benign
# Data point 867: BenignData point 859: Benign
#
# Data point 860: Benign
# Data point 894: Benign
# Data point 868: Benign
# Data point 869: Benign
#
# Data point 861: BenignData point 895: BenignData point 870: Benign
#
#
# Data point 862: BenignData point 896: BenignData point 871: Benign
#
#
# Data point 863: BenignData point 897: BenignData point 872: Benign
#
#
# Data point 864: BenignData point 898: BenignData point 873: Benign
#
#
# Data point 865: BenignData point 899: BenignData point 874: Benign
#
#
# Data point 900: BenignData point 866: BenignData point 875: Benign
#
# Data point 901: Benign
# Data point 867: BenignData point 876: Benign
#
#
# Data point 868: BenignData point 902: Benign
# Data point 877: Benign
# Data point 869: Benign
# Data point 903: Benign
#
# Data point 878: BenignData point 870: BenignData point 904: Benign
#
#
# Data point 879: BenignData point 871: BenignData point 905: Benign
#
#
# Data point 880: BenignData point 872: BenignData point 906: Benign
#
#
# Data point 881: BenignData point 873: BenignData point 907: Benign
#
#
# Data point 882: BenignData point 874: BenignData point 908: Benign
#
#
# Data point 883: BenignData point 909: BenignData point 875: Benign
#
#
# Data point 884: BenignData point 876: BenignData point 910: Benign
#
#
# Data point 885: BenignData point 877: BenignData point 911: Benign
#
#
# Data point 886: BenignData point 878: BenignData point 912: Benign
#
#
# Data point 887: BenignData point 879: Benign
# Data point 913: Benign
#
# Data point 880: BenignData point 888: BenignData point 914: Benign
#
#
# Data point 881: BenignData point 889: BenignData point 915: Benign
#
#
# Data point 882: BenignData point 916: BenignData point 890: Benign
#
#
# Data point 883: BenignData point 891: BenignData point 917: Benign
#
#
# Data point 918: BenignData point 884: BenignData point 892: Benign
#
#
# Data point 885: BenignData point 893: BenignData point 919: Benign
#
#
# Data point 886: BenignData point 920: Benign
#
# Data point 921: BenignData point 894: Benign
# Data point 922: Benign
# Data point 923: Benign
#
# Data point 895: Benign
# Data point 896: Benign
# Data point 897: BenignData point 924: BenignData point 887: Benign
# Data point 898: Benign
#
#
# Data point 899: BenignData point 888: Benign
# Data point 900: BenignData point 925: Benign
#
# Data point 901: Benign
#
# Data point 889: Benign
# Data point 890: Benign
# Data point 891: Benign
# Data point 892: BenignData point 926: Benign
# Data point 893: BenignData point 902: Benign
#
# Data point 903: Benign
# Data point 904: Benign
# Data point 894: BenignData point 905: Benign
#
# Data point 906: Benign
# Data point 907: Benign
# Data point 927: Benign
# Data point 908: Benign
# Data point 895: Benign
# Data point 909: BenignData point 896: Benign
#
#
# Data point 910: BenignData point 928: BenignData point 897: Benign
# Data point 911: Benign
# Data point 912: Benign
#
# Data point 898: Benign
# Data point 929: Benign
# Data point 899: Benign
# Data point 930: BenignData point 900: Benign
#
#
# Data point 913: Benign
# Data point 901: BenignData point 932: Benign
#
# Data point 931: BenignData point 933: Benign
# Data point 914: BenignData point 934: Benign
#
# CPU Utilization in process 202666: 100.0%Data point 902: Benign
# Data point 915: Benign
# Data point 935: Benign
# Data point 903: Benign
#
#
# Number of CPUs 202666:2Data point 936: Benign
#
# Data point 904: Benign
# Memory Usage 202666:17.6%Data point 916: BenignData point 937: BenignData point 905: Benign
#
# Data point 938: Benign
# Data point 906: BenignData point 917: Benign
#
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 939: Benign
#
# Data point 918: BenignData point 907: Benign
#
#
# Data point 940: BenignData point 908: BenignData point 919: Benign
#
# Data point 909: BenignData point 920: Benign
#
#
# Data point 921: BenignData point 941: BenignData point 910: Benign
#
# Data point 922: Benign
#
# Data point 923: BenignData point 911: Benign
# Data point 942: BenignData point 924: Benign
#
#
# Data point 943: BenignData point 925: BenignData point 912: Benign
# Data point 944: Benign
#
#
# Data point 926: BenignData point 945: Benign
#
# Data point 913: Benign
#
# Data point 927: BenignData point 914: Benign
# Data point 915: Benign
# Data point 916: Benign
#
# Data point 917: BenignData point 928: Benign
# Data point 929: Benign
# Data point 930: Benign
#
# Data point 931: Benign
# Latency for this chunk: 0.0015 secondsData point 932: BenignData point 918: Benign
#
# Data point 933: BenignData point 946: Benign
#
#
# Data point 947: Benign
# Data point 948: Benign
# Data point 919: BenignData point 949: Benign
# Data point 934: Benign
# Data point 935: Benign
# Data point 920: BenignPredictions for this chunk:Data point 950: BenignData point 936: Benign
#
#
# Data point 921: Benign
#
# Data point 922: BenignData point 937: Benign
# Data point 951: Benign
#
# Data point 923: BenignData point 952: BenignData point 938: BenignData point 1: Benign
#
#
#
# Data point 953: BenignData point 2: BenignData point 924: Benign
# Data point 939: Benign
#
# Data point 954: BenignData point 3: Benign
#
# Data point 940: BenignData point 955: BenignData point 925: Benign
#
#
#
# Data point 956: BenignData point 926: BenignData point 4: BenignData point 941: Benign
#
#
# Data point 5: Benign
# Data point 957: BenignData point 927: BenignData point 942: Benign
#
#
# Data point 6: Benign
# Data point 928: BenignData point 958: Benign
# Data point 943: Benign
#
# Data point 7: Benign
# Data point 959: BenignData point 929: Benign
# Data point 944: Benign
#
# Data point 8: Benign
# Data point 930: BenignData point 960: Benign
# Data point 945: Benign
#
# Data point 961: Benign
# Data point 9: BenignData point 931: BenignData point 946: Benign
#
#
#
# Data point 962: BenignData point 932: BenignData point 10: BenignData point 947: Benign
#
#
#
# Data point 933: BenignData point 11: BenignData point 963: BenignData point 948: Benign
#
#
#
# Data point 934: BenignData point 964: BenignData point 12: BenignData point 949: Benign
#
#
#
# Data point 13: BenignData point 935: BenignData point 965: BenignData point 950: Benign
#
#
#
# Data point 951: Benign
# Data point 936: BenignData point 966: BenignData point 14: Benign
# Data point 952: Benign
# Data point 967: Benign
#
# Data point 937: BenignData point 15: BenignData point 953: Benign
#
#
#
# Data point 16: BenignData point 968: BenignData point 938: Benign
# Data point 954: Benign
#
# Data point 17: Benign
# Data point 969: BenignData point 939: Benign
# Data point 955: BenignData point 970: Benign
# Data point 971: Benign
#
# Data point 940: BenignData point 972: Benign
#
#
#
# Data point 973: Benign
# Data point 974: Benign
# Data point 18: BenignData point 956: BenignData point 975: Benign
#
# Data point 976: BenignData point 19: Benign
#
# Data point 941: Benign
# Data point 977: BenignData point 20: Benign
# Data point 957: Benign
# Data point 978: BenignData point 21: Benign
#
# Data point 979: BenignData point 942: Benign
#
# Data point 958: BenignData point 980: Benign
#
# Data point 981: Benign
#
# Data point 959: Benign
# Data point 982: BenignData point 943: Benign
#
# Data point 960: BenignData point 983: Benign
#
# Data point 22: BenignData point 961: Benign
#
# Data point 962: Benign
# Data point 984: Benign
#
# Data point 944: BenignData point 963: BenignData point 985: Benign
#
# Data point 23: Benign
# Data point 945: BenignData point 964: BenignData point 986: Benign
#
#
#
# Data point 965: BenignData point 987: Benign
#
# Data point 946: BenignData point 988: BenignData point 966: BenignData point 24: Benign
#
#
# Data point 989: BenignData point 967: Benign
#
#
# Data point 990: BenignData point 947: BenignData point 25: BenignData point 968: Benign
# Data point 991: Benign
#
#
# Data point 992: BenignData point 948: BenignData point 26: Benign
#
#
#
# Data point 969: BenignData point 993: Benign
#
# Data point 27: BenignData point 970: BenignData point 994: Benign
#
# Data point 995: BenignData point 971: BenignData point 949: Benign
#
#
# Data point 28: Benign
# Data point 972: Benign
# Data point 950: BenignData point 996: Benign
# Data point 973: Benign
#
#
# Data point 29: BenignData point 951: BenignData point 974: BenignData point 997: Benign
#
#
# Data point 30: Benign
# Data point 952: Benign
# Data point 998: Benign
#
# Data point 975: BenignData point 999: BenignData point 31: Benign
#
# Data point 953: BenignData point 976: BenignData point 1000: Benign
#
# Data point 954: Benign
# Latency for this chunk: 23.9363 secondsData point 977: Benign
#
#
# Data point 32: BenignData point 955: Benign
#
#
# Total processing time: 25.0539 secondsData point 978: Benign
# Data point 33: Benign
# Data point 956: Benign
#
#
# Data point 979: BenignData point 34: BenignAverage latency per chunk: 23.9363 secondsData point 957: Benign
#
#
# Processing chunk in process ID: 202667
# Data point 958: BenignData point 35: BenignData point 980: Benign
#
#
# Data point 959: BenignData point 36: Benign
# Data point 960: Benign
#
#
# Data point 961: BenignData point 981: UDPAttackData point 962: Benign
#
#
# Data point 982: UDPAttackData point 963: Benign
# Data point 983: UDPAttackData point 37: Benign
# Data point 38: BenignData point 984: UDPAttack
#
# Data point 39: Benign
#
#
# Data point 985: UDPAttackData point 40: Benign
#
# Data point 964: BenignData point 986: Benign
# Data point 987: Benign
#
# Data point 41: BenignData point 988: Benign
# Data point 965: BenignData point 42: Benign
#
#
# Data point 43: Benign
# Data point 966: BenignData point 44: BenignData point 989: Benign
#
#
# Data point 990: Benign
# Data point 991: Benign
# Data point 967: Benign
# Data point 45: BenignData point 968: Benign
# Data point 46: BenignData point 992: Benign
#
# Data point 47: Benign
# Data point 969: BenignData point 993: Benign
# Data point 48: BenignData point 994: BenignData point 970: Benign
#
#
#
#
# Data point 49: Benign
# Data point 995: BenignData point 971: BenignData point 50: Benign
# Data point 972: BenignData point 996: Benign
#
#
#
# Data point 51: BenignData point 973: BenignData point 997: Benign
#
# Data point 974: Benign
# Data point 998: BenignData point 52: Benign
#
# Data point 975: Benign
# Data point 53: BenignData point 999: Benign
#
#
# Data point 976: HTTPAttackData point 54: Benign
# Data point 1000: Benign
#
# Data point 977: HTTPAttackLatency for this chunk: 24.2034 secondsData point 55: Benign
#
#
# Data point 978: HTTPAttack
# Total processing time: 25.3463 secondsData point 56: Benign
#
#
# Data point 979: HTTPAttackAverage latency per chunk: 24.2034 secondsData point 57: Benign
#
#
# Processing chunk in process ID: 202664Data point 980: HTTPAttack
# Data point 981: HTTPAttackData point 58: Benign
# Data point 982: HTTPAttack
# Data point 983: HTTPAttack
#
#
# Data point 984: HTTPAttackData point 59: Benign
#
# Data point 985: HTTPAttackData point 60: Benign
# Data point 986: Benign
#
# Data point 61: Benign
# Data point 62: Benign
# Data point 63: Benign
# Data point 64: Benign
# Data point 65: BenignData point 987: Benign
# Data point 66: Benign
# Data point 67: Benign
#
# Data point 68: BenignData point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
#
# Data point 992: Benign
# Data point 993: BenignData point 69: Benign
#
# Data point 70: BenignData point 994: Benign
#
# Data point 71: Benign
# Data point 995: BenignData point 72: Benign
#
# Data point 996: BenignData point 73: Benign
#
# Data point 74: BenignData point 997: Benign
#
# Data point 75: Benign
# Data point 76: Benign
# Data point 77: Benign
# Data point 998: BenignData point 78: Benign
#
# Data point 79: Benign
# Data point 80: BenignData point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 24.7342 seconds
# Data point 81: Benign
#
# Data point 82: Benign
# Total processing time: 25.8671 seconds
# Average latency per chunk: 24.7342 seconds
#
# Processing chunk in process ID: 202665
# Data point 83: Benign
# Data point 84: Benign
# Data point 85: Benign
# Data point 86: Benign
# Data point 87: Benign
# Data point 88: Benign
# Data point 89: Benign
# Data point 90: BenignCPU Utilization in process 202667: 100.0%
# Data point 91: Benign
# Number of CPUs 202667:2
#
# Data point 92: BenignMemory Usage 202667:17.7%
#
# Data point 93: Benign
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 94: Benign
# Data point 95: Benign
# Data point 96: Benign
# Data point 97: Benign
# Data point 98: Benign
# Data point 99: Benign
# Data point 100: Benign
# Data point 101: Benign
# Data point 102: BenignLatency for this chunk: 0.0072 seconds
#
# Data point 103: BenignPredictions for this chunk:
#
# Data point 104: BenignData point 1: Benign
# Data point 105: Benign
# Data point 2: Benign
# Data point 106: Benign
#
# Data point 3: Benign
# Data point 107: BenignData point 4: Benign
#
# Data point 108: BenignData point 5: Benign
#
# Data point 109: BenignData point 6: Benign
#
# Data point 110: BenignData point 7: Benign
#
# Data point 111: BenignData point 8: Benign
#
# Data point 112: BenignData point 9: Benign
#
# Data point 113: BenignData point 10: BenignData point 114: Benign
#
# Data point 11: Benign
#
# Data point 115: BenignData point 12: Benign
#
# Data point 116: BenignData point 13: Benign
#
# Data point 117: BenignCPU Utilization in process 202664: 100.0%Data point 14: Benign
#
# Number of CPUs 202664:2
# Data point 118: Benign
# Data point 15: Benign
# Memory Usage 202664:17.7%
# Data point 119: Benign
# Data point 16: Benign
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')
# Data point 120: Benign
#
# Data point 17: BenignData point 121: Benign
#
# Data point 18: BenignData point 122: Benign
#
# Data point 123: Benign
# Data point 124: Benign
# Data point 125: BenignData point 126: Benign
#
# Data point 127: Benign
# Data point 128: Benign
# Data point 129: Benign
# Data point 130: Benign
# Data point 19: Benign
# Data point 20: BenignData point 131: Benign
#
# Data point 21: BenignData point 132: Benign
# Latency for this chunk: 0.0007 secondsData point 22: Benign
# Data point 133: Benign
#
# Predictions for this chunk:
# Data point 23: Benign
# Data point 134: BenignData point 1: Benign
# CPU Utilization in process 202665: 100.0%
#
# Data point 135: Benign
# Data point 24: BenignNumber of CPUs 202665:2
# Data point 2: Benign
#
# Data point 136: Benign
# Data point 25: Benign
# Data point 26: BenignData point 3: Benign
#
# Data point 27: Benign
#
# Memory Usage 202665:17.7%Data point 28: BenignData point 137: Benign
#
# Index(['start_time', 'end_time_x', 'total_forward_packets_window',
#        'total_backward_packets_window', 'total_forward_bytes_window',
#        'total_backward_bytes_window', 'average_packet_size_fwd_window',
#        'average_packet_size_bwd_window', 'flow_duration_window',
#        'packet_count_window', 'mean_iat_fwd_window', 'stddev_iat_fwd_window',
#        'min_iat_fwd_window', 'max_iat_fwd_window', 'mean_iat_bwd_window',
#        'stddev_iat_bwd_window', 'min_iat_bwd_window', 'max_iat_bwd_window',
#        'flow_rate_packets_window', 'flow_rate_bytes_window',
#        'flow_direction_ratio_window', 'byte_direction_ratio_window',
#        'src_ip_entropy_window', 'dst_ip_entropy_window', 'time_diff',
#        'time_diff_seconds', 'src_ip', 'dst_ip', 'src_port', 'dst_port',
#        'protocol', 'flow_duration', 'total_forward_packets',
#        'total_backward_packets', 'total_bytes_forward', 'total_bytes_backward',
#        'mean_packet_length_forward', 'mean_packet_length_backward',
#        'packet_size_mean', 'flow_iat_mean', 'down_up_ratio',
#        'subflow_fwd_pkts', 'subflow_bwd_pkts', 'subflow_fwd_byts',
#        'subflow_bwd_byts', 'fwd_pkt_len_mean', 'fwd_pkt_len_max',
#        'fwd_pkt_len_min', 'fwd_pkt_len_std', 'fwd_iat_mean', 'fwd_iat_max',
#        'fwd_iat_min', 'fwd_iat_tot', 'fwd_blk_rate_avg', 'bwd_pkt_len_mean',
#        'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_std', 'bwd_iat_mean',
#        'bwd_iat_max', 'bwd_iat_min', 'bwd_iat_tot', 'bwd_blk_rate_avg',
#        'end_time_y', 'total_packets', 'total_bytes', 'Label', 'BinLabel'],
#       dtype='object')Data point 29: Benign
#
#
# Data point 4: BenignData point 30: Benign
# Data point 138: Benign
# Data point 5: Benign
# Data point 139: BenignData point 31: Benign
#
#
# Data point 140: BenignData point 6: Benign
# Data point 7: Benign
#
# Data point 32: BenignData point 141: BenignData point 8: Benign
#
#
# Data point 33: BenignData point 142: Benign
# Data point 9: Benign
# Data point 34: Benign
#
# Data point 10: BenignData point 35: BenignData point 143: Benign
#
# Latency for this chunk: 0.0007 seconds
# Data point 36: BenignData point 11: Benign
#
#
# Predictions for this chunk:
# Data point 144: BenignData point 37: BenignData point 12: Benign
#
#
# Data point 38: Benign
# Data point 1: BenignData point 145: BenignData point 13: BenignData point 39: Benign
#
#
#
# Data point 2: BenignData point 146: BenignData point 14: Benign
# Data point 40: Benign
#
# Data point 3: Benign
# Data point 147: BenignData point 15: BenignData point 41: Benign
#
#
#
# Data point 4: BenignData point 16: BenignData point 148: BenignData point 42: Benign
#
#
#
# Data point 5: BenignData point 17: Benign
# Data point 149: BenignData point 43: Benign
#
# Data point 6: Benign
# Data point 18: BenignData point 150: Benign
# Data point 7: BenignData point 44: Benign
#
#
#
# Data point 151: BenignData point 19: BenignData point 8: BenignData point 45: Benign
#
#
#
# Data point 152: BenignData point 20: BenignData point 9: BenignData point 46: Benign
#
#
#
# Data point 21: BenignData point 153: BenignData point 10: BenignData point 47: Benign
#
#
#
# Data point 22: BenignData point 154: BenignData point 48: BenignData point 11: Benign
#
#
#
# Data point 12: BenignData point 23: BenignData point 49: BenignData point 155: Benign
#
# Data point 13: Benign
# Data point 156: Benign
# Data point 50: BenignData point 24: Benign
#
# Data point 157: Benign
#
# Data point 14: BenignData point 51: Benign
# Data point 25: Benign
#
# Data point 26: Benign
# Data point 52: BenignData point 158: Benign
#
# Data point 15: Benign
# Data point 27: BenignData point 53: BenignData point 159: Benign
#
# Data point 16: Benign
#
# Data point 28: Benign
# Data point 54: Benign
# Data point 160: BenignData point 17: Benign
#
#
# Data point 29: Benign
# Data point 55: BenignData point 161: BenignData point 18: Benign
# Data point 30: Benign
#
# Data point 56: Benign
# Data point 162: BenignData point 31: BenignData point 19: Benign
# Data point 32: Benign
# Data point 33: Benign
#
#
#
# Data point 34: Benign
# Data point 35: Benign
# Data point 36: BenignData point 20: BenignData point 163: Benign
#
# Data point 57: Benign
# Data point 21: BenignData point 164: BenignData point 37: Benign
#
#
# Data point 38: Benign
# Data point 22: Benign
# Data point 23: BenignData point 58: BenignData point 165: Benign
#
# Data point 39: BenignData point 24: Benign
#
# Data point 59: BenignData point 40: Benign
#
#
# Data point 166: BenignData point 60: Benign
#
# Data point 41: Benign
# Data point 25: BenignData point 167: BenignData point 61: Benign
#
#
# Data point 168: BenignData point 62: Benign
#
#
# Data point 169: BenignData point 42: Benign
# Data point 170: BenignData point 26: Benign
# Data point 63: Benign
#
# Data point 171: BenignData point 27: Benign
#
# Data point 43: Benign
# Data point 172: Benign
#
# Data point 64: BenignData point 44: BenignData point 28: Benign
# Data point 45: Benign
# Data point 173: Benign
#
#
# Data point 65: BenignData point 29: BenignData point 174: Benign
# Data point 46: Benign
#
#
# Data point 47: BenignData point 66: BenignData point 175: Benign
# Data point 49: Benign
#
# Data point 30: Benign
# Data point 48: BenignData point 176: BenignData point 67: Benign
#
#
#
# Data point 68: BenignData point 50: BenignData point 31: BenignData point 177: Benign
#
#
# Data point 69: Benign
# Data point 178: BenignData point 32: Benign
# Data point 51: Benign
# Data point 70: Benign
#
#
# Data point 179: BenignData point 33: BenignData point 52: Benign
# Data point 71: Benign
#
# Data point 34: Benign
# Data point 180: Benign
# Data point 53: Benign
# Data point 72: BenignData point 181: Benign
#
# Data point 35: BenignData point 54: BenignData point 73: Benign
#
#
#
# Data point 36: BenignData point 182: BenignData point 55: Benign
#
# Data point 74: Benign
#
# Data point 183: BenignData point 37: BenignData point 56: Benign
# Data point 184: Benign
# Data point 185: Benign
# Data point 186: BenignData point 75: Benign
#
# Data point 187: Benign
#
#
# Data point 188: Benign
# Data point 189: Benign
# Data point 190: Benign
# Data point 76: BenignData point 57: BenignData point 191: Benign
# Data point 38: BenignData point 77: Benign
#
#
# Data point 192: BenignData point 78: Benign
#
#
# Data point 58: BenignData point 79: Benign
#
# Data point 59: BenignData point 80: BenignData point 39: Benign
# Data point 193: Benign
# Data point 60: Benign
#
# Data point 194: Benign
# Data point 61: BenignData point 40: BenignData point 81: Benign
#
# Data point 62: BenignData point 195: Benign
#
# Data point 63: Benign
#
# Data point 41: BenignData point 64: Benign
# Data point 82: Benign
#
#
# Data point 65: Benign
# Data point 196: BenignData point 83: BenignData point 66: Benign
#
# Data point 67: BenignData point 42: Benign
#
#
# Data point 68: BenignData point 43: Benign
#
# Data point 84: BenignData point 197: BenignData point 69: Benign
# Data point 198: Benign
# Data point 199: Benign
# Data point 200: Benign
#
# Data point 44: Benign
# Data point 201: BenignData point 85: Benign
#
# Data point 86: Benign
#
# Data point 202: BenignData point 45: BenignData point 87: Benign
#
# Data point 70: Benign
# Data point 46: Benign
# Data point 47: BenignData point 203: Benign
# Data point 88: Benign
# Data point 89: Benign
# Data point 71: Benign
#
# Data point 90: BenignData point 204: BenignData point 48: Benign
#
#
# Data point 91: Benign
#
# Data point 72: BenignData point 92: BenignData point 205: Benign
# Data point 49: Benign
# Data point 73: BenignData point 93: Benign
#
#
#
# Data point 50: Benign
# Data point 51: BenignData point 206: BenignData point 52: Benign
# Data point 74: Benign
# Data point 53: Benign
# Data point 94: Benign
#
#
# Data point 207: BenignData point 95: Benign
# Data point 75: BenignData point 54: Benign
#
#
# Data point 55: BenignData point 96: BenignData point 208: Benign
#
# Data point 76: BenignData point 56: BenignData point 97: Benign
#
#
# Data point 209: BenignData point 77: Benign
#
# Data point 78: Benign
# Data point 98: Benign
# Data point 57: BenignData point 210: Benign
#
#
# Data point 79: BenignData point 99: Benign
# Data point 80: BenignData point 58: Benign
# Data point 211: BenignData point 100: Benign
# Data point 101: Benign
#
#
#
# Data point 59: BenignData point 102: Benign
#
# Data point 81: BenignData point 60: Benign
# Data point 103: Benign
#
# Data point 104: Benign
# Data point 212: BenignData point 82: BenignData point 61: BenignData point 105: Benign
#
#
# Data point 62: Benign
#
# Data point 83: BenignData point 106: BenignData point 63: Benign
# Data point 213: Benign
#
# Data point 107: BenignData point 64: Benign
#
# Data point 108: BenignData point 84: Benign
#
# Data point 109: BenignData point 65: Benign
#
# Data point 110: Benign
# Data point 214: Benign
#
# Data point 85: BenignData point 111: BenignData point 66: BenignData point 112: Benign
#
#
#
# Data point 67: BenignData point 113: Benign
#
# Data point 68: Benign
# Data point 86: BenignData point 215: BenignData point 69: Benign
#
# Data point 114: Benign
#
# Data point 87: BenignData point 70: BenignData point 216: BenignData point 115: Benign
#
# Data point 116: Benign
#
# Data point 217: Benign
# Data point 71: BenignData point 117: Benign
# Data point 118: Benign
# Data point 119: Benign
#
# Data point 88: Benign
# Data point 72: BenignData point 120: BenignData point 218: Benign
#
#
# Data point 73: Benign
# Data point 219: BenignData point 89: Benign
# Data point 121: Benign
#
# Data point 220: Benign
# Data point 90: BenignData point 74: Benign
#
# Data point 122: Benign
# Data point 221: Benign
# Data point 91: Benign
# Data point 75: BenignData point 123: Benign
# Data point 222: Benign
#
#
# Data point 92: BenignData point 76: BenignData point 124: Benign
# Data point 93: BenignData point 223: Benign
#
#
# Data point 77: Benign
# Data point 125: BenignData point 224: Benign
# Data point 78: BenignData point 94: Benign
#
#
#
# Data point 126: BenignData point 225: BenignData point 95: BenignData point 79: Benign
#
#
#
# Data point 127: BenignData point 226: BenignData point 96: Benign
# Data point 80: Benign
#
# Data point 128: Benign
#
# Data point 227: BenignData point 97: BenignData point 81: Benign
#
#
# Data point 129: Benign
# Data point 98: BenignData point 228: BenignData point 82: Benign
#
# Data point 130: Benign
#
# Data point 99: BenignData point 131: BenignData point 229: BenignData point 83: Benign
#
#
#
# Data point 230: BenignData point 84: BenignData point 132: BenignData point 100: Benign
#
#
#
# Data point 133: BenignData point 231: BenignData point 85: BenignData point 101: Benign
#
# Data point 86: Benign
#
# Data point 232: Benign
# Data point 134: Benign
# Data point 102: BenignData point 233: Benign
#
#
# Data point 103: BenignData point 135: BenignData point 234: Benign
#
#
# Data point 104: BenignData point 136: BenignData point 235: BenignData point 87: Benign
#
# Data point 105: BenignData point 137: Benign
#
#
# Data point 106: BenignData point 88: Benign
# Data point 107: Benign
#
# Data point 138: BenignData point 108: Benign
#
# Data point 236: Benign
# Data point 109: Benign
# Data point 139: BenignData point 89: Benign
# Data point 110: Benign
#
#
# Data point 237: BenignData point 90: BenignData point 111: BenignData point 140: Benign
#
#
# Data point 91: BenignData point 238: Benign
# Data point 92: Benign
# Data point 112: Benign
#
# Data point 141: BenignData point 93: Benign
# Data point 239: Benign
#
# Data point 142: Benign
# Data point 113: Benign
#
# Data point 114: BenignData point 240: BenignData point 94: Benign
# Data point 115: Benign
#
# Data point 143: BenignData point 116: Benign
# Data point 95: BenignData point 241: Benign
#
# Data point 117: BenignData point 144: Benign
#
#
#
# Data point 118: BenignData point 145: Benign
# Data point 242: BenignData point 96: BenignData point 119: Benign
#
#
# Data point 120: BenignData point 146: BenignData point 97: Benign
#
#
#
# Data point 243: BenignData point 121: Benign
# Data point 147: BenignData point 98: Benign
# Data point 244: Benign
#
# Data point 122: BenignData point 245: Benign
#
# Data point 148: Benign
# Data point 99: BenignData point 123: Benign
# Data point 246: Benign
# Data point 124: Benign
#
#
# Data point 149: BenignData point 125: Benign
# Data point 100: BenignData point 247: BenignData point 101: Benign
#
#
# Data point 248: Benign
# Data point 150: BenignData point 126: Benign
#
# Data point 127: BenignData point 102: Benign
#
#
# Data point 103: Benign
# Data point 249: BenignData point 151: BenignData point 128: Benign
#
#
# Data point 104: BenignData point 250: BenignData point 152: BenignData point 129: Benign
#
#
#
# Data point 251: BenignData point 105: Benign
# Data point 153: BenignData point 252: BenignData point 130: BenignData point 154: Benign
#
#
#
#
# Data point 253: Benign
# Data point 106: BenignData point 107: BenignData point 131: BenignData point 155: Benign
#
#
#
# Data point 156: BenignData point 254: Benign
# Data point 132: BenignData point 108: BenignData point 157: Benign
#
#
#
# Data point 158: BenignData point 109: BenignData point 133: BenignData point 255: Benign
#
#
#
# Data point 256: BenignData point 110: BenignData point 159: BenignData point 134: Benign
#
#
#
# Data point 135: BenignData point 111: BenignData point 257: Benign
#
# Data point 160: Benign
# Data point 112: Benign
# Data point 136: BenignData point 258: BenignData point 161: Benign
#
#
#
# Data point 113: BenignData point 137: BenignData point 259: BenignData point 162: Benign
#
#
# Data point 114: Benign
# Data point 260: BenignData point 163: BenignData point 138: Benign
#
#
# Data point 261: BenignData point 115: BenignData point 139: Benign
#
#
# Data point 262: BenignData point 164: Benign
# Data point 116: Benign
#
# Data point 140: Benign
# Data point 263: BenignData point 165: Benign
# Data point 117: Benign
#
#
# Data point 141: BenignData point 264: BenignData point 166: BenignData point 118: Benign
#
#
#
# Data point 142: BenignData point 265: BenignData point 167: Benign
# Data point 119: BenignData point 143: Benign
#
#
# Data point 266: BenignData point 120: BenignData point 168: Benign
#
#
# Data point 267: BenignData point 144: Benign
#
# Data point 121: Benign
# Data point 268: Benign
# Data point 122: Benign
# Data point 123: Benign
# Data point 124: BenignData point 169: Benign
#
# Data point 145: BenignData point 125: Benign
#
#
# Data point 146: Benign
# Data point 269: BenignData point 147: Benign
# Data point 148: Benign
# Data point 149: Benign
#
# Data point 150: Benign
# Data point 170: BenignData point 270: BenignData point 151: BenignData point 126: Benign
#
#
# Data point 152: BenignData point 271: Benign
#
# Data point 127: BenignData point 272: Benign
#
# Data point 128: BenignData point 273: Benign
#
# Data point 129: Benign
# Data point 274: BenignData point 171: BenignData point 153: Benign
#
# Data point 130: Benign
# Data point 275: BenignData point 154: Benign
#
#
# Data point 131: Benign
# Data point 276: BenignData point 155: Benign
#
#
# Data point 277: BenignData point 156: Benign
# Data point 172: Benign
# Data point 278: BenignData point 132: Benign
#
# Data point 133: BenignData point 173: Benign
#
# Data point 157: BenignData point 134: Benign
#
# Data point 135: Benign
# Data point 174: BenignData point 136: Benign
#
#
# Data point 279: BenignData point 137: BenignData point 158: Benign
# Data point 175: Benign
#
#
# Data point 138: BenignData point 176: BenignData point 280: Benign
#
# Data point 177: BenignData point 139: Benign
#
# Data point 159: BenignData point 178: Benign
#
# Data point 140: Benign
# Data point 179: Benign
#
# Data point 141: Benign
# Data point 180: BenignData point 142: Benign
# Data point 143: Benign
# Data point 144: Benign
# Data point 281: BenignData point 160: Benign
# Data point 145: Benign
#
# Data point 181: BenignData point 282: BenignData point 161: Benign
#
#
# Data point 182: BenignData point 162: Benign
#
# Data point 146: Benign
# Data point 183: BenignData point 147: BenignData point 283: Benign
#
# Data point 148: Benign
#
# Data point 184: Benign
# Data point 149: BenignData point 163: Benign
#
# Data point 164: BenignData point 150: Benign
# Data point 284: Benign
# Data point 151: Benign
# Data point 165: Benign
# Data point 185: Benign
# Data point 152: Benign
# Data point 153: Benign
#
# Data point 285: BenignData point 154: Benign
#
# Data point 155: Benign
#
# Data point 166: BenignData point 156: Benign
# Data point 286: BenignData point 186: Benign
# Data point 157: Benign
# Data point 158: Benign
# Data point 159: Benign
#
# Data point 167: BenignData point 160: Benign
# Data point 161: Benign
# Data point 287: Benign
#
# Data point 187: BenignData point 288: Benign
# Data point 168: Benign
# Data point 162: BenignData point 188: Benign
#
#
# Data point 189: Benign
# Data point 190: Benign
# Data point 169: BenignData point 163: Benign
# Data point 191: BenignData point 289: Benign
# Data point 192: Benign
# Data point 193: Benign
#
# Data point 290: Benign
# Data point 194: Benign
#
# Data point 164: BenignData point 170: BenignData point 195: Benign
#
#
#
# Data point 196: BenignData point 291: BenignData point 165: Benign
# Data point 171: Benign
# Data point 292: BenignData point 197: Benign
#
# Data point 166: Benign
# Data point 167: Benign
#
# Data point 198: Benign
#
# Data point 172: BenignData point 168: BenignData point 293: Benign
#
# Data point 169: BenignData point 199: Benign
#
# Data point 200: BenignData point 294: Benign
# Data point 173: Benign
#
# Data point 295: BenignData point 170: BenignData point 201: Benign
#
# Data point 171: BenignData point 174: Benign
# Data point 172: Benign
#
#
#
# Data point 202: BenignData point 173: BenignData point 175: Benign
#
# Data point 296: Benign
# Data point 203: BenignData point 176: BenignData point 174: Benign
#
#
#
# Data point 175: BenignData point 297: Benign
# Data point 204: BenignData point 177: Benign
# Data point 176: HTTPAttackData point 298: Benign
#
#
# Data point 205: BenignData point 178: Benign
# Data point 299: Benign
#
#
# Data point 206: BenignData point 179: Benign
#
# Data point 177: HTTPAttack
# Data point 180: BenignData point 207: Benign
#
# Data point 181: UDPAttackData point 178: HTTPAttackData point 300: Benign
#
# Data point 182: UDPAttack
#
# Data point 301: BenignData point 183: UDPAttackData point 208: Benign
# Data point 179: HTTPAttack
# Data point 184: UDPAttack
#
# Data point 209: Benign
# Data point 302: Benign
# Data point 180: HTTPAttackData point 210: Benign
#
#
# Data point 181: HTTPAttack
# Data point 303: BenignData point 185: UDPAttackData point 182: HTTPAttackData point 211: Benign
#
#
# Data point 183: HTTPAttackData point 304: Benign
# Data point 186: UDPAttack
# Data point 212: Benign
#
# Data point 184: HTTPAttack
# Data point 187: UDPAttackData point 213: BenignData point 305: Benign
#
#
# Data point 185: HTTPAttack
# Data point 188: UDPAttackData point 214: Benign
# Data point 306: Benign
#
#
# Data point 186: Benign
# Data point 307: BenignData point 189: UDPAttackData point 187: BenignData point 215: Benign
#
#
#
# ...
# Data point 824: Benign
# Data point 797: Benign
#
# Data point 887: Benign
# Data point 825: BenignData point 813: Benign
# Data point 798: Benign
#
#
# Data point 799: BenignData point 888: BenignData point 826: BenignData point 814: Benign
#
#
#
# Data point 800: BenignData point 815: BenignData point 827: Benign
# Data point 889: BenignData point 801: Benign
#
#
# Data point 816: Benign
# Data point 828: BenignData point 802: BenignData point 890: Benign
#
#
# Data point 803: Benign
# Data point 817: BenignData point 829: Benign
# Data point 891: Benign
# Data point 818: Benign
# Data point 804: Benign
#
# Data point 819: Benign
# Data point 830: BenignData point 820: Benign
# Data point 892: Benign
# Data point 821: Benign
#
# Data point 822: Benign
# Data point 831: Benign
# Data point 823: BenignData point 805: Benign
# Data point 893: BenignData point 824: Benign
#
# Data point 825: Benign
# Data point 806: Benign
#
#
# Data point 826: BenignData point 807: BenignData point 832: BenignData point 894: Benign
#
# Data point 827: Benign
# Data point 808: Benign
#
#
# Data point 828: BenignData point 809: BenignData point 833: BenignData point 895: Benign
#
#
#
# Data point 834: Benign
# Data point 896: BenignData point 835: BenignData point 810: BenignData point 829: Benign
# Data point 836: Benign
# Data point 897: Benign
#
#
#
# Data point 837: BenignData point 898: BenignData point 811: Benign
# Data point 899: BenignData point 830: Benign
#
# Data point 900: Benign
#
# Data point 901: BenignData point 812: Benign
#
#
# Data point 838: BenignData point 813: BenignData point 831: BenignData point 902: Benign
#
#
# Data point 814: Benign
# Data point 903: BenignData point 839: Benign
# Data point 832: BenignData point 815: Benign
#
#
# Data point 816: Benign
#
# Data point 840: BenignData point 817: BenignData point 904: Benign
# Data point 833: Benign
#
# Data point 905: BenignData point 818: Benign
#
# Data point 906: BenignData point 841: Benign
#
# Data point 834: Benign
# Data point 819: BenignData point 907: Benign
#
# Data point 842: BenignData point 908: Benign
#
# Data point 909: BenignData point 820: Benign
#
# Data point 910: Benign
# Data point 911: Benign
# Data point 835: Benign
# Data point 821: BenignData point 912: BenignData point 843: Benign
#
#
# Data point 913: Benign
# Data point 914: Benign
# Data point 915: Benign
# Data point 836: Benign
#
# Data point 822: BenignData point 844: BenignData point 916: Benign
# Data point 837: BenignData point 917: Benign
#
#
#
# Data point 838: BenignData point 823: BenignData point 845: Benign
#
# Data point 824: BenignData point 918: Benign
# Data point 846: Benign
# Data point 839: Benign
#
# Data point 825: Benign
# Data point 919: BenignData point 847: Benign
# Data point 840: Benign
#
# Data point 920: BenignData point 826: Benign
# Data point 848: Benign
#
# Data point 841: Benign
#
# Data point 827: BenignData point 921: BenignData point 849: Benign
# Data point 842: Benign
#
#
# Data point 828: BenignData point 922: BenignData point 850: Benign
# Data point 843: Benign
#
# Data point 829: Benign
# Data point 923: BenignData point 851: BenignData point 844: Benign
#
#
# Data point 830: Benign
# Data point 924: BenignData point 852: Benign
# Data point 845: Benign
#
# Data point 831: Benign
# Data point 925: BenignData point 853: BenignData point 846: Benign
#
# Data point 854: Benign
#
#
# Data point 855: Benign
# Data point 832: BenignData point 926: BenignData point 856: BenignData point 847: Benign
#
#
# Data point 927: BenignData point 857: Benign
# Data point 833: Benign
#
#
# Data point 848: BenignData point 928: BenignData point 858: Benign
# Data point 834: Benign
# Data point 849: Benign
#
# Data point 929: Benign
# Data point 930: BenignData point 835: Benign
# Data point 859: Benign
#
#
# Data point 850: BenignData point 860: Benign
# Data point 861: Benign
# Data point 836: BenignData point 931: Benign
#
# Data point 851: Benign
# Data point 862: BenignData point 837: Benign
# Data point 932: Benign
# Data point 852: Benign
#
# Data point 863: BenignData point 838: Benign
# Data point 933: Benign
#
# Data point 853: Benign
# Data point 864: BenignData point 839: BenignData point 934: Benign
#
#
#
# Data point 865: BenignData point 854: BenignData point 840: BenignData point 935: Benign
#
#
#
# Data point 866: BenignData point 855: BenignData point 936: BenignData point 841: Benign
#
#
# Data point 867: Benign
#
# Data point 937: BenignData point 842: BenignData point 856: Benign
#
#
# Data point 868: BenignData point 843: BenignData point 938: BenignData point 857: Benign
# Data point 869: Benign
#
#
# Data point 858: BenignData point 939: BenignData point 844: Benign
# Data point 870: Benign
#
#
#
# Data point 940: BenignData point 859: BenignData point 845: Benign
#
# Data point 871: Benign
#
# Data point 941: BenignData point 860: BenignData point 846: Benign
# Data point 872: BenignData point 942: Benign
#
#
#
# Data point 861: BenignData point 847: BenignData point 873: Benign
# Data point 943: Benign
#
# Data point 862: Benign
# Data point 848: BenignData point 874: Benign
#
# Data point 944: Benign
# Data point 849: BenignData point 863: Benign
# Data point 875: Benign
#
# Data point 945: Benign
#
# Data point 850: BenignData point 864: BenignData point 876: Benign
#
#
# Data point 946: BenignData point 865: BenignData point 851: BenignData point 877: Benign
# Data point 947: Benign
#
# Data point 948: Benign
#
# Data point 852: BenignData point 866: Benign
# Data point 878: BenignData point 949: Benign
#
#
# Data point 879: Benign
#
# Data point 950: BenignData point 867: BenignData point 853: Benign
# Data point 880: Benign
#
# Data point 951: BenignData point 881: Benign
# Data point 854: Benign
#
# Data point 952: BenignData point 882: Benign
#
#
# Data point 855: BenignData point 953: BenignData point 883: Benign
# Data point 868: Benign
#
# Data point 856: Benign
# Data point 954: Benign
# Data point 955: Benign
#
# Data point 956: BenignData point 857: Benign
# Data point 957: Benign
# Data point 884: BenignData point 869: Benign
# Data point 858: Benign
# Data point 859: Benign
#
#
# Data point 885: BenignData point 958: Benign
# Data point 886: Benign
# Data point 887: BenignData point 870: Benign
# Data point 860: BenignData point 888: Benign
#
# Data point 861: Benign
#
#
# Data point 889: BenignData point 871: BenignData point 959: BenignData point 862: Benign
#
#
#
# Data point 960: BenignData point 872: BenignData point 890: BenignData point 863: Benign
#
#
#
# Data point 891: BenignData point 873: Benign
# Data point 874: BenignData point 864: BenignData point 961: Benign
#
#
#
# Data point 865: BenignData point 892: BenignData point 875: Benign
# Data point 962: Benign
#
# Data point 866: BenignData point 963: Benign
# Data point 893: Benign
#
# Data point 894: BenignData point 876: BenignData point 964: Benign
#
# Data point 867: BenignData point 895: Benign
#
# Data point 896: Benign
#
#
# Data point 897: BenignData point 868: Benign
# Data point 965: BenignData point 898: BenignData point 877: Benign
#
#
#
# Data point 966: BenignData point 899: BenignData point 878: Benign
# Data point 869: Benign
#
#
# Data point 900: BenignData point 879: BenignData point 967: Benign
# Data point 870: BenignData point 968: Benign
#
#
#
# Data point 901: BenignData point 871: BenignData point 969: Benign
# Data point 880: Benign
# Data point 902: Benign
#
#
# Data point 903: BenignData point 872: BenignData point 970: Benign
#
#
# Data point 881: BenignData point 873: BenignData point 904: BenignData point 971: Benign
#
# Data point 882: Benign
#
# Data point 905: Benign
# Data point 883: BenignData point 874: Benign
# Data point 972: Benign
#
# Data point 884: Benign
# Data point 875: BenignData point 906: Benign
# Data point 973: BenignData point 885: Benign
#
#
# Data point 876: BenignData point 907: Benign
#
# Data point 974: BenignData point 877: Benign
# Data point 886: Benign
#
# Data point 908: Benign
# Data point 909: BenignData point 975: BenignData point 878: Benign
#
# Data point 879: Benign
#
#
# Data point 910: BenignData point 880: BenignData point 887: Benign
# Data point 881: BenignData point 976: UDPAttack
#
#
#
# Data point 911: BenignData point 977: UDPAttackData point 882: Benign
#
# Data point 883: Benign
# Data point 888: Benign
# Data point 884: Benign
# Data point 978: UDPAttackData point 912: Benign
#
# Data point 885: Benign
# Data point 913: BenignData point 889: Benign
# Data point 979: UDPAttack
# Data point 886: Benign
#
# Data point 914: Benign
# Data point 890: BenignData point 980: UDPAttack
#
# Data point 887: Benign
# Data point 981: BenignData point 891: BenignData point 915: Benign
#
#
# Data point 892: Benign
#
# Data point 982: BenignData point 916: BenignData point 888: BenignData point 893: Benign
#
# Data point 983: BenignData point 917: Benign
# Data point 984: Benign
#
#
#
# Data point 894: BenignData point 985: BenignData point 889: Benign
#
# Data point 918: Benign
# Data point 986: BenignData point 895: BenignData point 919: Benign
#
# Data point 987: Benign
#
# Data point 920: Benign
#
# Data point 890: BenignData point 896: BenignData point 921: BenignData point 988: Benign
# Data point 897: Benign
#
#
#
# Data point 898: BenignData point 922: Benign
# Data point 891: BenignData point 989: BenignData point 899: Benign
#
#
# Data point 892: BenignData point 900: BenignData point 923: Benign
#
#
#
# Data point 893: BenignData point 901: Benign
#
# Data point 924: BenignData point 990: Benign
# Data point 894: Benign
# Data point 902: BenignData point 991: Benign
#
# Data point 925: Benign
# Data point 895: Benign
# Data point 992: BenignData point 903: Benign
#
# Data point 926: Benign
# Data point 927: Benign
#
# Data point 904: BenignData point 993: BenignData point 928: Benign
# Data point 896: Benign
# Data point 994: BenignData point 905: Benign
#
# Data point 929: Benign
#
# Data point 930: BenignData point 897: BenignData point 995: Benign
#
# Data point 931: Benign
#
#
# Data point 906: BenignData point 932: BenignData point 996: Benign
# Data point 898: Benign
#
# Data point 933: BenignData point 907: Benign
# Data point 997: BenignData point 899: Benign
#
#
# Data point 908: Benign
# Data point 998: BenignData point 934: Benign
#
#
# Data point 999: BenignData point 935: Benign
# Data point 900: BenignData point 909: Benign
#
#
# Data point 901: Benign
# Data point 936: BenignData point 1000: BenignData point 910: BenignData point 902: Benign
#
# Latency for this chunk: 24.1056 seconds
#
# Data point 937: Benign
# Data point 903: BenignData point 911: Benign
# Data point 904: Benign
#
# Total processing time: 25.2525 seconds
#
# Data point 938: BenignData point 912: Benign
# Data point 939: Benign
# Average latency per chunk: 24.1056 seconds
#
#
# Data point 913: BenignData point 940: BenignData point 905: Benign
#
#
# Data point 906: BenignData point 914: BenignData point 941: Benign
#
#
# Data point 915: BenignData point 907: Benign
# Data point 942: Benign
# Data point 916: Benign
# Data point 908: Benign
# Data point 943: Benign
# Data point 917: Benign
# Data point 909: Benign
#
# Data point 944: Benign
# Data point 918: BenignData point 910: BenignData point 945: Benign
#
#
# Data point 919: BenignData point 911: BenignData point 946: Benign
# Data point 920: Benign
#
#
# Data point 912: BenignData point 921: Benign
#
# Data point 947: Benign
# Data point 922: BenignData point 913: BenignData point 948: Benign
#
#
# Data point 923: BenignData point 914: BenignData point 949: Benign
#
# Data point 924: Benign
# Data point 915: Benign
# Data point 950: BenignData point 925: Benign
#
#
# Data point 926: BenignData point 916: BenignData point 951: Benign
#
#
# Data point 927: BenignData point 917: Benign
# Data point 952: Benign
# Data point 928: Benign
# Data point 953: BenignData point 918: Benign
#
#
# Data point 929: BenignData point 954: BenignData point 919: Benign
#
# Data point 930: BenignData point 955: Benign
#
#
# Data point 920: BenignData point 931: Benign
# Data point 956: BenignData point 921: Benign
#
#
# Data point 932: BenignData point 922: BenignData point 957: Benign
#
#
# Data point 923: BenignData point 933: BenignData point 958: Benign
#
#
# Data point 924: BenignData point 934: BenignData point 959: Benign
#
#
# Data point 925: BenignData point 935: BenignData point 960: Benign
#
#
# Data point 926: BenignData point 961: BenignData point 936: Benign
#
# Data point 937: Benign
# Data point 927: BenignData point 962: Benign
#
#
# Data point 938: BenignData point 928: BenignData point 963: Benign
#
#
# Data point 964: BenignData point 939: BenignData point 929: Benign
#
#
# Data point 930: BenignData point 940: BenignData point 965: Benign
#
#
# Data point 931: BenignData point 941: BenignData point 966: Benign
#
#
# Data point 942: BenignData point 932: BenignData point 967: Benign
#
#
# Data point 943: BenignData point 933: BenignData point 968: Benign
#
#
# Data point 944: BenignData point 934: BenignData point 969: Benign
#
#
# Data point 970: BenignData point 935: BenignData point 945: Benign
#
#
# Data point 936: BenignData point 971: BenignData point 946: Benign
#
#
# Data point 937: BenignData point 972: BenignData point 947: Benign
#
#
# Data point 938: BenignData point 948: BenignData point 973: Benign
#
#
# Data point 949: BenignData point 939: BenignData point 974: Benign
#
#
# Data point 975: BenignData point 950: BenignData point 940: Benign
#
#
# Data point 941: Benign
# Data point 976: BenignData point 942: BenignData point 951: Benign
#
#
# Data point 977: BenignData point 943: BenignData point 952: Benign
#
#
# Data point 978: BenignData point 944: Benign
# Data point 953: Benign
# Data point 945: Benign
#
# Data point 979: BenignData point 954: BenignData point 946: Benign
#
# Data point 955: Benign
# Data point 980: Benign
# Data point 947: Benign
# Data point 956: Benign
# Data point 981: Benign
# Data point 948: Benign
# Data point 957: BenignData point 982: Benign
#
#
# Data point 949: BenignData point 958: Benign
# Data point 950: Benign
#
# Data point 983: BenignData point 984: Benign
# Data point 959: Benign
#
# Data point 951: BenignData point 985: BenignData point 960: Benign
# Data point 986: Benign
#
#
# Data point 952: BenignData point 961: Benign
# Data point 987: BenignData point 953: Benign
#
#
# Data point 988: BenignData point 962: BenignData point 954: Benign
#
# Data point 963: Benign
# Data point 989: Benign
# Data point 955: BenignData point 964: Benign
#
# Data point 990: Benign
# Data point 956: Benign
# Data point 965: Benign
#
#
#
# Data point 967: Benign
# Data point 991: BenignData point 957: BenignData point 966: BenignData point 968: Benign
#
# Data point 992: BenignData point 969: BenignData point 958: Benign
#
# Data point 970: BenignData point 959: Benign
#
#
# Data point 960: Benign
# Data point 993: BenignData point 961: BenignData point 971: Benign
# Data point 994: Benign
#
#
# Data point 972: BenignData point 995: BenignData point 962: Benign
#
#
# Data point 996: BenignData point 973: BenignData point 963: Benign
#
#
# Data point 997: BenignData point 974: BenignData point 964: Benign
#
#
# Data point 998: BenignData point 975: BenignData point 965: Benign
#
#
# Data point 966: BenignData point 976: BenignData point 999: Benign
#
# Data point 967: BenignData point 977: Benign
#
#
# Data point 1000: BenignData point 968: BenignData point 978: Benign
#
# Data point 969: Benign
# Latency for this chunk: 23.3320 seconds
#
# Data point 970: Benign
# Total processing time: 24.4368 seconds
#
# Data point 979: BenignAverage latency per chunk: 23.3320 secondsData point 971: XMasAttack
#
#
# Data point 980: BenignData point 972: XMasAttack
#
# Data point 973: XMasAttackData point 981: Benign
#
# Data point 974: XMasAttackData point 982: Benign
#
# Data point 983: BenignData point 975: XMasAttack
# Data point 976: Benign
#
# Data point 984: BenignData point 977: Benign
# Data point 978: Benign
# Data point 979: Benign
# Data point 985: Benign
# Data point 986: Benign
#
# Latency for this chunk: 22.8956 secondsData point 980: Benign
#
#
# Total processing time: 24.0515 secondsData point 981: Benign
#
# Average latency per chunk: 22.8956 secondsData point 982: Benign
# Data point 983: Benign
#
# Data point 984: Benign
# Data point 985: Benign
# Data point 986: Benign
# Data point 987: Benign
# Data point 988: Benign
# Data point 989: Benign
# Data point 990: Benign
# Data point 991: Benign
# Data point 992: Benign
# Data point 993: Benign
# Data point 994: Benign
# Data point 995: Benign
# Data point 996: Benign
# Data point 997: Benign
# Data point 998: Benign
# Data point 999: Benign
# Data point 1000: Benign
# Latency for this chunk: 23.0289 seconds
#
# Total processing time: 24.1333 seconds
# Average latency per chunk: 23.0289 seconds
# Total processing time with parallelization: 149.7212 seconds
